# %%
import snorkel

# %%
import pandas as pd

# %%
crowd_df =pd.read_csv('/jupyter/data/output/match_crowd_data.csv')
crowd_df.head()
# Out:
#    Unnamed: 0    DB_ID       DO_ID                 disease  \
# 0           0  DB00657  DOID_10763            hypertension
# 1        1285  DB00657  DOID_10824  malignant hypertension
# 2           1  DB00401  DOID_10763            hypertension
# 3           2  DB00612  DOID_10763            hypertension
# 4           3  DB00960  DOID_10763            hypertension
#
#                                    Label_ID   relation      Section  \
# 0  976f404f-4857-4bad-9a3c-9bf3d5ca9f5b.xml  treatment  Indications
# 1  976f404f-4857-4bad-9a3c-9bf3d5ca9f5b.xml  treatment  Indications
# 2  ce733b39-7857-4538-92d6-1c68a4e4eb75.xml  treatment  Indications
# 3  c818c38d-ee37-4ceb-b078-611483b4f743.xml  treatment  Indications
# 4  d4078b63-30ad-435b-a081-4d90562962b5.xml  treatment  Indications
#
#                                  Set_ID      Drug_Brand_Name  \
# 0  c6822ce4-e741-4366-b72a-5f5146354f97              Vecamyl
# 1  c6822ce4-e741-4366-b72a-5f5146354f97              Vecamyl
# 2  a6a8a8ba-3966-4f37-a58b-44d3b05bdc4e          Nisoldipine
# 3  c818c38d-ee37-4ceb-b078-611483b4f743  Bisoprolol Fumarate
# 4  b5a5a1e9-ee9b-41b1-b2d5-5f5834b816a7             Pindolol
#
#   Active_ingredient     UNII_ID  \
# 0      Mecamylamine  6EE945D3OK
# 1      Mecamylamine  6EE945D3OK
# 2       NISOLDIPINE  4I8HAB65SZ
# 3        BISOPROLOL  Y41JS2NL6U
# 4          PINDOLOL  BJ4HF6IU1D
#
#                                              Context  WordCount     Drug_name
# 0  For the management of moderately severe to sev...         17  Mecamylamine
# 1  For the management of moderately severe to sev...         17  Mecamylamine
# 2  Nisoldipine extended-release tablets are indic...         22   Nisoldipine
# 3  Bisoprolol fumarate tablets, USP are indicated...         23    Bisoprolol
# 4  Pindolol tablets are indicated in the manageme...         25      Pindolol

# %%
test_df =pd.read_csv('/jupyter/data/output/match_expert_data.csv')
test_df.head()
# Out:
#      DB_ID       DO_ID       disease  \
# 0  DB00401  DOID_10763  HYPERTENSION
# 1  DB00612  DOID_10763  HYPERTENSION
# 2  DB00960  DOID_10763  HYPERTENSION
# 3  DB00876  DOID_10763  HYPERTENSION
# 4  DB00598  DOID_10763  HYPERTENSION
#
#                                    Label_ID               relation  \
# 0  ce733b39-7857-4538-92d6-1c68a4e4eb75.xml  Indication: Treatment
# 1  c818c38d-ee37-4ceb-b078-611483b4f743.xml  Indication: Treatment
# 2  d4078b63-30ad-435b-a081-4d90562962b5.xml  Indication: Treatment
# 3  ab531d28-345b-4113-9fde-00cd63ad5b1a.xml  Indication: Treatment
# 4  78765cc3-27dc-0373-e053-2991aa0a7fe1.xml  Indication: Treatment
#
#        Section                                Set_ID      Drug_Brand_Name  \
# 0  Indications  a6a8a8ba-3966-4f37-a58b-44d3b05bdc4e          Nisoldipine
# 1  Indications  c818c38d-ee37-4ceb-b078-611483b4f743  Bisoprolol Fumarate
# 2  Indications  b5a5a1e9-ee9b-41b1-b2d5-5f5834b816a7             Pindolol
# 3  Indications  64fbc500-3b77-4c9c-8576-b3ec5f6655a5  Eprosartan Mesylate
# 4  Indications  f81baebd-424d-4d39-893c-d9d622377c53        Labetalol HCL
#
#   Active_ingredient     UNII_ID  \
# 0       NISOLDIPINE  4I8HAB65SZ
# 1        BISOPROLOL  Y41JS2NL6U
# 2          PINDOLOL  BJ4HF6IU1D
# 3        EPROSARTAN  2KH13Z0S0Y
# 4         LABETALOL  R5H8897N95
#
#                                              Context  WordCount    Drug_name
# 0  Nisoldipine extended-release tablets are indic...         22  Nisoldipine
# 1  Bisoprolol fumarate tablets, USP are indicated...         23   Bisoprolol
# 2  Pindolol tablets are indicated in the manageme...         25     Pindolol
# 3  Eprosartan mesylate tablets are indicated for ...         28   Eprosartan
# 4  Labetalol hydrochloride tablets, USP are indic...         31    Labetalol

# %%
diff = pd.concat([crowd_df,test_df])
diff  = diff.reset_index(drop=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
diff_gpby = diff.groupby(['Label_ID','DO_ID'])

# %%
idx = [d.index[0] for g,d in diff_gpby if len(d) == 1]

# %%
idx_val = [d.index[0] for g,d in diff_gpby if len(d) > 1]

# %%
train_df = diff.iloc[idx]

# %%
dev_df = diff.iloc[idx_val]
len(dev_df)
# Out:
# 328

# %%
dev_df.head()
# Out:
#    Active_ingredient                                            Context  \
# 37          ramipril  Ramipril capsules are indicated in patients 55...
# 39          ramipril  Ramipril capsules are indicated in patients 55...
# 17      TRANDOLAPRIL  \r\nHypertension:\r\nTrandolapril tablets are ...
# 18      TRANDOLAPRIL  \r\nHypertension:\r\nTrandolapril tablets are ...
# 19      TRANDOLAPRIL  \r\nHypertension:\r\nTrandolapril tablets are ...
#
#       DB_ID       DO_ID Drug_Brand_Name     Drug_name  \
# 37  DB00178  DOID_10763        Ramipril      Ramipril
# 39  DB00178   DOID_1558        Ramipril      Ramipril
# 17  DB00519  DOID_10763    Trandolapril  Trandolapril
# 18  DB00519   DOID_1558    Trandolapril  Trandolapril
# 19  DB00519    DOID_178    Trandolapril  Trandolapril
#
#                                     Label_ID      Section  \
# 37  00bdb48f-8b8f-4cc5-bb63-77213f2279cb.xml  Indications
# 39  00bdb48f-8b8f-4cc5-bb63-77213f2279cb.xml  Indications
# 17  02953299-f03e-4305-9b78-8590f2ad4a46.xml  Indications
# 18  02953299-f03e-4305-9b78-8590f2ad4a46.xml  Indications
# 19  02953299-f03e-4305-9b78-8590f2ad4a46.xml  Indications
#
#                                   Set_ID     UNII_ID  Unnamed: 0  WordCount  \
# 37  00bdb48f-8b8f-4cc5-bb63-77213f2279cb  L35JN3I7SJ        19.0        211
# 39  00bdb48f-8b8f-4cc5-bb63-77213f2279cb  L35JN3I7SJ      1924.0        211
# 17  ad682e7f-e0f5-4f11-8e05-dd308cbf6a05  1T0N3G9CRC        12.0        110
# 18  ad682e7f-e0f5-4f11-8e05-dd308cbf6a05  1T0N3G9CRC      1909.0        110
# 19  ad682e7f-e0f5-4f11-8e05-dd308cbf6a05  1T0N3G9CRC      2000.0        110
#
#              disease   relation
# 37      hypertension  treatment
# 39        angioedema     effect
# 17      hypertension  treatment
# 18        angioedema     effect
# 19  vascular disease     effect

# %%
Y_dev = dev_df.merge(test_df, on=['Label_ID','DO_ID'])['relation_y']

# %%
classes_y = {
'Effect': 0,
'Contraindication': 1,
'Indication: Symptomatic Relief': 2,
'Indication: Treatment':3 
}
Y_dev =Y_dev.map(classes_y)

# %%
from snorkel.labeling import LabelingFunction



def worker_lf(x, worker_dict):
    return worker_dict.get(x.tweet_id, ABSTAIN)


def make_worker_lf(worker_id):
    worker_dict = worker_dicts[worker_id]
    name = f"worker_{worker_id}"
    return LabelingFunction(name, f=worker_lf, resources={"worker_dict": worker_dict})


def crowd(x):
    #print (x.relation_type)
    if x.relation in classes:
        return classes[x.relation]
    return ABSTAIN

# %%
from snorkel.labeling import PandasLFApplier

# %%
applier = PandasLFApplier([LabelingFunction('CrowdLabels', f=crowd)])

# %%
L_train = applier.apply(train_df)
# Out:
# 100%|██████████| 1248/1248 [00:00<00:00, 17379.66it/s]

# %%
L_test = applier.apply(test_df)
# Out:
# 100%|██████████| 330/330 [00:00<00:00, 11648.59it/s]

# %%
L_val = applier.apply(val_df)
# Out:
# /opt/conda/lib/python3.7/site-packages/tqdm/std.py:654: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
#
#
# 100%|██████████| 328/328 [00:00<00:00, 12747.11it/s]

# %%
from snorkel.labeling import LFAnalysis

# %%
my_phrases = { 'effect': 
["hypersensitivity reactions",
"associated with the risk of",
"to the risk of",
"a high risk for",
"a high risk of",
"high incidence of", 
"higher incidence of", 
" cause ",
" causes ",
"symptoms occure",
"teratogenic",
"site reaction",
"the risk of development",
"is associated with a risk of",
"symptoms of the poisoning",
"symptoms of poisoning" 
],

 'contraindication': 
["not administrated to",
"contraindicated in",
"contraindicatedin",
"should not be used",
"is contraindication for",
"is contraindication when",
"is contraindicated when",
"must not be used for",
"do not administer",
"should not initiate",
"not be administered to",
"do not initiate patients",
"contraindication for",
"should not be given",
"do not use"],
              
 'relief': 
["relief of the signs",
"relief of signs",
"relief of symptoms",
"relief of the symptoms",
"help",
"helps",
"relief of signs and symptoms of",
"reduction of symptoms of",
"treatment of the symptoms of",
"for the relief",
"management of the signs and symptoms of"], 

 'treatment':
[" indicated for the treatment of",
" indicated in the management of",
" indicated for the management of",
"for the management of",
"management of",
" indicated for the maintenance of remission", 
"or the treatment of",
"in the treatment of",
" indicated as",
" indicated in",
"be effective",
"active treatment of",
" indicated for",
"treatment of",
" indicated as an adjunct",
" indicated for use in the treatment of", 
" indicated for the intermittent treatment", 
" indicated to reduce the rate of",
" indicated for the rapid control",
" indicated for the control",
"reduce the risk of",
" indicated as adjunctive treatment",
"for the treatment of",
" indicated as an adjunct"]
           }

phrases = pd.DataFrame({ key:pd.Series(value) for key, value in my_phrases.items() })

phrases
# Out:
#                           effect          contraindication  \
# 0     hypersensitivity reactions      not administrated to
# 1    associated with the risk of        contraindicated in
# 2                 to the risk of         contraindicatedin
# 3                a high risk for        should not be used
# 4                 a high risk of   is contraindication for
# 5              high incidence of  is contraindication when
# 6            higher incidence of   is contraindicated when
# 7                         cause       must not be used for
# 8                        causes          do not administer
# 9                symptoms occure       should not initiate
# 10                   teratogenic    not be administered to
# 11                 site reaction  do not initiate patients
# 12       the risk of development      contraindication for
# 13  is associated with a risk of       should not be given
# 14     symptoms of the poisoning                do not use
# 15         symptoms of poisoning                       NaN
# 16                           NaN                       NaN
# 17                           NaN                       NaN
# 18                           NaN                       NaN
# 19                           NaN                       NaN
# 20                           NaN                       NaN
# 21                           NaN                       NaN
# 22                           NaN                       NaN
# 23                           NaN                       NaN
#
#                                      relief  \
# 0                       relief of the signs
# 1                           relief of signs
# 2                        relief of symptoms
# 3                    relief of the symptoms
# 4                                      help
# 5                                     helps
# 6           relief of signs and symptoms of
# 7                  reduction of symptoms of
# 8              treatment of the symptoms of
# 9                            for the relief
# 10  management of the signs and symptoms of
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
#
#                                       treatment
# 0                indicated for the treatment of
# 1                indicated in the management of
# 2               indicated for the management of
# 3                         for the management of
# 4                                 management of
# 5    indicated for the maintenance of remission
# 6                           or the treatment of
# 7                           in the treatment of
# 8                                  indicated as
# 9                                  indicated in
# 10                                 be effective
# 11                          active treatment of
# 12                                indicated for
# 13                                 treatment of
# 14                      indicated as an adjunct
# 15        indicated for use in the treatment of
# 16     indicated for the intermittent treatment
# 17              indicated to reduce the rate of
# 18              indicated for the rapid control
# 19                    indicated for the control
# 20                           reduce the risk of
# 21            indicated as adjunctive treatment
# 22                         for the treatment of
# 23                      indicated as an adjunct

# %%
effect = { 'phrases': 
["hypersensitivity reactions",
"associated with the risk of",
"to the risk of",
"a high risk for",
"a high risk of",
"high incidence of", 
"higher incidence of", 
" cause ",
" causes ",
"symptoms occure",
"teratogenic",
"site reaction",
"the risk of development",
"is associated with a risk of",
"symptoms of the poisoning",
"symptoms of poisoning" 
]}
effect_df = pd.DataFrame(effect)

 
contraindication = {'phrases': 
["not administrated to",
"contraindicated in",
"contraindicatedin",
"should not be used",
"is contraindication for",
"is contraindication when",
"is contraindicated when",
"must not be used for",
"do not administer",
"should not initiate",
"not be administered to",
"do not initiate patients",
"contraindication for",
"should not be given",
"do not use"]}
contraindication_df = pd.DataFrame(contraindication)
              
relief = {'phrases': 
["relief of the signs",
"relief of signs",
"relief of symptoms",
"relief of the symptoms",
"help",
"helps",
"relief of signs and symptoms of",
"reduction of symptoms of",
"treatment of the symptoms of",
"for the relief",
"management of the signs and symptoms of"]} 
relief_df = pd.DataFrame(relief)

treatment = {'phrases':
[" indicated for the treatment of",
" indicated in the management of",
" indicated for the management of",
"for the management of",
"management of",
" indicated for the maintenance of remission", 
"or the treatment of",
"in the treatment of",
" indicated as",
" indicated in",
"be effective",
"active treatment of",
" indicated for",
"treatment of",
" indicated as an adjunct",
" indicated for use in the treatment of", 
" indicated for the intermittent treatment", 
" indicated to reduce the rate of",
" indicated for the rapid control",
" indicated for the control",
"reduce the risk of",
" indicated as adjunctive treatment",
"for the treatment of"]}
treatment_df = pd.DataFrame(treatment)

# %%
from snorkel.labeling import labeling_function
from snorkel.preprocess import preprocessor


def check(x, string):
    return x in string


def find_phrases(text):
    # Find which phrases appear in the sentence
    class_effect = effect_df['phrases'].apply(lambda num : check(num,text))
    class_contraindication = contraindication_df['phrases'].apply(lambda num : check(num,text))
    class_relief = relief_df['phrases'].apply(lambda num : check(num,text))
    class_treatment = treatment_df['phrases'].apply(lambda num : check(num,text))
    
    #Create a dataset from them
    classes = {
    'effect': class_effect,
    'contraindication': class_contraindication,
    'relief': class_relief,
    'treatment':class_treatment 
    }

    classes = pd.DataFrame(classes)
    
    a = class_effect.index[class_effect == True].tolist()
    b = class_contraindication.index[class_contraindication == True].tolist()
    c = class_relief.index[class_relief == True].tolist()
    d = class_treatment.index[class_treatment == True].tolist()
    return classes, a, b, c, d
                                                 

# return the position of a phrase/word in a sentence
def pos_of_phrase(string, substring):
    substring_length = len(substring)    
    def recurse(locations_found, start):
        location = string.find(substring, start)
        if location != -1:
            return recurse(locations_found + [location], location+substring_length)
        else:
            return locations_found

    return recurse([], 0)

# return the minimum distance of all phrase/word from the target disease
def get_diff_of_pos(classes, column, pos, string):
    name = classes.columns[column]
    my_col = classes[name]
    x = [k for k,v in enumerate(my_col) if v == True]
    
    candidate = []
    distances = []
    for i in range(len(x)):
        word = phrases[classes.columns[column]][x[i]]
        
        for i in range(len(pos_of_phrase(string, word))):
            distances.append( abs(pos -   pos_of_phrase(string, word)[i]) )

    return min(distances)


@labeling_function()
def phrases_claas(x):
    
    text = x.Context

    classes, a, b, c, d =find_phrases(text)


    # Check if you have unique class and label based on that 
    if len(a)!=0 and len(b)==len(c)==len(d)==0:
        #print('effect')
        return RELATION_CLASSES['effect']
    elif len(b)!=0 and len(a)==len(c)==len(d)==0:
        #print('contraindication')
        return RELATION_CLASSES['contraindication']
    elif len(c)!=0 and len(a)==len(b)==len(d)==0:
        #print('relief')
        return  RELATION_CLASSES['relief']
    elif len(d)!=0 and len(a)==len(b)==len(c)==0:
        #print('treatment')
        return  RELATION_CLASSES['treatment']
    elif len(a)==len(b)==len(c)==len(d)==0:
        #print('IDK')
        return ABSTAIN
    return ABSTAIN

@labeling_function()
def phrase_closeness(x):
    text = x.Context
    pos1 = text.find(x.disease)
    dis_len = len(x.disease)
    classes, a, b, c, d = find_phrases(text)
    
    minDist = len(text.split())
    category = ABSTAIN
    for class_,found_phrases in {'effect':a, 'contraindication':b, 'relief':c, 'treatment':d}.items():
        for phrase_index in found_phrases:
            phrase =phrases.loc[phrase_index,class_]
            pos2 = text.find(phrase)
            phr_len = len(phrase)
            if pos1 > pos2:
                span = text[pos2+phr_len:pos1]
            else:
                span = text[pos1+dis_len:pos2]
            words = span.split()
            distance = len(words)
            if minDist > distance:
                minDist = distance
                category = class_
    
    if category == ABSTAIN:
        return ABSTAIN
    return RELATION_CLASSES[category]

@labeling_function()
def crowd(x):
    #print (x.relation_type)
    if x.relation in RELATION_CLASSES:
        return RELATION_CLASSES[x.relation]
    return ABSTAIN

# %%
dev_df.relation.unique()
# Out:
# array(['treatment', 'effect', 'relief', 'contraindication'], dtype=object)

# %%
ABSTAIN = -1

RELATION_CLASSES = {
'effect': 0,
'contraindication': 1,
'relief': 2,
'treatment':3 
} 
RELATION_CLASSES
# Out:
# {'effect': 0, 'contraindication': 1, 'relief': 2, 'treatment': 3}

# %%
lfs = [crowd, phrases_claas, phrase_closeness]
applier = PandasLFApplier(lfs)

# %%
L_train = applier.apply(train_df)
# Out:
# /opt/conda/lib/python3.7/site-packages/tqdm/std.py:654: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1248 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 12/1248 [00:00<00:10, 118.42it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 25/1248 [00:00<00:10, 121.58it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 38/1248 [00:00<00:09, 122.11it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 51/1248 [00:00<00:09, 123.27it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▌         | 64/1248 [00:00<00:09, 123.82it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▋         | 78/1248 [00:00<00:09, 125.92it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 92/1248 [00:00<00:09, 127.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 105/1248 [00:00<00:09, 125.57it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 118/1248 [00:00<00:09, 125.39it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|█         | 131/1248 [00:01<00:08, 126.47it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 144/1248 [00:01<00:08, 126.64it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 157/1248 [00:01<00:08, 126.16it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▎        | 170/1248 [00:01<00:08, 124.82it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▍        | 183/1248 [00:01<00:08, 125.12it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 196/1248 [00:01<00:08, 124.01it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 209/1248 [00:01<00:08, 121.14it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 222/1248 [00:01<00:08, 121.90it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 236/1248 [00:01<00:08, 124.53it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|█▉        | 249/1248 [00:01<00:07, 125.43it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 263/1248 [00:02<00:07, 126.95it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 276/1248 [00:02<00:07, 122.79it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 289/1248 [00:02<00:07, 123.71it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 302/1248 [00:02<00:07, 124.43it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▌       | 315/1248 [00:02<00:07, 123.87it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 329/1248 [00:02<00:07, 126.58it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 342/1248 [00:02<00:07, 126.72it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 355/1248 [00:02<00:07, 127.16it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 368/1248 [00:02<00:06, 126.98it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███       | 381/1248 [00:03<00:06, 126.31it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 394/1248 [00:03<00:06, 125.90it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 407/1248 [00:03<00:06, 126.39it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▎      | 421/1248 [00:03<00:06, 127.94it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▍      | 434/1248 [00:03<00:06, 127.59it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | 447/1248 [00:03<00:06, 124.76it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 460/1248 [00:03<00:06, 124.99it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 473/1248 [00:03<00:06, 121.07it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  39%|███▉      | 486/1248 [00:03<00:06, 122.91it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  40%|████      | 500/1248 [00:03<00:05, 125.93it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  41%|████      | 513/1248 [00:04<00:05, 127.06it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 527/1248 [00:04<00:05, 128.72it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  43%|████▎     | 540/1248 [00:04<00:05, 121.83it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  44%|████▍     | 553/1248 [00:04<00:05, 123.33it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  45%|████▌     | 566/1248 [00:04<00:05, 124.63it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  46%|████▋     | 579/1248 [00:04<00:05, 124.05it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  48%|████▊     | 593/1248 [00:04<00:05, 127.45it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  49%|████▊     | 606/1248 [00:04<00:05, 120.61it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  50%|████▉     | 619/1248 [00:04<00:05, 120.81it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  51%|█████     | 632/1248 [00:05<00:05, 121.53it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  52%|█████▏    | 645/1248 [00:05<00:05, 118.92it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 657/1248 [00:05<00:05, 118.07it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  54%|█████▎    | 669/1248 [00:05<00:04, 118.10it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  55%|█████▍    | 682/1248 [00:05<00:04, 121.00it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  56%|█████▌    | 695/1248 [00:05<00:04, 117.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  57%|█████▋    | 708/1248 [00:05<00:04, 119.00it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 721/1248 [00:05<00:04, 121.03it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  59%|█████▉    | 735/1248 [00:05<00:04, 124.71it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  60%|██████    | 749/1248 [00:06<00:03, 127.55it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  61%|██████    | 762/1248 [00:06<00:03, 127.38it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  62%|██████▏   | 777/1248 [00:06<00:03, 131.44it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 791/1248 [00:06<00:03, 133.52it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  65%|██████▍   | 806/1248 [00:06<00:03, 135.87it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  66%|██████▌   | 820/1248 [00:06<00:03, 129.62it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  67%|██████▋   | 834/1248 [00:06<00:03, 129.16it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 848/1248 [00:06<00:03, 130.11it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  69%|██████▉   | 862/1248 [00:06<00:02, 131.51it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  70%|███████   | 876/1248 [00:06<00:02, 131.96it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  71%|███████▏  | 890/1248 [00:07<00:02, 131.69it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  72%|███████▏  | 904/1248 [00:07<00:02, 131.35it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 918/1248 [00:07<00:02, 128.69it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  75%|███████▍  | 931/1248 [00:07<00:02, 126.56it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  76%|███████▌  | 944/1248 [00:07<00:02, 126.64it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  77%|███████▋  | 957/1248 [00:07<00:02, 124.36it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  78%|███████▊  | 971/1248 [00:07<00:02, 126.69it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 985/1248 [00:07<00:02, 128.21it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  80%|███████▉  | 998/1248 [00:07<00:02, 124.02it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  81%|████████  | 1011/1248 [00:08<00:01, 123.06it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  82%|████████▏ | 1024/1248 [00:08<00:01, 123.89it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  83%|████████▎ | 1038/1248 [00:08<00:01, 126.04it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 1052/1248 [00:08<00:01, 128.01it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  85%|████████▌ | 1066/1248 [00:08<00:01, 130.44it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  87%|████████▋ | 1080/1248 [00:08<00:01, 130.53it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  88%|████████▊ | 1094/1248 [00:08<00:01, 128.68it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▊ | 1107/1248 [00:08<00:01, 127.11it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|████████▉ | 1120/1248 [00:08<00:01, 124.99it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 1133/1248 [00:09<00:00, 124.17it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 1146/1248 [00:09<00:00, 124.27it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 1159/1248 [00:09<00:00, 124.57it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▍| 1172/1248 [00:09<00:00, 124.80it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 1185/1248 [00:09<00:00, 123.14it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▌| 1199/1248 [00:09<00:00, 125.78it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  97%|█████████▋| 1212/1248 [00:09<00:00, 124.93it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 1225/1248 [00:09<00:00, 122.89it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 1248/1248 [00:09<00:00, 125.60it/s]

# %%
L_dev = applier.apply(dev_df)
# Out:
#   0%|          | 0/328 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 13/328 [00:00<00:02, 128.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 26/328 [00:00<00:02, 126.82it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 38/328 [00:00<00:02, 122.01it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 51/328 [00:00<00:02, 122.02it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 63/328 [00:00<00:02, 121.14it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 76/328 [00:00<00:02, 122.57it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 89/328 [00:00<00:01, 124.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███▏      | 103/328 [00:00<00:01, 127.43it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | 117/328 [00:00<00:01, 128.42it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  40%|███▉      | 130/328 [00:01<00:01, 124.43it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  44%|████▎     | 143/328 [00:01<00:01, 122.34it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  48%|████▊     | 156/328 [00:01<00:01, 124.32it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  52%|█████▏    | 170/328 [00:01<00:01, 126.46it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  56%|█████▌    | 183/328 [00:01<00:01, 127.08it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  60%|█████▉    | 196/328 [00:01<00:01, 126.73it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  64%|██████▎   | 209/328 [00:01<00:00, 127.26it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 222/328 [00:01<00:00, 127.46it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  72%|███████▏  | 235/328 [00:01<00:00, 121.17it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  76%|███████▌  | 248/328 [00:02<00:00, 120.73it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  80%|███████▉  | 261/328 [00:02<00:00, 122.78it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▎ | 274/328 [00:02<00:00, 123.77it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  88%|████████▊ | 288/328 [00:02<00:00, 125.88it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 302/328 [00:02<00:00, 128.63it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▌| 315/328 [00:02<00:00, 124.59it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 328/328 [00:02<00:00, 124.00it/s]

# %%
Y_dev.unique()
# Out:
# array([3, 0, 2, 1])

# %%
from snorkel.labeling import LabelModel
# Train LabelModel.
label_model = LabelModel(cardinality=4, verbose=True)
label_model.fit(L_train, n_epochs=100, seed=123, log_freq=20, l2=0.1, lr=0.01)

# %%
from snorkel.analysis import metric_score

preds_dev = label_model.predict(L_dev)

# %%
Y_dev
# Out:
# 0      3
# 1      0
# 2      3
# 3      0
# 4      3
#       ..
# 323    1
# 324    3
# 325    0
# 326    3
# 327    1
# Name: relation_y, Length: 328, dtype: int64

# %%
acc = metric_score(Y_dev, preds_dev, probs=None, metric="accuracy")

# %%
print(f"LabelModel Accuracy: {acc:.3f}")
# Out:
# LabelModel Accuracy: 0.793

# %%
LFAnalysis(L_dev, lfs).lf_summary(Y_dev.values).head()
# Out:
#                   j      Polarity  Coverage  Overlaps  Conflicts  Correct  \
# crowd             0  [0, 1, 2, 3]  1.000000  0.935976   0.426829      204
# phrases_claas     1  [0, 1, 2, 3]  0.600610  0.600610   0.295732      164
# phrase_closeness  2  [0, 1, 2, 3]  0.935976  0.935976   0.426829      241
#
#                   Incorrect  Emp. Acc.
# crowd                   124   0.621951
# phrases_claas            33   0.832487
# phrase_closeness         66   0.785016

# %%
test_df.relation.value_counts()
# Out:
# Indication: Treatment             127
# Contraindication                  107
# Indication: Symptomatic Relief     49
# Effect                             47
# Name: relation, dtype: int64

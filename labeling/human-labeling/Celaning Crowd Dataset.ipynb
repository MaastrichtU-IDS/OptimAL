# %%
import pandas as pd

# %%
#pd.set_option("display.max_colwidth", 0)

# %%
xml_df = pd.read_csv('../data/unlabeled/XMLProduct_DBID.csv')
xml_df.head()
# Out:
#                                    Label_ID  \
# 0  276a14ff-47c4-404c-aff5-0df4dc4b7192.xml
# 1  276a14ff-47c4-404c-aff5-0df4dc4b7192.xml
# 2  f0e16cc6-966d-4e3c-99c9-29a45d3480dc.xml
# 3  f0e16cc6-966d-4e3c-99c9-29a45d3480dc.xml
# 4  75907d04-0c9d-4a6a-b8c0-7d88ab5ad337.xml
#
#                                  Set_ID Drug_Brand_Name Active_ingredient  \
# 0  ac387aa0-3f04-4865-a913-db6ed6f4fdc5         Marplan     ISOCARBOXAZID
# 1  ac387aa0-3f04-4865-a913-db6ed6f4fdc5         Marplan     ISOCARBOXAZID
# 2  80e736d3-2017-4d68-94b4-38255c3c59c6       Cuprimine     Penicillamine
# 3  80e736d3-2017-4d68-94b4-38255c3c59c6       Cuprimine     Penicillamine
# 4  db8a3ae7-fb5b-47a9-a9f7-f57cd90501c2       Isoniazid         ISONIAZID
#
#       UNII_ID            Section  \
# 0  34237V843T  Contraindications
# 1  34237V843T        Indications
# 2  GNN1DV99GX        Indications
# 3  GNN1DV99GX  Contraindications
# 4  V83O1VOZ8L        Indications
#
#                                                 Text  WordCount    DB_ID  \
# 0  Marplan (isocarboxazid) should not be administ...        908  DB01247
# 1  Marplan is indicated for the treatment of depr...        231  DB01247
# 2  CUPRIMINE is indicated in the treatment of Wil...        897  DB00859
# 3  Except for the treatment of Wilson's disease o...         89  DB00859
# 4  Isoniazid oral solution is recommended for all...        719  DB00951
#
#        Drug_name
# 0  Isocarboxazid
# 1  Isocarboxazid
# 2  Penicillamine
# 3  Penicillamine
# 4      Isoniazid

# %%
xml_df1 = pd.read_csv('../data/unlabeled/XMLProduct_DBID_2.csv')
xml_df1.head()
# Out:
#                                    Label_ID  \
# 0  9fb5dedd-b589-42b7-850a-41dfc5bd8688.xml
# 1  2e8a4140-97a5-4031-a6df-4b2663b5bf83.xml
# 2  e653596f-6792-4e6b-a50f-2d02b5159a8a.xml
# 3  daf75b73-a930-4baa-8b04-703c9f89e2e7.xml
# 4  9fb5dedd-b589-42b7-850a-41dfc5bd8688.xml
#
#                                  Set_ID Drug_Brand_Name Active_ingredient  \
# 0  3fa9bff0-676b-45d9-9d77-a6363c63395f       Omnipaque           Iohexol
# 1  442aed6e-6242-4a96-90aa-d988b62d55e8       Omnipaque           Iohexol
# 2  f9e9d558-064c-4b86-8d96-2f8a678c89f9       OMNIPAQUE           Iohexol
# 3  eee15ebe-d349-4497-acef-6abe7a8247fb       OMNIPAQUE           Iohexol
# 4  3fa9bff0-676b-45d9-9d77-a6363c63395f       Omnipaque           Iohexol
#
#       UNII_ID            Section  \
# 0  4419T9MX03        Indications
# 1  4419T9MX03        Indications
# 2  4419T9MX03        Indications
# 3  4419T9MX03        Indications
# 4  4419T9MX03  Contraindications
#
#                                                 Text  WordCount    DB_ID  \
# 0  OMNIPAQUE 300 is indicated for intrathecal adm...       4207  DB01362
# 1  OMNIPAQUE 300 is indicated for intrathecal adm...       4207  DB01362
# 2  OMNIPAQUE (iohexol) injection is a radiographi...        365  DB01362
# 3  OMNIPAQUE (iohexol) injection is a radiographi...        365  DB01362
# 4  OMNIPAQUE should not be administered to patien...        157  DB01362
#
#   Drug_name
# 0   Iohexol
# 1   Iohexol
# 2   Iohexol
# 3   Iohexol
# 4   Iohexol

# %%
xml_df = xml_df.append(xml_df1)

# %%
xml_df = xml_df.drop_duplicates(subset=['Label_ID','Section'], keep='first')

# %%
crowd = pd.read_csv('../data/crowd/crowd_all.csv')
crowd.head()
# Out:
#    Unnamed: 0     DBID        DOID       disease          drug  \
# 0           0  DB00657  DOID_10763  hypertension  Mecamylamine
# 1           1  DB00401  DOID_10763  hypertension   Nisoldipine
# 2           2  DB00612  DOID_10763  hypertension    Bisoprolol
# 3           3  DB00960  DOID_10763  hypertension      Pindolol
# 4           4  DB00876  DOID_10763  hypertension    Eprosartan
#
#                                    label_id   relation  \
# 0  976f404f-4857-4bad-9a3c-9bf3d5ca9f5b.xml  treatment
# 1  ce733b39-7857-4538-92d6-1c68a4e4eb75.xml  treatment
# 2  c818c38d-ee37-4ceb-b078-611483b4f743.xml  treatment
# 3  d4078b63-30ad-435b-a081-4d90562962b5.xml  treatment
# 4  ab531d28-345b-4113-9fde-00cd63ad5b1a.xml  treatment
#
#                                                 text
# 0  For the management of moderately severe to sev...
# 1  Nisoldipine extended-release tablets are indic...
# 2  Bisoprolol fumarate tablets, USP are indicated...
# 3  Pindolol tablets are indicated in the manageme...
# 4  Eprosartan mesylate tablets are indicated for ...

# %%
print (len(crowd))
crowd = crowd.dropna(subset=['label_id'])
print (len(crowd))
# Out:
# 3457
# 3256

# %%
crowd['Section'] = 'Indications'

# %%
index= crowd.label_id.str.contains('./DailyMedExtracter/prescription/')
crowd.loc[index,'Section']=  'Contraindications'

# %%
crowd.loc[index,'label_id'] = crowd.loc[index,'label_id'].str.replace('../DailyMedExtracter/prescription/temp_xml/','')

# %%
crowd =crowd.rename(columns={'DOID':'DO_ID','DBID':'DB_ID','label_id':'Label_ID'})

# %%
crowd.sample()
# Out:
#       Unnamed: 0    DB_ID       DO_ID                     disease  drug  \
# 2413        2413  DB11823  DOID_11294  arteriovenous malformation  drug
#
#                                       Label_ID relation  \
# 2413  bc3d3756-7b9f-11e8-9668-824e676ff592.xml   relief
#
#                                                    text            Section
# 2413  SPRAVATO is contraindicated in patients with:A...  Contraindications

# %%
match = crowd.merge(xml_df, on=['DB_ID','Label_ID','Section'])

# %%
match.sample()
# Out:
#       Unnamed: 0    DB_ID      DO_ID                            disease  \
# 3036        2769  DB00642  DOID_1205  allergic hypersensitivity disease
#
#             drug                                  Label_ID          relation  \
# 3036  Pemetrexed  55e080d5-d7a8-45b8-9d52-11629342cb7c.xml  contraindication
#
#                                                    text            Section  \
# 3036  ALIMTA is contraindicated in patients with a h...  Contraindications
#
#                                     Set_ID Drug_Brand_Name Active_ingredient  \
# 3036  f5a860f3-37ec-429c-ae04-9c88d7c55c08          Alimta        Pemetrexed
#
#          UNII_ID                                               Text  \
# 3036  04Q9AIZ7NO  ALIMTA is contraindicated in patients with a h...
#
#       WordCount   Drug_name
# 3036         28  Pemetrexed

# %%
len(match)
# Out:
# 3251

# %%
match.head()
# Out:
#    Unnamed: 0    DB_ID       DO_ID                 disease          drug  \
# 0           0  DB00657  DOID_10763            hypertension  Mecamylamine
# 1        1285  DB00657  DOID_10824  malignant hypertension          drug
# 2           1  DB00401  DOID_10763            hypertension   Nisoldipine
# 3           2  DB00612  DOID_10763            hypertension    Bisoprolol
# 4         434  DB00612  DOID_10763            hypertension    Bisoprolol
#
#                                    Label_ID   relation  \
# 0  976f404f-4857-4bad-9a3c-9bf3d5ca9f5b.xml  treatment
# 1  976f404f-4857-4bad-9a3c-9bf3d5ca9f5b.xml  treatment
# 2  ce733b39-7857-4538-92d6-1c68a4e4eb75.xml  treatment
# 3  c818c38d-ee37-4ceb-b078-611483b4f743.xml  treatment
# 4  c818c38d-ee37-4ceb-b078-611483b4f743.xml  treatment
#
#                                                 text      Section  \
# 0  For the management of moderately severe to sev...  Indications
# 1  For the management of moderately severe to sev...  Indications
# 2  Nisoldipine extended-release tablets are indic...  Indications
# 3  Bisoprolol fumarate tablets, USP are indicated...  Indications
# 4  [None, 'Bisoprolol fumarate tablets, USP are i...  Indications
#
#                                  Set_ID      Drug_Brand_Name  \
# 0  c6822ce4-e741-4366-b72a-5f5146354f97              Vecamyl
# 1  c6822ce4-e741-4366-b72a-5f5146354f97              Vecamyl
# 2  a6a8a8ba-3966-4f37-a58b-44d3b05bdc4e          Nisoldipine
# 3  c818c38d-ee37-4ceb-b078-611483b4f743  Bisoprolol Fumarate
# 4  c818c38d-ee37-4ceb-b078-611483b4f743  Bisoprolol Fumarate
#
#   Active_ingredient     UNII_ID  \
# 0      Mecamylamine  6EE945D3OK
# 1      Mecamylamine  6EE945D3OK
# 2       NISOLDIPINE  4I8HAB65SZ
# 3        BISOPROLOL  Y41JS2NL6U
# 4        BISOPROLOL  Y41JS2NL6U
#
#                                                 Text  WordCount     Drug_name
# 0  For the management of moderately severe to sev...         17  Mecamylamine
# 1  For the management of moderately severe to sev...         17  Mecamylamine
# 2  Nisoldipine extended-release tablets are indic...         22   Nisoldipine
# 3  Bisoprolol fumarate tablets, USP are indicated...         23    Bisoprolol
# 4  Bisoprolol fumarate tablets, USP are indicated...         23    Bisoprolol

# %%
crowd = crowd[crowd.relation != 'IDK']

# %%
crowd =crowd.drop_duplicates(subset=['Label_ID','DO_ID'], keep='first')
len(crowd)
# Out:
# 1577

# %%
match = crowd.merge(xml_df, on=['DB_ID','Label_ID','Section'])

# %%
match.rename(columns={'Text':'Context'}, inplace=True)

# %%
len(match)
# Out:
# 1574

# %%
match = match.drop(columns=['drug','text'])

# %%
match.to_csv('../data/crowd/match_crowd_data.csv', index=False)

# %%
match.relation.value_counts()
# Out:
# treatment           917
# relief              272
# contraindication    254
# effect              131
# Name: relation, dtype: int64

# %%
match.head()
# Out:
#    Unnamed: 0    DB_ID       DO_ID                 disease  \
# 0           0  DB00657  DOID_10763            hypertension
# 1        1285  DB00657  DOID_10824  malignant hypertension
# 2           1  DB00401  DOID_10763            hypertension
# 3           2  DB00612  DOID_10763            hypertension
# 4           3  DB00960  DOID_10763            hypertension
#
#                                    Label_ID   relation      Section  \
# 0  976f404f-4857-4bad-9a3c-9bf3d5ca9f5b.xml  treatment  Indications
# 1  976f404f-4857-4bad-9a3c-9bf3d5ca9f5b.xml  treatment  Indications
# 2  ce733b39-7857-4538-92d6-1c68a4e4eb75.xml  treatment  Indications
# 3  c818c38d-ee37-4ceb-b078-611483b4f743.xml  treatment  Indications
# 4  d4078b63-30ad-435b-a081-4d90562962b5.xml  treatment  Indications
#
#                                  Set_ID      Drug_Brand_Name  \
# 0  c6822ce4-e741-4366-b72a-5f5146354f97              Vecamyl
# 1  c6822ce4-e741-4366-b72a-5f5146354f97              Vecamyl
# 2  a6a8a8ba-3966-4f37-a58b-44d3b05bdc4e          Nisoldipine
# 3  c818c38d-ee37-4ceb-b078-611483b4f743  Bisoprolol Fumarate
# 4  b5a5a1e9-ee9b-41b1-b2d5-5f5834b816a7             Pindolol
#
#   Active_ingredient     UNII_ID  \
# 0      Mecamylamine  6EE945D3OK
# 1      Mecamylamine  6EE945D3OK
# 2       NISOLDIPINE  4I8HAB65SZ
# 3        BISOPROLOL  Y41JS2NL6U
# 4          PINDOLOL  BJ4HF6IU1D
#
#                                              Context  WordCount     Drug_name
# 0  For the management of moderately severe to sev...         17  Mecamylamine
# 1  For the management of moderately severe to sev...         17  Mecamylamine
# 2  Nisoldipine extended-release tablets are indic...         22   Nisoldipine
# 3  Bisoprolol fumarate tablets, USP are indicated...         23    Bisoprolol
# 4  Pindolol tablets are indicated in the manageme...         25      Pindolol

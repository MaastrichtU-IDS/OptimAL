# %%
import spacy

from scispacy.abbreviation import AbbreviationDetector

# %%
import pandas as pd

# %%
nlp = spacy.load("en_core_sci_md")

# %%
# Add the abbreviation pipe to the spacy pipeline.
abbreviation_pipe = AbbreviationDetector(nlp)
nlp.add_pipe(abbreviation_pipe)

# %%
doc = nlp("Spinal and bulbar muscular atrophy (SBMA) is an \
           inherited motor neuron disease caused by the expansion \
           of a polyglutamine tract within the androgen receptor (AR). \
           SBMA can be caused by this easily.")

print("Abbreviation", "\t", "Definition")
for abrv in doc._.abbreviations:
	print(f"{abrv} \t ({abrv.start}, {abrv.end}) {abrv._.long_form}")
# Out:
# Abbreviation 	 Definition
# SBMA 	 (6, 7) Spinal and bulbar muscular atrophy
# SBMA 	 (33, 34) Spinal and bulbar muscular atrophy
# AR 	 (29, 30) androgen receptor

# %%
from scispacy.umls_linking import UmlsEntityLinker
linker = UmlsEntityLinker(resolve_abbreviations=True)

nlp.add_pipe(linker)

doc = nlp("Spinal and bulbar muscular atrophy (SBMA) is an \
           inherited motor neuron disease caused by the expansion \
           of a polyglutamine tract within the androgen receptor (AR). \
           SBMA can be caused by this easily.")

# Let's look at a random entity!
entity = doc.ents[1]

print("Name: ", entity)
# Out:
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linking_model/tfidf_vectors_sparse.npz not found in cache, downloading to /tmp/tmpxd70cvx4
# Finished download, copying /tmp/tmpxd70cvx4 to cache at /home/jovyan/.scispacy/datasets/ea855fd121a193f03190a91417c209d4cd97e63d3ce4b456c248ef7c13a4ca77.03518aabd12de2103a27a50302f37c3d87b0f313a8be08b5ec306c9c4334b9b1.tfidf_vectors_sparse.npz
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linking_model/nmslib_index.bin not found in cache, downloading to /tmp/tmp0r9hd1aq
# Finished download, copying /tmp/tmp0r9hd1aq to cache at /home/jovyan/.scispacy/datasets/5f620d1bd549a98c005ed601a73806ea2cd1a86ae6c54bbc62bcb3b452ca2630.27a7ac6807fde6628311ff7d70b86fefc640d0eb70637b544c591722a2c16c2a.nmslib_index.bin
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linking_model/tfidf_vectorizer.joblib not found in cache, downloading to /tmp/tmpc9hp96ta
# Finished download, copying /tmp/tmpc9hp96ta to cache at /home/jovyan/.scispacy/datasets/ffb7a77cdcb3c9233c1e4009c69f38efc13c3619238c508459b5f03fd5f14e4b.9e501319abafbe723d25f1737402d504af6f198fb43b96c85692fa0f9ddc5516.tfidf_vectorizer.joblib
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linking_model/concept_aliases.json not found in cache, downloading to /tmp/tmpzff9_yqk
# Finished download, copying /tmp/tmpzff9_yqk to cache at /home/jovyan/.scispacy/datasets/0f064d20aefab965d5772b2100f8436b3541e7d5313c76cfe5fe070902f149fe.31df9cdb04729860a81bd6c980224ed2bff582586c398d0c9b96ae4e257b9da2.concept_aliases.json
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/umls_2017_aa_cat0129.json not found in cache, downloading to /tmp/tmp4jico444
# Finished download, copying /tmp/tmp4jico444 to cache at /home/jovyan/.scispacy/datasets/13b30cd31cd37c1b52f3df6ea023061172d16e9941660e677fdbb29489af7410.4ad71d86ce780e00cab131c7e3b81acfd2f11dd80ccd61125c8bcde506f2ab8a.umls_2017_aa_cat0129.json
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/umls_semantic_type_tree.tsv not found in cache, downloading to /tmp/tmpga4c7r3o
# Finished download, copying /tmp/tmpga4c7r3o to cache at /home/jovyan/.scispacy/datasets/21a1012c532c3a431d60895c509f5b4d45b0f8966c4178b892190a302b21836f.330707f4efe774134872b9f77f0e3208c1d30f50800b3b39a6b8ec21d9adf1b7.umls_semantic_type_tree.tsv
# Name:  bulbar muscular atrophy

# %%
df = pd.read_csv('/data/output/XMLProduct_DBID.csv')

# %%
df.head()
# Out:
#                                    Label_ID  \
# 0  9fb5dedd-b589-42b7-850a-41dfc5bd8688.xml
# 1  2e8a4140-97a5-4031-a6df-4b2663b5bf83.xml
# 2  e653596f-6792-4e6b-a50f-2d02b5159a8a.xml
# 3  daf75b73-a930-4baa-8b04-703c9f89e2e7.xml
# 4  9fb5dedd-b589-42b7-850a-41dfc5bd8688.xml
#
#                                  Set_ID Drug_Brand_Name Active_ingredient  \
# 0  3fa9bff0-676b-45d9-9d77-a6363c63395f       Omnipaque           Iohexol
# 1  442aed6e-6242-4a96-90aa-d988b62d55e8       Omnipaque           Iohexol
# 2  f9e9d558-064c-4b86-8d96-2f8a678c89f9       OMNIPAQUE           Iohexol
# 3  eee15ebe-d349-4497-acef-6abe7a8247fb       OMNIPAQUE           Iohexol
# 4  3fa9bff0-676b-45d9-9d77-a6363c63395f       Omnipaque           Iohexol
#
#       UNII_ID            Section  \
# 0  4419T9MX03        Indications
# 1  4419T9MX03        Indications
# 2  4419T9MX03        Indications
# 3  4419T9MX03        Indications
# 4  4419T9MX03  Contraindications
#
#                                                 Text  WordCount    DB_ID  \
# 0  OMNIPAQUE 300 is indicated for intrathecal adm...       4207  DB01362
# 1  OMNIPAQUE 300 is indicated for intrathecal adm...       4207  DB01362
# 2  OMNIPAQUE (iohexol) injection is a radiographi...        365  DB01362
# 3  OMNIPAQUE (iohexol) injection is a radiographi...        365  DB01362
# 4  OMNIPAQUE should not be administered to patien...        157  DB01362
#
#   Drug_name
# 0   Iohexol
# 1   Iohexol
# 2   Iohexol
# 3   Iohexol
# 4   Iohexol

# %%
data =[]
for index, row in df.iterrows():
    if index % 100  == 0:
        perc = index/len(df) *100
        print(str(index) + " : "+ str(perc))
    text =row['Text']
    db_id = row["DB_ID"]
    drug_name = row['Active_ingredient']
    drug_brand_name = row["Drug_Brand_Name"]
    label_id = row["Label_ID"]
    set_id = row["Set_ID"]
    section = row['Section']
    doc = nlp(text)
    if len(doc.ents) > 0:
        for entity in doc.ents:
            for umls_ent in entity._.umls_ents:
                
                umls_concept = linker.umls.cui_to_entity[umls_ent[0]]
                if 'T047' in umls_concept.types:
                    #print("Name: ", entity)
                    #print (umls_concept)
                    data.append([label_id, set_id, entity.start_char, entity.end_char, '|'.join(umls_concept.types), umls_concept.canonical_name, 
                                 text, umls_concept.concept_id, db_id, drug_name, drug_brand_name,  section])
# Out:
# 0 : 0.0
# 100 : 0.1584183511818009
# 200 : 0.3168367023636018
# 300 : 0.4752550535454027
# 400 : 0.6336734047272036
# 500 : 0.7920917559090045
# 600 : 0.9505101070908054
# 700 : 1.1089284582726062
# 800 : 1.2673468094544071
# 900 : 1.425765160636208
# 1000 : 1.584183511818009
# 1100 : 1.7426018629998101
# 1200 : 1.9010202141816108
# 1300 : 2.0594385653634117
# 55100 : 87.2885115011723
# 55200 : 87.44692985235409
# 55300 : 87.6053482035359
# 55400 : 87.7637665547177
# 55500 : 87.9221849058995
# 55600 : 88.08060325708131
# 55700 : 88.2390216082631
# 55800 : 88.3974399594449
# 55900 : 88.5558583106267
# 56000 : 88.7142766618085
# 56100 : 88.8726950129903
# 56200 : 89.03111336417211
# 56300 : 89.18953171535391
# 56400 : 89.3479500665357
# 56500 : 89.50636841771751
# 56600 : 89.6647867688993
# 56700 : 89.82320512008111
# 56800 : 89.9816234712629
# 56900 : 90.14004182244472
# 57000 : 90.29846017362651
# 57100 : 90.45687852480832
# 57200 : 90.61529687599011
# 57300 : 90.77371522717192
# 57400 : 90.93213357835371
# 57500 : 91.09055192953551
# 57600 : 91.24897028071732
# 57700 : 91.40738863189912
# 57800 : 91.56580698308092
# 57900 : 91.72422533426273
# 58000 : 91.88264368544452
# 58100 : 92.04106203662631
# 58200 : 92.19948038780812
# 58300 : 92.35789873898993
# 58400 : 92.51631709017173
# 58500 : 92.67473544135353
# 58600 : 92.83315379253533
# 58700 : 92.99157214371712
# 58800 : 93.14999049489893
# 58900 : 93.30840884608072
# 59000 : 93.46682719726253
# 59100 : 93.62524554844434
# 59200 : 93.78366389962613
# 59300 : 93.94208225080793
# 59400 : 94.10050060198974
# 59500 : 94.25891895317153
# 59600 : 94.41733730435334
# 59700 : 94.57575565553513
# 59800 : 94.73417400671694
# 59900 : 94.89259235789874
# 60000 : 95.05101070908054
# 60100 : 95.20942906026234
# 60200 : 95.36784741144415
# 60300 : 95.52626576262594
# 60400 : 95.68468411380773
# 60500 : 95.84310246498956
# 60600 : 96.00152081617135
# 60700 : 96.15993916735314
# 60800 : 96.31835751853495
# 60900 : 96.47677586971675
# 61000 : 96.63519422089854
# 61100 : 96.79361257208035
# 61200 : 96.95203092326216
# 61300 : 97.11044927444395
# 61400 : 97.26886762562576
# 61500 : 97.42728597680755
# 61600 : 97.58570432798935
# 61700 : 97.74412267917116
# 61800 : 97.90254103035295
# 61900 : 98.06095938153476
# 62000 : 98.21937773271657
# 62100 : 98.37779608389836
# 62200 : 98.53621443508015
# 62300 : 98.69463278626196
# 62400 : 98.85305113744376
# 62500 : 99.01146948862556
# 62600 : 99.16988783980736
# 62700 : 99.32830619098917
# 62800 : 99.48672454217096
# 62900 : 99.64514289335277
# 63000 : 99.80356124453456
# 63100 : 99.96197959571637

# %%
columns =['Label_ID','Set_ID', 'From','To','Type', 'Annotation', 'Context','CUI_ID','DB_ID','DrugName', 'Drug_Brand_Name', 'Section' ]
newdf = pd.DataFrame(data, columns= columns)

# %%
newdf.tail()
# Out:
#                                         Label_ID  \
# 912832  544ddf40-c75f-564c-e054-00144ff8d46c.xml
# 912833  314f1ebc-353d-413e-beff-ddf3336e051a.xml
# 912834  dd8b3696-fb4b-481f-b774-508a38f82e1a.xml
# 912835  dd8b3696-fb4b-481f-b774-508a38f82e1a.xml
# 912836  890daf89-0304-41e5-a66c-5109d2333633.xml
#
#                                       Set_ID  From  To  Type  \
# 912832  544ddf40-c75e-564c-e054-00144ff8d46c    18  29  T047
# 912833  4c294bea-5a61-4756-af3c-17ed30f2c0d8    56  69  T047
# 912834  e9ea2ae7-1b98-4034-9fba-8ce2225e0145    15  31  T047
# 912835  e9ea2ae7-1b98-4034-9fba-8ce2225e0145    15  31  T047
# 912836  13148b04-9295-41bb-bd8b-76dbd4ce7c00    12  21  T047
#
#                                      Annotation  \
# 912832                              Cycloplegia
# 912833                   Hair follicle disorder
# 912834                       Dentin Sensitivity
# 912835                  Familial cold urticaria
# 912836  Infection caused by Helicobacter pylori
#
#                                                   Context    CUI_ID    DB_ID  \
# 912832  For mydriasis and cycloplegia for diagnostic p...  C0235238  DB00809
# 912833  This product is for topical application direct...  C0178668  DB00121
# 912834  AZOPT\r\n(r)\r\n \r\nHypersensitivity to any c...  C0011432  DB01194
# 912835  AZOPT\r\n(r)\r\n \r\nHypersensitivity to any c...  C0343068  DB01194
# 912836               PYtest\r\n14\r\nH. pylori\r\n14\r\n2  C0850666  DB09513
#
#             DrugName Drug_Brand_Name
# 912832   TROPICAMIDE     Tropicamide
# 912833        BIOTIN       SPAI-SONS
# 912834  BRINZOLAMIDE          Azopt
# 912835  BRINZOLAMIDE          Azopt
# 912836     Urea C-14          PYtest

# %%
def getDiseaseTerm(row):
   #print (row)
    from_ = row['From']
    to_ = row['To']
    return row['Context'][from_-1:to_]

newdf['DieaseName']= newdf.apply(getDiseaseTerm, axis='columns')

# %%
newdf.tail()
# Out:
#                                         Label_ID  \
# 912832  544ddf40-c75f-564c-e054-00144ff8d46c.xml
# 912833  314f1ebc-353d-413e-beff-ddf3336e051a.xml
# 912834  dd8b3696-fb4b-481f-b774-508a38f82e1a.xml
# 912835  dd8b3696-fb4b-481f-b774-508a38f82e1a.xml
# 912836  890daf89-0304-41e5-a66c-5109d2333633.xml
#
#                                       Set_ID  From  To  Type  \
# 912832  544ddf40-c75e-564c-e054-00144ff8d46c    18  29  T047
# 912833  4c294bea-5a61-4756-af3c-17ed30f2c0d8    56  69  T047
# 912834  e9ea2ae7-1b98-4034-9fba-8ce2225e0145    15  31  T047
# 912835  e9ea2ae7-1b98-4034-9fba-8ce2225e0145    15  31  T047
# 912836  13148b04-9295-41bb-bd8b-76dbd4ce7c00    12  21  T047
#
#                                      Annotation  \
# 912832                              Cycloplegia
# 912833                   Hair follicle disorder
# 912834                       Dentin Sensitivity
# 912835                  Familial cold urticaria
# 912836  Infection caused by Helicobacter pylori
#
#                                                   Context    CUI_ID    DB_ID  \
# 912832  For mydriasis and cycloplegia for diagnostic p...  C0235238  DB00809
# 912833  This product is for topical application direct...  C0178668  DB00121
# 912834  AZOPT\r\n(r)\r\n \r\nHypersensitivity to any c...  C0011432  DB01194
# 912835  AZOPT\r\n(r)\r\n \r\nHypersensitivity to any c...  C0343068  DB01194
# 912836               PYtest\r\n14\r\nH. pylori\r\n14\r\n2  C0850666  DB09513
#
#             DrugName Drug_Brand_Name          DieaseName
# 912832   TROPICAMIDE     Tropicamide         cycloplegia
# 912833        BIOTIN       SPAI-SONS       hair follicle
# 912834  BRINZOLAMIDE          Azopt   \nHypersensitivity
# 912835  BRINZOLAMIDE          Azopt   \nHypersensitivity
# 912836     Urea C-14          PYtest         \nH. pylori

# %%
newdf.to_csv('/data/output/XMLProduct_annotations_scispacy.csv', index=False)

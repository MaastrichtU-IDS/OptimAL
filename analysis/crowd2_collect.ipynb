# %%
import pandas as pd

# %%
# Import that data
data = pd.read_csv('crowd2.csv')

# %%
# Keep the important columns 
data.columns
# Out:
# Index(['HITId', 'HITTypeId', 'Title', 'Description', 'Keywords', 'Reward',
#        'CreationTime', 'MaxAssignments', 'RequesterAnnotation',
#        'AssignmentDurationInSeconds', 'AutoApprovalDelayInSeconds',
#        'Expiration', 'NumberOfSimilarHITs', 'LifetimeInSeconds',
#        'AssignmentId', 'WorkerId', 'AssignmentStatus', 'AcceptTime',
#        'SubmitTime', 'AutoApprovalTime', 'ApprovalTime', 'RejectionTime',
#        'RequesterFeedback', 'WorkTimeInSeconds', 'LifetimeApprovalRate',
#        'Last30DaysApprovalRate', 'Last7DaysApprovalRate', 'Input.No',
#        'Input.Label_ID', 'Input.From', 'Input.To', 'Input.Type',
#        'Input.Annotation', 'Input.Context', 'Input.DO_ID', 'Input.DB_ID',
#        'Input.DrugName', 'Input.Drug_Brand_Name', 'Input.atc_label',
#        'Input.ATC_LEVEL_0', 'Input.DieaseName', 'Input.WordCount',
#        'Input.Set_ID', 'Input.Section', 'Answer.category.label', 'Approve',
#        'Reject'],
#       dtype='object')

# %%
data= data[['WorkerId', 'Input.Annotation','Input.Context','Input.DO_ID', 'Input.DB_ID', 'Input.DrugName', 'Input.Section', 'Answer.category.label' ]]

# %%
# Group by unique data instances and collect ansewers from different workers
df = data.groupby(['Input.Annotation', 'Input.Context', 'Input.DO_ID','Input.DB_ID', 'Input.DrugName','Input.Section'])['Answer.category.label'].apply(list).reset_index(name='merged')

# %%
data['Answer.category.label'].unique()
# Out:
# array(['Indication: treatment', 'Contraindication', 'Effect',
#        'I dont know', 'Indication: Symptomatic relief'], dtype=object)

# %%
#  Create a column with lists that collect the ansers per label in lists like:
#  (treatment, contraindication, relief,effect,IDK)

df['votes'] = 'votes'
for i in range(len(df)):
    df['votes'][i] = [df['merged'][i].count('Indication: treatment'),df['merged'][i].count('Contraindication'),
                       df['merged'][i].count('Indication: Symptomatic relief'),df['merged'][i].count('Effect'), df['merged'][i].count('I dont know')]

# %%
#  Create one column with the inter-aggrement rate between the workers
#  and one other for assigning the majority label
df['aggrement'] = 'agree'
df['label'] = 'label'
for i in range(len(df)):
    df['aggrement'][i] = max(df['votes'][i])/sum(df['votes'][i])
    idx = df['votes'][i].index(max(df['votes'][i]))
    if idx==0:
        df['label'][i] = 'treatment'
    elif idx==1:
        df['label'][i] = 'contraindication'
    elif idx==2:
        df['label'][i] = 'relief'
    elif idx==3:
        df['label'][i] = 'effect'
    elif idx==4:
        df['label'][i] = 'IDK'

# %%
df
# Out:
#                Input.Annotation  \
# 0                    ACROMEGALY
# 1                 ACTINOMYCOSIS
# 2                ACUTE CYSTITIS
# 3    ACUTE LYMPHOCYTIC LEUKEMIA
# 4     ACUTE MAXILLARY SINUSITIS
# ..                          ...
# 825                        YAWS
# 826                        YAWS
# 827  ZOLLINGER-ELLISON SYNDROME
# 828  ZOLLINGER-ELLISON SYNDROME
# 829  ZOLLINGER-ELLISON SYNDROME
#
#                                          Input.Context   Input.DO_ID  \
# 0    Bromocriptine mesylate tablets and capsules ar...     DOID_2449
# 1    Penicillin G Potassium Injection, USP is indic...     DOID_8478
# 2    Nitrofurantoin capsules, USP (monohydrate/macr...    DOID_13148
# 3    Methotrexate is indicated in the treatment of ...     DOID_9952
# 4    Cefpodoxime proxetil is indicated for the trea...     DOID_2050
# ..                                                 ...           ...
# 825  Tetracycline is indicated in the treatment of ...    DOID_10371
# 826  To reduce the development of drug-resistant ba...    DOID_10371
# 827  Esomeprazole magnesium delayed-release capsule...  DOID_0050782
# 828  Rabeprazole sodium delayed-release tablets are...  DOID_0050782
# 829  Ranitidine is indicated in:\r\n 1. Short-term ...  DOID_0050782
#
#     Input.DB_ID  Input.DrugName Input.Section  \
# 0       DB01200   BROMOCRIPTINE    Indication
# 1       DB01053    PENICILLIN G    Indication
# 2       DB00698  NITROFURANTOIN    Indication
# 3       DB00563    METHOTREXATE    Indication
# 4       DB01416     CEFPODOXIME    Indication
# ..          ...             ...           ...
# 825     DB00759    TETRACYCLINE    Indication
# 826     DB01053    PENICILLIN G    Indication
# 827     DB00736    ESOMEPRAZOLE    Indication
# 828     DB01129     RABEPRAZOLE    Indication
# 829     DB00863      RANITIDINE    Indication
#
#                                                 merged            votes  \
# 0    [Indication: treatment, Indication: Symptomati...  [4, 0, 1, 0, 0]
# 1    [Indication: treatment, Indication: Symptomati...  [4, 0, 1, 0, 0]
# 2    [Indication: treatment, Indication: treatment,...  [4, 0, 1, 0, 0]
# 3    [Indication: treatment, Contraindication, Indi...  [3, 1, 0, 0, 0]
# 4    [Indication: treatment, Indication: treatment,...  [4, 0, 0, 0, 0]
# ..                                                 ...              ...
# 825  [Indication: treatment, Contraindication, Indi...  [3, 2, 0, 0, 0]
# 826  [Indication: treatment, Indication: treatment,...  [2, 2, 1, 0, 0]
# 827  [Indication: treatment, Indication: treatment,...  [5, 0, 0, 0, 0]
# 828  [Indication: Symptomatic relief, Indication: t...  [3, 0, 2, 0, 0]
# 829  [Indication: Symptomatic relief, Indication: t...  [4, 0, 1, 0, 0]
#
#     aggrement      label
# 0         0.8  treatment
# 1         0.8  treatment
# 2         0.8  treatment
# 3        0.75  treatment
# 4           1  treatment
# ..        ...        ...
# 825       0.6  treatment
# 826       0.4  treatment
# 827         1  treatment
# 828       0.6  treatment
# 829       0.8  treatment
#
# [830 rows x 10 columns]

# %%
df_aggred = df[df.aggrement > 0.51].reset_index()
df_aggred = df_aggred[df_aggred.label != 'IDK'].reset_index()

# %%
df_aggred = df_aggred[['Input.Annotation','Input.Context', 'Input.DO_ID','Input.DB_ID', 'Input.DrugName', 'Input.Section', 'merged', 'votes', 'aggrement','label']]

# %%
df_aggred
# Out:
#                Input.Annotation  \
# 0                    ACROMEGALY
# 1                 ACTINOMYCOSIS
# 2                ACUTE CYSTITIS
# 3    ACUTE LYMPHOCYTIC LEUKEMIA
# 4     ACUTE MAXILLARY SINUSITIS
# ..                          ...
# 606              VULVOVAGINITIS
# 607                        YAWS
# 608  ZOLLINGER-ELLISON SYNDROME
# 609  ZOLLINGER-ELLISON SYNDROME
# 610  ZOLLINGER-ELLISON SYNDROME
#
#                                          Input.Context   Input.DO_ID  \
# 0    Bromocriptine mesylate tablets and capsules ar...     DOID_2449
# 1    Penicillin G Potassium Injection, USP is indic...     DOID_8478
# 2    Nitrofurantoin capsules, USP (monohydrate/macr...    DOID_13148
# 3    Methotrexate is indicated in the treatment of ...     DOID_9952
# 4    Cefpodoxime proxetil is indicated for the trea...     DOID_2050
# ..                                                 ...           ...
# 606  Enter section text here\r\n Tindamax is a nitr...     DOID_2273
# 607  Tetracycline is indicated in the treatment of ...    DOID_10371
# 608  Esomeprazole magnesium delayed-release capsule...  DOID_0050782
# 609  Rabeprazole sodium delayed-release tablets are...  DOID_0050782
# 610  Ranitidine is indicated in:\r\n 1. Short-term ...  DOID_0050782
#
#     Input.DB_ID  Input.DrugName Input.Section  \
# 0       DB01200   BROMOCRIPTINE    Indication
# 1       DB01053    PENICILLIN G    Indication
# 2       DB00698  NITROFURANTOIN    Indication
# 3       DB00563    METHOTREXATE    Indication
# 4       DB01416     CEFPODOXIME    Indication
# ..          ...             ...           ...
# 606     DB00911      TINIDAZOLE    Indication
# 607     DB00759    TETRACYCLINE    Indication
# 608     DB00736    ESOMEPRAZOLE    Indication
# 609     DB01129     RABEPRAZOLE    Indication
# 610     DB00863      RANITIDINE    Indication
#
#                                                 merged            votes  \
# 0    [Indication: treatment, Indication: Symptomati...  [4, 0, 1, 0, 0]
# 1    [Indication: treatment, Indication: Symptomati...  [4, 0, 1, 0, 0]
# 2    [Indication: treatment, Indication: treatment,...  [4, 0, 1, 0, 0]
# 3    [Indication: treatment, Contraindication, Indi...  [3, 1, 0, 0, 0]
# 4    [Indication: treatment, Indication: treatment,...  [4, 0, 0, 0, 0]
# ..                                                 ...              ...
# 606  [Effect, Indication: treatment, Indication: tr...  [4, 0, 0, 1, 0]
# 607  [Indication: treatment, Contraindication, Indi...  [3, 2, 0, 0, 0]
# 608  [Indication: treatment, Indication: treatment,...  [5, 0, 0, 0, 0]
# 609  [Indication: Symptomatic relief, Indication: t...  [3, 0, 2, 0, 0]
# 610  [Indication: Symptomatic relief, Indication: t...  [4, 0, 1, 0, 0]
#
#     aggrement      label
# 0         0.8  treatment
# 1         0.8  treatment
# 2         0.8  treatment
# 3        0.75  treatment
# 4           1  treatment
# ..        ...        ...
# 606       0.8  treatment
# 607       0.6  treatment
# 608         1  treatment
# 609       0.6  treatment
# 610       0.8  treatment
#
# [611 rows x 10 columns]

# %%
df_aggred.to_csv('crowd_2nd.csv')

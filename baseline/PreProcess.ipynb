# %%
# Packages needed

import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
import numpy as np
import pandas as pd
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kristi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/kristi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Import data set

data = pd.read_csv('data.csv')
text =  data['text']
labels = data['relation_type']
disease = data['disease_name']
drug = data['drug_name']

# %%
# Functions for cleaning 

def remove (x):
    no_punct = ""
    for char in x:
            if char in '''qwertyuiopasdfghjklzxcvbnmQWERTYUIOPASDFGHJKLZXCVBNM ''':
                    no_punct = no_punct + char
    return no_punct

def remove_non_digits (x):
    no_punct = ""
    for char in x:
            if char in '''1234567890qwertyuiopasdfghjklzxcvbnmQWERTYUIOPASDFGHJKLZXCVBNM ''':
                    no_punct = no_punct + char
    return no_punct

def lower (x):
    return x.lower()

# %% [markdown]
# # Preprocess

# %%
# --- Encode Labels ---

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(labels)
le.classes_
labels_en = le.transform(labels)

# %%
# --- Clean Drug and Disease ---

#Disease
disease_new_1 = disease.apply(remove_non_digits)
disease_new_2 = disease_new_1.apply(lower)
disease_new = disease_new_2.apply(word_tokenize)


#Drug
drug_new_1 = drug.apply(remove_non_digits)
drug_new_2 = drug_new_1.apply(lower)
drug_new = drug_new_2.apply(word_tokenize)

# %%
# --- Remove stop words and clean Text ---

#lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))
corpus_prep= []
text_new=[]


for i in range(len(text)):
    text_new.append(remove(text[i]))
    
for i in range (len(text_new)):
    sentence = text_new[i].lower()
    word_tokens = word_tokenize(sentence)
    filtered_sentence = [w for w in word_tokens if not w in stop_words]
    filtered_sentence = []
    
    for w in word_tokens:
        if w not in stop_words and len(w)>2:
            filtered_sentence.append(w)
    corpus_prep.append(filtered_sentence)

# %%
# New Data Frame with tokenized and clean sentences

d = {'label': labels_en, 'text': corpus_prep, 'disease': disease_new, 'drug':drug_new}
df = pd.DataFrame(data=d)

# %% [markdown]
# # Embeddings

# %% [markdown]
# ## TFIDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()

# %%
seq = (text_new[0], disease[0], drug[0])

for i in range(len(text_new)):
    seq = seq + (text_new[i], disease[i], drug[i])
rows = " ".join(seq)

# %%
for i in range(len(text_new)):
    rows = rows + text_new[i] + drug[i] +disease[i]

# %%
response = tfidf.fit_transform([rows])

# %% [markdown]
# ## Word2Vec

# %%
# Word2Vec
from gensim.models import Word2Vec

# Encode the labels 
y = labels_en

# Create the total corpus where the word2vec is going to be trained 
corpus_final = corpus_prep + disease_new + drug_new

# %% [raw]
# # X = []
# for i in range(len(corpus_prep)):
#     total = [corpus_prep[i], diseases[i], drugs[i]]
#     X.append(total)

# %%
# Train the model of vector representation
model = Word2Vec(sentences = corpus_final, size = 100, sg = 1, window = 3, 
                 min_count = 1, iter = 10, workers = 3)

# %%
# Create a copy of the initial df so that we work on that 
df_en = df.copy()

# %%
# For each instance/sentence compute the average of all the words 

def avg_vector(list_of_words):
    vector_sum = model.wv[list_of_words[0]]
    for i in range(1,len(list_of_words)):
        vector_sum = vector_sum +  model.wv[list_of_words[i]]
    return vector_sum/len(list_of_words)


#def avg_vector_test():
    #text = ['nisoldipine', 'extendedrelease', 'tablets', 'indicated', 'treatment', 'hypertension', 'may', 'used', 'alone', 'combination', 'antihypertensive', 'agents']
    #print (text)
    #print (avg_vector(text))

# %%
# 
df_en['text'] = df_en['text'].apply(avg_vector)
df_en['disease'] = df_en['disease'].apply(avg_vector)
df_en['drug'] = df_en['drug'].apply(avg_vector)

# %%
arr1 =  df_en['text'].values
arr2 = np.array( df_en['drug'])
arr3 = np.array( df_en['disease'] )

# %%
X_arr1 = np.array(list(map(np.array, arr1)))
X_arr2 = np.array(list(map(np.array, arr2)))
X_arr3 = np.array(list(map(np.array, arr3)))

# The instances and the labels
X_features =np.hstack((X_arr1, X_arr2, X_arr3))
y = list(y)

# %%
# Check the shape, we have 1322 data points of 3 different features (text, drug, disease) each having a shape of 100
# so we should have a total ok (1322,300)
X_features.shape
# Out:
# (1322, 300)

# %%
y = np.array(y)

# %%
d1 = {'feature': X_features, 'class': y}
df1 = pd.DataFrame(data=d1)
embedded = df1.to_csv('embedded.csv')

# %% [markdown]
# # Baseline Models

# %% [markdown]
# ## Split

# %%
#from sklearn.model_selection import train_test_split

# %%
#X_train, X_test, y_train, y_test = train_test_split(X_features, y, test_size=0.2)

# %% [markdown]
# ## Scaling

# %%
# Scaling

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import cross_val_score, GridSearchCV

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## SVM

# %%
params_grid = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'C': [1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000]}]

# %%
from sklearn import svm 
from sklearn.svm import SVC

from sklearn.model_selection import StratifiedKFold, KFold
from pycm import *

skf = StratifiedKFold(n_splits=5)
#kf = KFold(n_splits=2)
X = scaler.fit_transform(X_features)
#X = X_features

all_cm = []

for train_index, test_index in skf.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    print (len(X_train), len(X_test))
    
    #svm_model = GridSearchCV(SVC(), params_grid, cv=5)
    model = svm.SVC(gamma= 'scale')
    model.fit(X_train, y_train)
    
    
    y_pred = model.predict(X_test)
    
    cm = ConfusionMatrix(y_test, y_pred)
    print(cm)
    all_cm.append(c)

# %%
# print('Best score for training data:', svm_model.best_score_,"\n") 

# View the best parameters for the model found using grid search
# print('Best C:',svm_model.best_estimator_.C,"\n") 
# print('Best Kernel:',svm_model.best_estimator_.kernel,"\n")
# print('Best Gamma:',svm_model.best_estimator_.gamma,"\n")


#final_model = svm_model.best_estimator_
#y_pred = final_model.predict(X_test_scaled)
#y_pred_label = list(le.inverse_transform(y_pred))

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from pycm import *

# %%
skf = StratifiedKFold(n_splits=5)
dt_model = DecisionTreeClassifier()

X = scaler.fit_transform(X_features)
#X = X_features
all_cm = []


for train_index, test_index in skf.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    print (len(X_train), len(X_test))
    
    dt_model = DecisionTreeClassifier()
    dt_model = dt_model.fit(X_train, y_train)
    
    
    y_pred = dt_model.predict(X_test)
    
    cm = ConfusionMatrix(y_test, y_pred)
    print(cm)
    all_cm.append(c)
# Out:
# 1057 265
# Predict   0         1         2         3
# Actual
# 0         16        0         0         0
#
# 1         0         12        0         0
#
# 2         0         0         34        0
#
# 3         0         0         0         203
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (1.0,1.0)
# ACC Macro                                                         1.0
# AUNP                                                              1.0
# AUNU                                                              1.0
# Bennett S                                                         1.0
# CBA                                                               1.0
# Chi-Squared                                                       795.0
# Chi-Squared DF                                                    9
# Conditional Entropy                                               -0.0
# Cramer V                                                          1.0
# Cross Entropy                                                     1.12133
# F1 Macro                                                          1.0
# F1 Micro                                                          1.0
# Gwet AC1                                                          1.0
# Hamming Loss                                                      0.0
# Joint Entropy                                                     1.12133
# KL Divergence                                                     0.0
# Kappa                                                             1.0
# Kappa 95% CI                                                      (1.0,1.0)
# Kappa No Prevalence                                               1.0
# Kappa Standard Error                                              0.0
# Kappa Unbiased                                                    1.0
# Lambda A                                                          1.0
# Lambda B                                                          1.0
# Mutual Information                                                1.12133
# NIR                                                               0.76604
# Overall ACC                                                       1.0
# Overall CEN                                                       0.0
# Overall J                                                         (4.0,1.0)
# Overall MCC                                                       1.0
# Overall MCEN                                                      0.0
# Overall RACC                                                      0.60897
# Overall RACCU                                                     0.60897
# P-Value                                                           0.0
# PPV Macro                                                         1.0
# PPV Micro                                                         1.0
# Pearson C                                                         0.86603
# Phi-Squared                                                       3.0
# RCI                                                               1.0
# RR                                                                66.25
# Reference Entropy                                                 1.12133
# Response Entropy                                                  1.12133
# SOA1(Landis & Koch)                                               Almost Perfect
# SOA2(Fleiss)                                                      Excellent
# SOA3(Altman)                                                      Very Good
# SOA4(Cicchetti)                                                   Excellent
# SOA5(Cramer)                                                      Very Strong
# SOA6(Matthews)                                                    Very Strong
# Scott PI                                                          1.0
# Standard Error                                                    0.0
# TPR Macro                                                         1.0
# TPR Micro                                                         1.0
# Zero-one Loss                                                     0
#
# Class Statistics :
#
# Classes                                                           0             1             2             3
# ACC(Accuracy)                                                     1.0           1.0           1.0           1.0
# AGF(Adjusted F-score)                                             1.0           1.0           1.0           1.0
# AGM(Adjusted geometric mean)                                      1.0           1.0           1.0           1.0
# AM(Difference between automatic and manual classification)        0             0             0             0
# AUC(Area under the ROC curve)                                     1.0           1.0           1.0           1.0
# AUCI(AUC value interpretation)                                    Excellent     Excellent     Excellent     Excellent
# AUPR(Area under the PR curve)                                     1.0           1.0           1.0           1.0
# BCD(Bray-Curtis dissimilarity)                                    0.0           0.0           0.0           0.0
# BM(Informedness or bookmaker informedness)                        1.0           1.0           1.0           1.0
# CEN(Confusion entropy)                                            0             0             0             0
# DOR(Diagnostic odds ratio)                                        None          None          None          None
# DP(Discriminant power)                                            None          None          None          None
# DPI(Discriminant power interpretation)                            None          None          None          None
# ERR(Error rate)                                                   0.0           0.0           0.0           0.0
# F0.5(F0.5 score)                                                  1.0           1.0           1.0           1.0
# F1(F1 score - harmonic mean of precision and sensitivity)         1.0           1.0           1.0           1.0
# F2(F2 score)                                                      1.0           1.0           1.0           1.0
# FDR(False discovery rate)                                         0.0           0.0           0.0           0.0
# FN(False negative/miss/type 2 error)                              0             0             0             0
# FNR(Miss rate or false negative rate)                             0.0           0.0           0.0           0.0
# FOR(False omission rate)                                          0.0           0.0           0.0           0.0
# FP(False positive/type 1 error/false alarm)                       0             0             0             0
# FPR(Fall-out or false positive rate)                              0.0           0.0           0.0           0.0
# G(G-measure geometric mean of precision and sensitivity)          1.0           1.0           1.0           1.0
# GI(Gini index)                                                    1.0           1.0           1.0           1.0
# GM(G-mean geometric mean of specificity and sensitivity)          1.0           1.0           1.0           1.0
# IBA(Index of balanced accuracy)                                   1.0           1.0           1.0           1.0
# IS(Information score)                                             4.04985       4.46489       2.96239       0.38451
# J(Jaccard index)                                                  1.0           1.0           1.0           1.0
# LS(Lift score)                                                    16.5625       22.08333      7.79412       1.30542
# MCC(Matthews correlation coefficient)                             1.0           1.0           1.0           1.0
# MCCI(Matthews correlation coefficient interpretation)             Very Strong   Very Strong   Very Strong   Very Strong
# MCEN(Modified confusion entropy)                                  0             0             0             0
# MK(Markedness)                                                    1.0           1.0           1.0           1.0
# N(Condition negative)                                             249           253           231           62
# NLR(Negative likelihood ratio)                                    0.0           0.0           0.0           0.0
# NLRI(Negative likelihood ratio interpretation)                    Good          Good          Good          Good
# NPV(Negative predictive value)                                    1.0           1.0           1.0           1.0
# OC(Overlap coefficient)                                           1.0           1.0           1.0           1.0
# OOC(Otsuka-Ochiai coefficient)                                    1.0           1.0           1.0           1.0
# OP(Optimized precision)                                           1.0           1.0           1.0           1.0
# P(Condition positive or support)                                  16            12            34            203
# PLR(Positive likelihood ratio)                                    None          None          None          None
# PLRI(Positive likelihood ratio interpretation)                    None          None          None          None
# POP(Population)                                                   265           265           265           265
# PPV(Precision or positive predictive value)                       1.0           1.0           1.0           1.0
# PRE(Prevalence)                                                   0.06038       0.04528       0.1283        0.76604
# Q(Yule Q - coefficient of colligation)                            None          None          None          None
# RACC(Random accuracy)                                             0.00365       0.00205       0.01646       0.58681
# RACCU(Random accuracy unbiased)                                   0.00365       0.00205       0.01646       0.58681
# TN(True negative/correct rejection)                               249           253           231           62
# TNR(Specificity or true negative rate)                            1.0           1.0           1.0           1.0
# TON(Test outcome negative)                                        249           253           231           62
# TOP(Test outcome positive)                                        16            12            34            203
# TP(True positive/hit)                                             16            12            34            203
# TPR(Sensitivity, recall, hit rate, or true positive rate)         1.0           1.0           1.0           1.0
# Y(Youden index)                                                   1.0           1.0           1.0           1.0
# dInd(Distance index)                                              0.0           0.0           0.0           0.0
# sInd(Similarity index)                                            1.0           1.0           1.0           1.0
#
# 1057 265
# Predict   0         1         2         3
# Actual
# 0         16        0         0         0
#
# 1         0         12        0         0
#
# 2         0         0         34        0
#
# 3         0         0         0         203
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (1.0,1.0)
# ACC Macro                                                         1.0
# AUNP                                                              1.0
# AUNU                                                              1.0
# Bennett S                                                         1.0
# CBA                                                               1.0
# Chi-Squared                                                       795.0
# Chi-Squared DF                                                    9
# Conditional Entropy                                               -0.0
# Cramer V                                                          1.0
# Cross Entropy                                                     1.12133
# F1 Macro                                                          1.0
# F1 Micro                                                          1.0
# Gwet AC1                                                          1.0
# Hamming Loss                                                      0.0
# Joint Entropy                                                     1.12133
# KL Divergence                                                     0.0
# Kappa                                                             1.0
# Kappa 95% CI                                                      (1.0,1.0)
# Kappa No Prevalence                                               1.0
# Kappa Standard Error                                              0.0
# Kappa Unbiased                                                    1.0
# Lambda A                                                          1.0
# Lambda B                                                          1.0
# Mutual Information                                                1.12133
# NIR                                                               0.76604
# Overall ACC                                                       1.0
# Overall CEN                                                       0.0
# Overall J                                                         (4.0,1.0)
# Overall MCC                                                       1.0
# Overall MCEN                                                      0.0
# Overall RACC                                                      0.60897
# Overall RACCU                                                     0.60897
# P-Value                                                           0.0
# PPV Macro                                                         1.0
# PPV Micro                                                         1.0
# Pearson C                                                         0.86603
# Phi-Squared                                                       3.0
# RCI                                                               1.0
# RR                                                                66.25
# Reference Entropy                                                 1.12133
# Response Entropy                                                  1.12133
# SOA1(Landis & Koch)                                               Almost Perfect
# SOA2(Fleiss)                                                      Excellent
# SOA3(Altman)                                                      Very Good
# SOA4(Cicchetti)                                                   Excellent
# SOA5(Cramer)                                                      Very Strong
# SOA6(Matthews)                                                    Very Strong
# Scott PI                                                          1.0
# Standard Error                                                    0.0
# TPR Macro                                                         1.0
# TPR Micro                                                         1.0
# Zero-one Loss                                                     0
#
# Class Statistics :
#
# Classes                                                           0             1             2             3
# ACC(Accuracy)                                                     1.0           1.0           1.0           1.0
# AGF(Adjusted F-score)                                             1.0           1.0           1.0           1.0
# AGM(Adjusted geometric mean)                                      1.0           1.0           1.0           1.0
# AM(Difference between automatic and manual classification)        0             0             0             0
# AUC(Area under the ROC curve)                                     1.0           1.0           1.0           1.0
# AUCI(AUC value interpretation)                                    Excellent     Excellent     Excellent     Excellent
# AUPR(Area under the PR curve)                                     1.0           1.0           1.0           1.0
# BCD(Bray-Curtis dissimilarity)                                    0.0           0.0           0.0           0.0
# BM(Informedness or bookmaker informedness)                        1.0           1.0           1.0           1.0
# CEN(Confusion entropy)                                            0             0             0             0
# DOR(Diagnostic odds ratio)                                        None          None          None          None
# DP(Discriminant power)                                            None          None          None          None
# DPI(Discriminant power interpretation)                            None          None          None          None
# ERR(Error rate)                                                   0.0           0.0           0.0           0.0
# F0.5(F0.5 score)                                                  1.0           1.0           1.0           1.0
# F1(F1 score - harmonic mean of precision and sensitivity)         1.0           1.0           1.0           1.0
# F2(F2 score)                                                      1.0           1.0           1.0           1.0
# FDR(False discovery rate)                                         0.0           0.0           0.0           0.0
# FN(False negative/miss/type 2 error)                              0             0             0             0
# FNR(Miss rate or false negative rate)                             0.0           0.0           0.0           0.0
# FOR(False omission rate)                                          0.0           0.0           0.0           0.0
# FP(False positive/type 1 error/false alarm)                       0             0             0             0
# FPR(Fall-out or false positive rate)                              0.0           0.0           0.0           0.0
# G(G-measure geometric mean of precision and sensitivity)          1.0           1.0           1.0           1.0
# GI(Gini index)                                                    1.0           1.0           1.0           1.0
# GM(G-mean geometric mean of specificity and sensitivity)          1.0           1.0           1.0           1.0
# IBA(Index of balanced accuracy)                                   1.0           1.0           1.0           1.0
# IS(Information score)                                             4.04985       4.46489       2.96239       0.38451
# J(Jaccard index)                                                  1.0           1.0           1.0           1.0
# LS(Lift score)                                                    16.5625       22.08333      7.79412       1.30542
# MCC(Matthews correlation coefficient)                             1.0           1.0           1.0           1.0
# MCCI(Matthews correlation coefficient interpretation)             Very Strong   Very Strong   Very Strong   Very Strong
# MCEN(Modified confusion entropy)                                  0             0             0             0
# MK(Markedness)                                                    1.0           1.0           1.0           1.0
# N(Condition negative)                                             249           253           231           62
# NLR(Negative likelihood ratio)                                    0.0           0.0           0.0           0.0
# NLRI(Negative likelihood ratio interpretation)                    Good          Good          Good          Good
# NPV(Negative predictive value)                                    1.0           1.0           1.0           1.0
# OC(Overlap coefficient)                                           1.0           1.0           1.0           1.0
# OOC(Otsuka-Ochiai coefficient)                                    1.0           1.0           1.0           1.0
# OP(Optimized precision)                                           1.0           1.0           1.0           1.0
# P(Condition positive or support)                                  16            12            34            203
# PLR(Positive likelihood ratio)                                    None          None          None          None
# PLRI(Positive likelihood ratio interpretation)                    None          None          None          None
# POP(Population)                                                   265           265           265           265
# PPV(Precision or positive predictive value)                       1.0           1.0           1.0           1.0
# PRE(Prevalence)                                                   0.06038       0.04528       0.1283        0.76604
# Q(Yule Q - coefficient of colligation)                            None          None          None          None
# RACC(Random accuracy)                                             0.00365       0.00205       0.01646       0.58681
# RACCU(Random accuracy unbiased)                                   0.00365       0.00205       0.01646       0.58681
# TN(True negative/correct rejection)                               249           253           231           62
# TNR(Specificity or true negative rate)                            1.0           1.0           1.0           1.0
# TON(Test outcome negative)                                        249           253           231           62
# TOP(Test outcome positive)                                        16            12            34            203
# TP(True positive/hit)                                             16            12            34            203
# TPR(Sensitivity, recall, hit rate, or true positive rate)         1.0           1.0           1.0           1.0
# Y(Youden index)                                                   1.0           1.0           1.0           1.0
# dInd(Distance index)                                              0.0           0.0           0.0           0.0
# sInd(Similarity index)                                            1.0           1.0           1.0           1.0
#
# 1058 264
# Predict   0         1         2         3
# Actual
# 0         16        0         0         0
#
# 1         0         12        0         0
#
# 2         0         0         34        0
#
# 3         0         0         0         202
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (1.0,1.0)
# ACC Macro                                                         1.0
# AUNP                                                              1.0
# AUNU                                                              1.0
# Bennett S                                                         1.0
# CBA                                                               1.0
# Chi-Squared                                                       792.0
# Chi-Squared DF                                                    9
# Conditional Entropy                                               -0.0
# Cramer V                                                          1.0
# Cross Entropy                                                     1.12412
# F1 Macro                                                          1.0
# F1 Micro                                                          1.0
# Gwet AC1                                                          1.0
# Hamming Loss                                                      0.0
# Joint Entropy                                                     1.12412
# KL Divergence                                                     0.0
# Kappa                                                             1.0
# Kappa 95% CI                                                      (1.0,1.0)
# Kappa No Prevalence                                               1.0
# Kappa Standard Error                                              0.0
# Kappa Unbiased                                                    1.0
# Lambda A                                                          1.0
# Lambda B                                                          1.0
# Mutual Information                                                1.12412
# NIR                                                               0.76515
# Overall ACC                                                       1.0
# Overall CEN                                                       0.0
# Overall J                                                         (4.0,1.0)
# Overall MCC                                                       1.0
# Overall MCEN                                                      0.0
# Overall RACC                                                      0.60778
# Overall RACCU                                                     0.60778
# P-Value                                                           -0.0
# PPV Macro                                                         1.0
# PPV Micro                                                         1.0
# Pearson C                                                         0.86603
# Phi-Squared                                                       3.0
# RCI                                                               1.0
# RR                                                                66.0
# Reference Entropy                                                 1.12412
# Response Entropy                                                  1.12412
# SOA1(Landis & Koch)                                               Almost Perfect
# SOA2(Fleiss)                                                      Excellent
# SOA3(Altman)                                                      Very Good
# SOA4(Cicchetti)                                                   Excellent
# SOA5(Cramer)                                                      Very Strong
# SOA6(Matthews)                                                    Very Strong
# Scott PI                                                          1.0
# Standard Error                                                    0.0
# TPR Macro                                                         1.0
# TPR Micro                                                         1.0
# Zero-one Loss                                                     0
#
# Class Statistics :
#
# Classes                                                           0             1             2             3
# ACC(Accuracy)                                                     1.0           1.0           1.0           1.0
# AGF(Adjusted F-score)                                             1.0           1.0           1.0           1.0
# AGM(Adjusted geometric mean)                                      1.0           1.0           1.0           1.0
# AM(Difference between automatic and manual classification)        0             0             0             0
# AUC(Area under the ROC curve)                                     1.0           1.0           1.0           1.0
# AUCI(AUC value interpretation)                                    Excellent     Excellent     Excellent     Excellent
# AUPR(Area under the PR curve)                                     1.0           1.0           1.0           1.0
# BCD(Bray-Curtis dissimilarity)                                    0.0           0.0           0.0           0.0
# BM(Informedness or bookmaker informedness)                        1.0           1.0           1.0           1.0
# CEN(Confusion entropy)                                            0             0             0             0
# DOR(Diagnostic odds ratio)                                        None          None          None          None
# DP(Discriminant power)                                            None          None          None          None
# DPI(Discriminant power interpretation)                            None          None          None          None
# ERR(Error rate)                                                   0.0           0.0           0.0           0.0
# F0.5(F0.5 score)                                                  1.0           1.0           1.0           1.0
# F1(F1 score - harmonic mean of precision and sensitivity)         1.0           1.0           1.0           1.0
# F2(F2 score)                                                      1.0           1.0           1.0           1.0
# FDR(False discovery rate)                                         0.0           0.0           0.0           0.0
# FN(False negative/miss/type 2 error)                              0             0             0             0
# FNR(Miss rate or false negative rate)                             0.0           0.0           0.0           0.0
# FOR(False omission rate)                                          0.0           0.0           0.0           0.0
# FP(False positive/type 1 error/false alarm)                       0             0             0             0
# FPR(Fall-out or false positive rate)                              0.0           0.0           0.0           0.0
# G(G-measure geometric mean of precision and sensitivity)          1.0           1.0           1.0           1.0
# GI(Gini index)                                                    1.0           1.0           1.0           1.0
# GM(G-mean geometric mean of specificity and sensitivity)          1.0           1.0           1.0           1.0
# IBA(Index of balanced accuracy)                                   1.0           1.0           1.0           1.0
# IS(Information score)                                             4.04439       4.45943       2.95693       0.38618
# J(Jaccard index)                                                  1.0           1.0           1.0           1.0
# LS(Lift score)                                                    16.5          22.0          7.76471       1.30693
# MCC(Matthews correlation coefficient)                             1.0           1.0           1.0           1.0
# MCCI(Matthews correlation coefficient interpretation)             Very Strong   Very Strong   Very Strong   Very Strong
# MCEN(Modified confusion entropy)                                  0             0             0             0
# MK(Markedness)                                                    1.0           1.0           1.0           1.0
# N(Condition negative)                                             248           252           230           62
# NLR(Negative likelihood ratio)                                    0.0           0.0           0.0           0.0
# NLRI(Negative likelihood ratio interpretation)                    Good          Good          Good          Good
# NPV(Negative predictive value)                                    1.0           1.0           1.0           1.0
# OC(Overlap coefficient)                                           1.0           1.0           1.0           1.0
# OOC(Otsuka-Ochiai coefficient)                                    1.0           1.0           1.0           1.0
# OP(Optimized precision)                                           1.0           1.0           1.0           1.0
# P(Condition positive or support)                                  16            12            34            202
# PLR(Positive likelihood ratio)                                    None          None          None          None
# PLRI(Positive likelihood ratio interpretation)                    None          None          None          None
# POP(Population)                                                   264           264           264           264
# PPV(Precision or positive predictive value)                       1.0           1.0           1.0           1.0
# PRE(Prevalence)                                                   0.06061       0.04545       0.12879       0.76515
# Q(Yule Q - coefficient of colligation)                            None          None          None          None
# RACC(Random accuracy)                                             0.00367       0.00207       0.01659       0.58546
# RACCU(Random accuracy unbiased)                                   0.00367       0.00207       0.01659       0.58546
# TN(True negative/correct rejection)                               248           252           230           62
# TNR(Specificity or true negative rate)                            1.0           1.0           1.0           1.0
# TON(Test outcome negative)                                        248           252           230           62
# TOP(Test outcome positive)                                        16            12            34            202
# TP(True positive/hit)                                             16            12            34            202
# TPR(Sensitivity, recall, hit rate, or true positive rate)         1.0           1.0           1.0           1.0
# Y(Youden index)                                                   1.0           1.0           1.0           1.0
# dInd(Distance index)                                              0.0           0.0           0.0           0.0
# sInd(Similarity index)                                            1.0           1.0           1.0           1.0
#
# 1058 264
# Predict   0         1         2         3
# Actual
# 0         16        0         0         0
#
# 1         0         12        0         0
#
# 2         0         0         34        0
#
# 3         0         0         0         202
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (1.0,1.0)
# ACC Macro                                                         1.0
# AUNP                                                              1.0
# AUNU                                                              1.0
# Bennett S                                                         1.0
# CBA                                                               1.0
# Chi-Squared                                                       792.0
# Chi-Squared DF                                                    9
# Conditional Entropy                                               -0.0
# Cramer V                                                          1.0
# Cross Entropy                                                     1.12412
# F1 Macro                                                          1.0
# F1 Micro                                                          1.0
# Gwet AC1                                                          1.0
# Hamming Loss                                                      0.0
# Joint Entropy                                                     1.12412
# KL Divergence                                                     0.0
# Kappa                                                             1.0
# Kappa 95% CI                                                      (1.0,1.0)
# Kappa No Prevalence                                               1.0
# Kappa Standard Error                                              0.0
# Kappa Unbiased                                                    1.0
# Lambda A                                                          1.0
# Lambda B                                                          1.0
# Mutual Information                                                1.12412
# NIR                                                               0.76515
# Overall ACC                                                       1.0
# Overall CEN                                                       0.0
# Overall J                                                         (4.0,1.0)
# Overall MCC                                                       1.0
# Overall MCEN                                                      0.0
# Overall RACC                                                      0.60778
# Overall RACCU                                                     0.60778
# P-Value                                                           -0.0
# PPV Macro                                                         1.0
# PPV Micro                                                         1.0
# Pearson C                                                         0.86603
# Phi-Squared                                                       3.0
# RCI                                                               1.0
# RR                                                                66.0
# Reference Entropy                                                 1.12412
# Response Entropy                                                  1.12412
# SOA1(Landis & Koch)                                               Almost Perfect
# SOA2(Fleiss)                                                      Excellent
# SOA3(Altman)                                                      Very Good
# SOA4(Cicchetti)                                                   Excellent
# SOA5(Cramer)                                                      Very Strong
# SOA6(Matthews)                                                    Very Strong
# Scott PI                                                          1.0
# Standard Error                                                    0.0
# TPR Macro                                                         1.0
# TPR Micro                                                         1.0
# Zero-one Loss                                                     0
#
# Class Statistics :
#
# Classes                                                           0             1             2             3
# ACC(Accuracy)                                                     1.0           1.0           1.0           1.0
# AGF(Adjusted F-score)                                             1.0           1.0           1.0           1.0
# AGM(Adjusted geometric mean)                                      1.0           1.0           1.0           1.0
# AM(Difference between automatic and manual classification)        0             0             0             0
# AUC(Area under the ROC curve)                                     1.0           1.0           1.0           1.0
# AUCI(AUC value interpretation)                                    Excellent     Excellent     Excellent     Excellent
# AUPR(Area under the PR curve)                                     1.0           1.0           1.0           1.0
# BCD(Bray-Curtis dissimilarity)                                    0.0           0.0           0.0           0.0
# BM(Informedness or bookmaker informedness)                        1.0           1.0           1.0           1.0
# CEN(Confusion entropy)                                            0             0             0             0
# DOR(Diagnostic odds ratio)                                        None          None          None          None
# DP(Discriminant power)                                            None          None          None          None
# DPI(Discriminant power interpretation)                            None          None          None          None
# ERR(Error rate)                                                   0.0           0.0           0.0           0.0
# F0.5(F0.5 score)                                                  1.0           1.0           1.0           1.0
# F1(F1 score - harmonic mean of precision and sensitivity)         1.0           1.0           1.0           1.0
# F2(F2 score)                                                      1.0           1.0           1.0           1.0
# FDR(False discovery rate)                                         0.0           0.0           0.0           0.0
# FN(False negative/miss/type 2 error)                              0             0             0             0
# FNR(Miss rate or false negative rate)                             0.0           0.0           0.0           0.0
# FOR(False omission rate)                                          0.0           0.0           0.0           0.0
# FP(False positive/type 1 error/false alarm)                       0             0             0             0
# FPR(Fall-out or false positive rate)                              0.0           0.0           0.0           0.0
# G(G-measure geometric mean of precision and sensitivity)          1.0           1.0           1.0           1.0
# GI(Gini index)                                                    1.0           1.0           1.0           1.0
# GM(G-mean geometric mean of specificity and sensitivity)          1.0           1.0           1.0           1.0
# IBA(Index of balanced accuracy)                                   1.0           1.0           1.0           1.0
# IS(Information score)                                             4.04439       4.45943       2.95693       0.38618
# J(Jaccard index)                                                  1.0           1.0           1.0           1.0
# LS(Lift score)                                                    16.5          22.0          7.76471       1.30693
# MCC(Matthews correlation coefficient)                             1.0           1.0           1.0           1.0
# MCCI(Matthews correlation coefficient interpretation)             Very Strong   Very Strong   Very Strong   Very Strong
# MCEN(Modified confusion entropy)                                  0             0             0             0
# MK(Markedness)                                                    1.0           1.0           1.0           1.0
# N(Condition negative)                                             248           252           230           62
# NLR(Negative likelihood ratio)                                    0.0           0.0           0.0           0.0
# NLRI(Negative likelihood ratio interpretation)                    Good          Good          Good          Good
# NPV(Negative predictive value)                                    1.0           1.0           1.0           1.0
# OC(Overlap coefficient)                                           1.0           1.0           1.0           1.0
# OOC(Otsuka-Ochiai coefficient)                                    1.0           1.0           1.0           1.0
# OP(Optimized precision)                                           1.0           1.0           1.0           1.0
# P(Condition positive or support)                                  16            12            34            202
# PLR(Positive likelihood ratio)                                    None          None          None          None
# PLRI(Positive likelihood ratio interpretation)                    None          None          None          None
# POP(Population)                                                   264           264           264           264
# PPV(Precision or positive predictive value)                       1.0           1.0           1.0           1.0
# PRE(Prevalence)                                                   0.06061       0.04545       0.12879       0.76515
# Q(Yule Q - coefficient of colligation)                            None          None          None          None
# RACC(Random accuracy)                                             0.00367       0.00207       0.01659       0.58546
# RACCU(Random accuracy unbiased)                                   0.00367       0.00207       0.01659       0.58546
# TN(True negative/correct rejection)                               248           252           230           62
# TNR(Specificity or true negative rate)                            1.0           1.0           1.0           1.0
# TON(Test outcome negative)                                        248           252           230           62
# TOP(Test outcome positive)                                        16            12            34            202
# TP(True positive/hit)                                             16            12            34            202
# TPR(Sensitivity, recall, hit rate, or true positive rate)         1.0           1.0           1.0           1.0
# Y(Youden index)                                                   1.0           1.0           1.0           1.0
# dInd(Distance index)                                              0.0           0.0           0.0           0.0
# sInd(Similarity index)                                            1.0           1.0           1.0           1.0
#
# 1058 264
# Predict   0         1         2         3
# Actual
# 0         15        0         0         1
#
# 1         0         12        0         0
#
# 2         0         0         33        1
#
# 3         0         0         0         202
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (0.98196,1.00288)
# ACC Macro                                                         0.99621
# AUNP                                                              0.98387
# AUNU                                                              0.98448
# Bennett S                                                         0.9899
# CBA                                                               0.97457
# Chi-Squared                                                       765.266
# Chi-Squared DF                                                    9
# Conditional Entropy                                               0.0451
# Cramer V                                                          0.98298
# Cross Entropy                                                     1.12444
# F1 Macro                                                          0.98697
# F1 Micro                                                          0.99242
# Gwet AC1                                                          0.9913
# Hamming Loss                                                      0.00758
# Joint Entropy                                                     1.16922
# KL Divergence                                                     0.00031
# Kappa                                                             0.98043
# Kappa 95% CI                                                      (0.95341,1.00745)
# Kappa No Prevalence                                               0.98485
# Kappa Standard Error                                              0.01378
# Kappa Unbiased                                                    0.98043
# Lambda A                                                          0.96774
# Lambda B                                                          0.96667
# Mutual Information                                                1.05512
# NIR                                                               0.76515
# Overall ACC                                                       0.99242
# Overall CEN                                                       0.02077
# Overall J                                                         (3.89828,0.97457)
# Overall MCC                                                       0.98063
# Overall MCEN                                                      0.03553
# Overall RACC                                                      0.61286
# Overall RACCU                                                     0.61288
# P-Value                                                           -0.0
# PPV Macro                                                         0.99755
# PPV Micro                                                         0.99242
# Pearson C                                                         0.86227
# Phi-Squared                                                       2.89873
# RCI                                                               0.93862
# RR                                                                66.0
# Reference Entropy                                                 1.12412
# Response Entropy                                                  1.10022
# SOA1(Landis & Koch)                                               Almost Perfect
# SOA2(Fleiss)                                                      Excellent
# SOA3(Altman)                                                      Very Good
# SOA4(Cicchetti)                                                   Excellent
# SOA5(Cramer)                                                      Very Strong
# SOA6(Matthews)                                                    Very Strong
# Scott PI                                                          0.98043
# Standard Error                                                    0.00534
# TPR Macro                                                         0.97702
# TPR Micro                                                         0.99242
# Zero-one Loss                                                     2
#
# Class Statistics :
#
# Classes                                                           0             1             2             3
# ACC(Accuracy)                                                     0.99621       1.0           0.99621       0.99242
# AGF(Adjusted F-score)                                             0.97279       1.0           0.98638       0.9957
# AGM(Adjusted geometric mean)                                      0.98363       1.0           0.99208       0.9807
# AM(Difference between automatic and manual classification)        -1            0             -1            2
# AUC(Area under the ROC curve)                                     0.96875       1.0           0.98529       0.98387
# AUCI(AUC value interpretation)                                    Excellent     Excellent     Excellent     Excellent
# AUPR(Area under the PR curve)                                     0.96875       1.0           0.98529       0.9951
# BCD(Bray-Curtis dissimilarity)                                    0.00189       0.0           0.00189       0.00379
# BM(Informedness or bookmaker informedness)                        0.9375        1.0           0.97059       0.96774
# CEN(Confusion entropy)                                            0.06182       0             0.03503       0.01651
# DOR(Diagnostic odds ratio)                                        None          None          None          None
# DP(Discriminant power)                                            None          None          None          None
# DPI(Discriminant power interpretation)                            None          None          None          None
# ERR(Error rate)                                                   0.00379       0.0           0.00379       0.00758
# F0.5(F0.5 score)                                                  0.98684       1.0           0.99398       0.99214
# F1(F1 score - harmonic mean of precision and sensitivity)         0.96774       1.0           0.98507       0.99507
# F2(F2 score)                                                      0.94937       1.0           0.97633       0.99802
# FDR(False discovery rate)                                         0.0           0.0           0.0           0.0098
# FN(False negative/miss/type 2 error)                              1             0             1             0
# FNR(Miss rate or false negative rate)                             0.0625        0.0           0.02941       0.0
# FOR(False omission rate)                                          0.00402       0.0           0.00433       0.0
# FP(False positive/type 1 error/false alarm)                       0             0             0             2
# FPR(Fall-out or false positive rate)                              0.0           0.0           0.0           0.03226
# G(G-measure geometric mean of precision and sensitivity)          0.96825       1.0           0.98518       0.99509
# GI(Gini index)                                                    0.9375        1.0           0.97059       0.96774
# GM(G-mean geometric mean of specificity and sensitivity)          0.96825       1.0           0.98518       0.98374
# IBA(Index of balanced accuracy)                                   0.87891       1.0           0.94204       0.99896
# IS(Information score)                                             4.04439       4.45943       2.95693       0.37197
# J(Jaccard index)                                                  0.9375        1.0           0.97059       0.9902
# LS(Lift score)                                                    16.5          22.0          7.76471       1.29412
# MCC(Matthews correlation coefficient)                             0.9663        1.0           0.98305       0.9789
# MCCI(Matthews correlation coefficient interpretation)             Very Strong   Very Strong   Very Strong   Very Strong
# MCEN(Modified confusion entropy)                                  0.09671       0             0.05789       0.0291
# MK(Markedness)                                                    0.99598       1.0           0.99567       0.9902
# N(Condition negative)                                             248           252           230           62
# NLR(Negative likelihood ratio)                                    0.0625        0.0           0.02941       0.0
# NLRI(Negative likelihood ratio interpretation)                    Good          Good          Good          Good
# NPV(Negative predictive value)                                    0.99598       1.0           0.99567       1.0
# OC(Overlap coefficient)                                           1.0           1.0           1.0           1.0
# OOC(Otsuka-Ochiai coefficient)                                    0.96825       1.0           0.98518       0.99509
# OP(Optimized precision)                                           0.96395       1.0           0.98129       0.97603
# P(Condition positive or support)                                  16            12            34            202
# PLR(Positive likelihood ratio)                                    None          None          None          31.0
# PLRI(Positive likelihood ratio interpretation)                    None          None          None          Good
# POP(Population)                                                   264           264           264           264
# PPV(Precision or positive predictive value)                       1.0           1.0           1.0           0.9902
# PRE(Prevalence)                                                   0.06061       0.04545       0.12879       0.76515
# Q(Yule Q - coefficient of colligation)                            None          None          None          None
# RACC(Random accuracy)                                             0.00344       0.00207       0.0161        0.59125
# RACCU(Random accuracy unbiased)                                   0.00345       0.00207       0.0161        0.59127
# TN(True negative/correct rejection)                               248           252           230           60
# TNR(Specificity or true negative rate)                            1.0           1.0           1.0           0.96774
# TON(Test outcome negative)                                        249           252           231           60
# TOP(Test outcome positive)                                        15            12            33            204
# TP(True positive/hit)                                             15            12            33            202
# TPR(Sensitivity, recall, hit rate, or true positive rate)         0.9375        1.0           0.97059       1.0
# Y(Youden index)                                                   0.9375        1.0           0.97059       0.96774
# dInd(Distance index)                                              0.0625        0.0           0.02941       0.03226
# sInd(Similarity index)                                            0.95581       1.0           0.9792        0.97719

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        16
#            1       1.00      1.00      1.00        12
#            2       1.00      0.97      0.99        34
#            3       0.99      1.00      1.00       202
#
#     accuracy                           0.99       264
#    macro avg       1.00      0.98      0.99       264
# weighted avg       0.99      0.99      0.99       264

# %% [markdown]
# ## Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
X = scaler.fit_transform(X_features)
#X = X_features
all_cm = []


for train_index, test_index in skf.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    print (len(X_train), len(X_test))
    
    rf_model = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 42)
    rf_model = rf_model.fit(X_train, y_train)
    
    
    y_pred = rf_model.predict(X_test)
    
    cm = ConfusionMatrix(y_test, y_pred)
    print(cm)
    all_cm.append(c)
# Out:
# 1057 265
# Predict   0         1         2         3
# Actual
# 0         13        0         1         2
#
# 1         0         12        0         0
#
# 2         0         0         32        2
#
# 3         0         0         0         203
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (0.96475,0.99751)
# ACC Macro                                                         0.99057
# AUNP                                                              0.96558
# AUNU                                                              0.9606
# Bennett S                                                         0.97484
# CBA                                                               0.93359
# Chi-Squared                                                       718.01811
# Chi-Squared DF                                                    9
# Conditional Entropy                                               0.09384
# Cramer V                                                          0.95035
# Cross Entropy                                                     1.12338
# F1 Macro                                                          0.9605
# F1 Micro                                                          0.98113
# Gwet AC1                                                          0.97839
# Hamming Loss                                                      0.01887
# Joint Entropy                                                     1.21518
# KL Divergence                                                     0.00205
# Kappa                                                             0.95043
# Kappa 95% CI                                                      (0.90739,0.99347)
# Kappa No Prevalence                                               0.96226
# Kappa Standard Error                                              0.02196
# Kappa Unbiased                                                    0.95042
# Lambda A                                                          0.91935
# Lambda B                                                          0.91379
# Mutual Information                                                0.97434
# NIR                                                               0.76604
# Overall ACC                                                       0.98113
# Overall CEN                                                       0.04342
# Overall J                                                         (3.70746,0.92687)
# Overall MCC                                                       0.95126
# Overall MCEN                                                      0.07187
# Overall RACC                                                      0.61937
# Overall RACCU                                                     0.61946
# P-Value                                                           0.0
# PPV Macro                                                         0.98759
# PPV Micro                                                         0.98113
# Pearson C                                                         0.85465
# Phi-Squared                                                       2.7095
# RCI                                                               0.86891
# RR                                                                66.25
# Reference Entropy                                                 1.12133
# Response Entropy                                                  1.06818
# SOA1(Landis & Koch)                                               Almost Perfect
# SOA2(Fleiss)                                                      Excellent
# SOA3(Altman)                                                      Very Good
# SOA4(Cicchetti)                                                   Excellent
# SOA5(Cramer)                                                      Very Strong
# SOA6(Matthews)                                                    Very Strong
# Scott PI                                                          0.95042
# Standard Error                                                    0.00836
# TPR Macro                                                         0.93842
# TPR Micro                                                         0.98113
# Zero-one Loss                                                     5
#
# Class Statistics :
#
# Classes                                                           0             1             2             3
# ACC(Accuracy)                                                     0.98868       1.0           0.98868       0.98491
# AGF(Adjusted F-score)                                             0.91438       1.0           0.96922       0.99122
# AGM(Adjusted geometric mean)                                      0.94916       1.0           0.98091       0.96119
# AM(Difference between automatic and manual classification)        -3            0             -1            4
# AUC(Area under the ROC curve)                                     0.90625       1.0           0.96842       0.96774
# AUCI(AUC value interpretation)                                    Excellent     Excellent     Excellent     Excellent
# AUPR(Area under the PR curve)                                     0.90625       1.0           0.95544       0.99034
# BCD(Bray-Curtis dissimilarity)                                    0.00566       0.0           0.00189       0.00755
# BM(Informedness or bookmaker informedness)                        0.8125        1.0           0.93685       0.93548
# CEN(Confusion entropy)                                            0.16773       0             0.09353       0.02898
# DOR(Diagnostic odds ratio)                                        None          None          3680.0        None
# DP(Discriminant power)                                            None          None          1.96595       None
# DPI(Discriminant power interpretation)                            None          None          Limited       None
# ERR(Error rate)                                                   0.01132       0.0           0.01132       0.01509
# F0.5(F0.5 score)                                                  0.95588       1.0           0.96386       0.98448
# F1(F1 score - harmonic mean of precision and sensitivity)         0.89655       1.0           0.95522       0.99024
# F2(F2 score)                                                      0.84416       1.0           0.94675       0.99607
# FDR(False discovery rate)                                         0.0           0.0           0.0303        0.01932
# FN(False negative/miss/type 2 error)                              3             0             2             0
# FNR(Miss rate or false negative rate)                             0.1875        0.0           0.05882       0.0
# FOR(False omission rate)                                          0.0119        0.0           0.00862       0.0
# FP(False positive/type 1 error/false alarm)                       0             0             1             4
# FPR(Fall-out or false positive rate)                              0.0           0.0           0.00433       0.06452
# G(G-measure geometric mean of precision and sensitivity)          0.90139       1.0           0.95533       0.99029
# GI(Gini index)                                                    0.8125        1.0           0.93685       0.93548
# GM(G-mean geometric mean of specificity and sensitivity)          0.90139       1.0           0.96804       0.9672
# IBA(Index of balanced accuracy)                                   0.66016       1.0           0.88604       0.99584
# IS(Information score)                                             4.04985       4.46489       2.91799       0.35636
# J(Jaccard index)                                                  0.8125        1.0           0.91429       0.98068
# LS(Lift score)                                                    16.5625       22.08333      7.55793       1.28019
# MCC(Matthews correlation coefficient)                             0.89601       1.0           0.94888       0.95781
# MCCI(Matthews correlation coefficient interpretation)             Strong        Very Strong   Very Strong   Very Strong
# MCEN(Modified confusion entropy)                                  0.24178       0             0.14798       0.05004
# MK(Markedness)                                                    0.9881        1.0           0.96108       0.98068
# N(Condition negative)                                             249           253           231           62
# NLR(Negative likelihood ratio)                                    0.1875        0.0           0.05908       0.0
# NLRI(Negative likelihood ratio interpretation)                    Fair          Good          Good          Good
# NPV(Negative predictive value)                                    0.9881        1.0           0.99138       1.0
# OC(Overlap coefficient)                                           1.0           1.0           0.9697        1.0
# OOC(Otsuka-Ochiai coefficient)                                    0.90139       1.0           0.95533       0.99029
# OP(Optimized precision)                                           0.88523       1.0           0.96054       0.95157
# P(Condition positive or support)                                  16            12            34            203
# PLR(Positive likelihood ratio)                                    None          None          217.41176     15.5
# PLRI(Positive likelihood ratio interpretation)                    None          None          Good          Good
# POP(Population)                                                   265           265           265           265
# PPV(Precision or positive predictive value)                       1.0           1.0           0.9697        0.98068
# PRE(Prevalence)                                                   0.06038       0.04528       0.1283        0.76604
# Q(Yule Q - coefficient of colligation)                            None          None          0.99946       None
# RACC(Random accuracy)                                             0.00296       0.00205       0.01598       0.59838
# RACCU(Random accuracy unbiased)                                   0.00299       0.00205       0.01598       0.59843
# TN(True negative/correct rejection)                               249           253           230           58
# TNR(Specificity or true negative rate)                            1.0           1.0           0.99567       0.93548
# TON(Test outcome negative)                                        252           253           232           58
# TOP(Test outcome positive)                                        13            12            33            207
# TP(True positive/hit)                                             13            12            32            203
# TPR(Sensitivity, recall, hit rate, or true positive rate)         0.8125        1.0           0.94118       1.0
# Y(Youden index)                                                   0.8125        1.0           0.93685       0.93548
# dInd(Distance index)                                              0.1875        0.0           0.05898       0.06452
# sInd(Similarity index)                                            0.86742       1.0           0.95829       0.95438
#
# 1057 265
# Predict   0         1         2         3
# Actual
# 0         15        0         0         1
#
# 1         0         12        0         0
#
# 2         0         0         34        0
#
# 3         0         0         0         203
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (0.98884,1.00361)
# ACC Macro                                                         0.99811
# AUNP                                                              0.99194
# AUNU                                                              0.99017
# Bennett S                                                         0.99497
# CBA                                                               0.98315
# Chi-Squared                                                       777.21967
# Chi-Squared DF                                                    9
# Conditional Entropy                                               0.02036
# Cramer V                                                          0.98875
# Cross Entropy                                                     1.12152
# F1 Macro                                                          0.99132
# F1 Micro                                                          0.99623
# Gwet AC1                                                          0.99567
# Hamming Loss                                                      0.00377
# Joint Entropy                                                     1.1417
# KL Divergence                                                     0.00019
# Kappa                                                             0.99028
# Kappa 95% CI                                                      (0.97127,1.00929)
# Kappa No Prevalence                                               0.99245
# Kappa Standard Error                                              0.0097
# Kappa Unbiased                                                    0.99028
# Lambda A                                                          0.98387
# Lambda B                                                          0.98361
# Mutual Information                                                1.08695
# NIR                                                               0.76604
# Overall ACC                                                       0.99623
# Overall CEN                                                       0.00994
# Overall J                                                         (3.9326,0.98315)
# Overall MCC                                                       0.99034
# Overall MCEN                                                      0.01698
# Overall RACC                                                      0.61163
# Overall RACCU                                                     0.61164
# P-Value                                                           0.0
# PPV Macro                                                         0.99877
# PPV Micro                                                         0.99623
# Pearson C                                                         0.86356
# Phi-Squared                                                       2.9329
# RCI                                                               0.96934
# RR                                                                66.25
# Reference Entropy                                                 1.12133
# Response Entropy                                                  1.10731
# SOA1(Landis & Koch)                                               Almost Perfect
# SOA2(Fleiss)                                                      Excellent
# SOA3(Altman)                                                      Very Good
# SOA4(Cicchetti)                                                   Excellent
# SOA5(Cramer)                                                      Very Strong
# SOA6(Matthews)                                                    Very Strong
# Scott PI                                                          0.99028
# Standard Error                                                    0.00377
# TPR Macro                                                         0.98438
# TPR Micro                                                         0.99623
# Zero-one Loss                                                     1
#
# Class Statistics :
#
# Classes                                                           0             1             2             3
# ACC(Accuracy)                                                     0.99623       1.0           1.0           0.99623
# AGF(Adjusted F-score)                                             0.97279       1.0           1.0           0.99787
# AGM(Adjusted geometric mean)                                      0.98363       1.0           1.0           0.99038
# AM(Difference between automatic and manual classification)        -1            0             0             1
# AUC(Area under the ROC curve)                                     0.96875       1.0           1.0           0.99194
# AUCI(AUC value interpretation)                                    Excellent     Excellent     Excellent     Excellent
# AUPR(Area under the PR curve)                                     0.96875       1.0           1.0           0.99755
# BCD(Bray-Curtis dissimilarity)                                    0.00189       0.0           0.0           0.00189
# BM(Informedness or bookmaker informedness)                        0.9375        1.0           1.0           0.98387
# CEN(Confusion entropy)                                            0.06182       0             0             0.00824
# DOR(Diagnostic odds ratio)                                        None          None          None          None
# DP(Discriminant power)                                            None          None          None          None
# DPI(Discriminant power interpretation)                            None          None          None          None
# ERR(Error rate)                                                   0.00377       0.0           0.0           0.00377
# F0.5(F0.5 score)                                                  0.98684       1.0           1.0           0.99607
# F1(F1 score - harmonic mean of precision and sensitivity)         0.96774       1.0           1.0           0.99754
# F2(F2 score)                                                      0.94937       1.0           1.0           0.99902
# FDR(False discovery rate)                                         0.0           0.0           0.0           0.0049
# FN(False negative/miss/type 2 error)                              1             0             0             0
# FNR(Miss rate or false negative rate)                             0.0625        0.0           0.0           0.0
# FOR(False omission rate)                                          0.004         0.0           0.0           0.0
# FP(False positive/type 1 error/false alarm)                       0             0             0             1
# FPR(Fall-out or false positive rate)                              0.0           0.0           0.0           0.01613
# G(G-measure geometric mean of precision and sensitivity)          0.96825       1.0           1.0           0.99755
# GI(Gini index)                                                    0.9375        1.0           1.0           0.98387
# GM(G-mean geometric mean of specificity and sensitivity)          0.96825       1.0           1.0           0.9919
# IBA(Index of balanced accuracy)                                   0.87891       1.0           1.0           0.99974
# IS(Information score)                                             4.04985       4.46489       2.96239       0.37742
# J(Jaccard index)                                                  0.9375        1.0           1.0           0.9951
# LS(Lift score)                                                    16.5625       22.08333      7.79412       1.29902
# MCC(Matthews correlation coefficient)                             0.96631       1.0           1.0           0.98947
# MCCI(Matthews correlation coefficient interpretation)             Very Strong   Very Strong   Very Strong   Very Strong
# MCEN(Modified confusion entropy)                                  0.09671       0             0             0.01455
# MK(Markedness)                                                    0.996         1.0           1.0           0.9951
# N(Condition negative)                                             249           253           231           62
# NLR(Negative likelihood ratio)                                    0.0625        0.0           0.0           0.0
# NLRI(Negative likelihood ratio interpretation)                    Good          Good          Good          Good
# NPV(Negative predictive value)                                    0.996         1.0           1.0           1.0
# OC(Overlap coefficient)                                           1.0           1.0           1.0           1.0
# OOC(Otsuka-Ochiai coefficient)                                    0.96825       1.0           1.0           0.99755
# OP(Optimized precision)                                           0.96397       1.0           1.0           0.9881
# P(Condition positive or support)                                  16            12            34            203
# PLR(Positive likelihood ratio)                                    None          None          None          62.0
# PLRI(Positive likelihood ratio interpretation)                    None          None          None          Good
# POP(Population)                                                   265           265           265           265
# PPV(Precision or positive predictive value)                       1.0           1.0           1.0           0.9951
# PRE(Prevalence)                                                   0.06038       0.04528       0.1283        0.76604
# Q(Yule Q - coefficient of colligation)                            None          None          None          None
# RACC(Random accuracy)                                             0.00342       0.00205       0.01646       0.5897
# RACCU(Random accuracy unbiased)                                   0.00342       0.00205       0.01646       0.58971
# TN(True negative/correct rejection)                               249           253           231           61
# TNR(Specificity or true negative rate)                            1.0           1.0           1.0           0.98387
# TON(Test outcome negative)                                        250           253           231           61
# TOP(Test outcome positive)                                        15            12            34            204
# TP(True positive/hit)                                             15            12            34            203
# TPR(Sensitivity, recall, hit rate, or true positive rate)         0.9375        1.0           1.0           1.0
# Y(Youden index)                                                   0.9375        1.0           1.0           0.98387
# dInd(Distance index)                                              0.0625        0.0           0.0           0.01613
# sInd(Similarity index)                                            0.95581       1.0           1.0           0.9886
#
# 1058 264
# Predict   0         1         2         3
# Actual
# 0         15        0         0         1
#
# 1         0         11        0         1
#
# 2         0         0         32        2
#
# 3         0         0         0         202
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (0.97011,0.99958)
# ACC Macro                                                         0.99242
# AUNP                                                              0.96774
# AUNU                                                              0.96635
# Bennett S                                                         0.9798
# CBA                                                               0.94398
# Chi-Squared                                                       733.18204
# Chi-Squared DF                                                    9
# Conditional Entropy                                               0.08082
# Cramer V                                                          0.96215
# Cross Entropy                                                     1.12509
# F1 Macro                                                          0.97104
# F1 Micro                                                          0.98485
# Gwet AC1                                                          0.98264
# Hamming Loss                                                      0.01515
# Joint Entropy                                                     1.20494
# KL Divergence                                                     0.00097
# Kappa                                                             0.96034
# Kappa 95% CI                                                      (0.92176,0.99891)
# Kappa No Prevalence                                               0.9697
# Kappa Standard Error                                              0.01968
# Kappa Unbiased                                                    0.96033
# Lambda A                                                          0.93548
# Lambda B                                                          0.93103
# Mutual Information                                                0.99359
# NIR                                                               0.76515
# Overall ACC                                                       0.98485
# Overall CEN                                                       0.03829
# Overall J                                                         (3.77593,0.94398)
# Overall MCC                                                       0.96109
# Overall MCEN                                                      0.06424
# Overall RACC                                                      0.618
# Overall RACCU                                                     0.61808
# P-Value                                                           -0.0
# PPV Macro                                                         0.99515
# PPV Micro                                                         0.98485
# Pearson C                                                         0.85747
# Phi-Squared                                                       2.7772
# RCI                                                               0.88388
# RR                                                                66.0
# Reference Entropy                                                 1.12412
# Response Entropy                                                  1.07441
# SOA1(Landis & Koch)                                               Almost Perfect
# SOA2(Fleiss)                                                      Excellent
# SOA3(Altman)                                                      Very Good
# SOA4(Cicchetti)                                                   Excellent
# SOA5(Cramer)                                                      Very Strong
# SOA6(Matthews)                                                    Very Strong
# Scott PI                                                          0.96033
# Standard Error                                                    0.00752
# TPR Macro                                                         0.94884
# TPR Micro                                                         0.98485
# Zero-one Loss                                                     4
#
# Class Statistics :
#
# Classes                                                           0             1             2             3
# ACC(Accuracy)                                                     0.99621       0.99621       0.99242       0.98485
# AGF(Adjusted F-score)                                             0.97279       0.96398       0.97252       0.99121
# AGM(Adjusted geometric mean)                                      0.98363       0.97822       0.98404       0.96117
# AM(Difference between automatic and manual classification)        -1            -1            -2            4
# AUC(Area under the ROC curve)                                     0.96875       0.95833       0.97059       0.96774
# AUCI(AUC value interpretation)                                    Excellent     Excellent     Excellent     Excellent
# AUPR(Area under the PR curve)                                     0.96875       0.95833       0.97059       0.99029
# BCD(Bray-Curtis dissimilarity)                                    0.00189       0.00189       0.00379       0.00758
# BM(Informedness or bookmaker informedness)                        0.9375        0.91667       0.94118       0.93548
# CEN(Confusion entropy)                                            0.06182       0.07608       0.05913       0.031
# DOR(Diagnostic odds ratio)                                        None          None          None          None
# DP(Discriminant power)                                            None          None          None          None
# DPI(Discriminant power interpretation)                            None          None          None          None
# ERR(Error rate)                                                   0.00379       0.00379       0.00758       0.01515
# F0.5(F0.5 score)                                                  0.98684       0.98214       0.98765       0.98441
# F1(F1 score - harmonic mean of precision and sensitivity)         0.96774       0.95652       0.9697        0.9902
# F2(F2 score)                                                      0.94937       0.9322        0.95238       0.99606
# FDR(False discovery rate)                                         0.0           0.0           0.0           0.01942
# FN(False negative/miss/type 2 error)                              1             1             2             0
# FNR(Miss rate or false negative rate)                             0.0625        0.08333       0.05882       0.0
# FOR(False omission rate)                                          0.00402       0.00395       0.00862       0.0
# FP(False positive/type 1 error/false alarm)                       0             0             0             4
# FPR(Fall-out or false positive rate)                              0.0           0.0           0.0           0.06452
# G(G-measure geometric mean of precision and sensitivity)          0.96825       0.95743       0.97014       0.99024
# GI(Gini index)                                                    0.9375        0.91667       0.94118       0.93548
# GM(G-mean geometric mean of specificity and sensitivity)          0.96825       0.95743       0.97014       0.9672
# IBA(Index of balanced accuracy)                                   0.87891       0.84028       0.88581       0.99584
# IS(Information score)                                             4.04439       4.45943       2.95693       0.35789
# J(Jaccard index)                                                  0.9375        0.91667       0.94118       0.98058
# LS(Lift score)                                                    16.5          22.0          7.76471       1.28155
# MCC(Matthews correlation coefficient)                             0.9663        0.95553       0.96595       0.95777
# MCCI(Matthews correlation coefficient interpretation)             Very Strong   Very Strong   Very Strong   Very Strong
# MCEN(Modified confusion entropy)                                  0.09671       0.11557       0.09301       0.05398
# MK(Markedness)                                                    0.99598       0.99605       0.99138       0.98058
# N(Condition negative)                                             248           252           230           62
# NLR(Negative likelihood ratio)                                    0.0625        0.08333       0.05882       0.0
# NLRI(Negative likelihood ratio interpretation)                    Good          Good          Good          Good
# NPV(Negative predictive value)                                    0.99598       0.99605       0.99138       1.0
# OC(Overlap coefficient)                                           1.0           1.0           1.0           1.0
# OOC(Otsuka-Ochiai coefficient)                                    0.96825       0.95743       0.97014       0.99024
# OP(Optimized precision)                                           0.96395       0.95273       0.96212       0.95152
# P(Condition positive or support)                                  16            12            34            202
# PLR(Positive likelihood ratio)                                    None          None          None          15.5
# PLRI(Positive likelihood ratio interpretation)                    None          None          None          Good
# POP(Population)                                                   264           264           264           264
# PPV(Precision or positive predictive value)                       1.0           1.0           1.0           0.98058
# PRE(Prevalence)                                                   0.06061       0.04545       0.12879       0.76515
# Q(Yule Q - coefficient of colligation)                            None          None          None          None
# RACC(Random accuracy)                                             0.00344       0.00189       0.01561       0.59705
# RACCU(Random accuracy unbiased)                                   0.00345       0.0019        0.01562       0.59711
# TN(True negative/correct rejection)                               248           252           230           58
# TNR(Specificity or true negative rate)                            1.0           1.0           1.0           0.93548
# TON(Test outcome negative)                                        249           253           232           58
# TOP(Test outcome positive)                                        15            11            32            206
# TP(True positive/hit)                                             15            11            32            202
# TPR(Sensitivity, recall, hit rate, or true positive rate)         0.9375        0.91667       0.94118       1.0
# Y(Youden index)                                                   0.9375        0.91667       0.94118       0.93548
# dInd(Distance index)                                              0.0625        0.08333       0.05882       0.06452
# sInd(Similarity index)                                            0.95581       0.94107       0.95841       0.95438
#
# 1058 264
# Predict   0         1         2         3
# Actual
# 0         15        0         0         1
#
# 1         0         12        0         0
#
# 2         0         0         34        0
#
# 3         0         0         0         202
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (0.9888,1.00362)
# ACC Macro                                                         0.99811
# AUNP                                                              0.99194
# AUNU                                                              0.99017
# Bennett S                                                         0.99495
# CBA                                                               0.98314
# Chi-Squared                                                       774.28079
# Chi-Squared DF                                                    9
# Conditional Entropy                                               0.02044
# Cramer V                                                          0.98875
# Cross Entropy                                                     1.12431
# F1 Macro                                                          0.99132
# F1 Micro                                                          0.99621
# Gwet AC1                                                          0.99565
# Hamming Loss                                                      0.00379
# Joint Entropy                                                     1.14456
# KL Divergence                                                     0.00019
# Kappa                                                             0.99028
# Kappa 95% CI                                                      (0.97125,1.0093)
# Kappa No Prevalence                                               0.99242
# Kappa Standard Error                                              0.00971
# Kappa Unbiased                                                    0.99028
# Lambda A                                                          0.98387
# Lambda B                                                          0.98361
# Mutual Information                                                1.08963
# NIR                                                               0.76515
# Overall ACC                                                       0.99621
# Overall CEN                                                       0.00998
# Overall J                                                         (3.93257,0.98314)
# Overall MCC                                                       0.99034
# Overall MCEN                                                      0.01703
# Overall RACC                                                      0.61045
# Overall RACCU                                                     0.61046
# P-Value                                                           -0.0
# PPV Macro                                                         0.99877
# PPV Micro                                                         0.99621
# Pearson C                                                         0.86356
# Phi-Squared                                                       2.93288
# RCI                                                               0.96932
# RR                                                                66.0
# Reference Entropy                                                 1.12412
# Response Entropy                                                  1.11008
# SOA1(Landis & Koch)                                               Almost Perfect
# SOA2(Fleiss)                                                      Excellent
# SOA3(Altman)                                                      Very Good
# SOA4(Cicchetti)                                                   Excellent
# SOA5(Cramer)                                                      Very Strong
# SOA6(Matthews)                                                    Very Strong
# Scott PI                                                          0.99028
# Standard Error                                                    0.00378
# TPR Macro                                                         0.98438
# TPR Micro                                                         0.99621
# Zero-one Loss                                                     1
#
# Class Statistics :
#
# Classes                                                           0             1             2             3
# ACC(Accuracy)                                                     0.99621       1.0           1.0           0.99621
# AGF(Adjusted F-score)                                             0.97279       1.0           1.0           0.99787
# AGM(Adjusted geometric mean)                                      0.98363       1.0           1.0           0.99038
# AM(Difference between automatic and manual classification)        -1            0             0             1
# AUC(Area under the ROC curve)                                     0.96875       1.0           1.0           0.99194
# AUCI(AUC value interpretation)                                    Excellent     Excellent     Excellent     Excellent
# AUPR(Area under the PR curve)                                     0.96875       1.0           1.0           0.99754
# BCD(Bray-Curtis dissimilarity)                                    0.00189       0.0           0.0           0.00189
# BM(Informedness or bookmaker informedness)                        0.9375        1.0           1.0           0.98387
# CEN(Confusion entropy)                                            0.06182       0             0             0.00827
# DOR(Diagnostic odds ratio)                                        None          None          None          None
# DP(Discriminant power)                                            None          None          None          None
# DPI(Discriminant power interpretation)                            None          None          None          None
# ERR(Error rate)                                                   0.00379       0.0           0.0           0.00379
# F0.5(F0.5 score)                                                  0.98684       1.0           1.0           0.99606
# F1(F1 score - harmonic mean of precision and sensitivity)         0.96774       1.0           1.0           0.99753
# F2(F2 score)                                                      0.94937       1.0           1.0           0.99901
# FDR(False discovery rate)                                         0.0           0.0           0.0           0.00493
# FN(False negative/miss/type 2 error)                              1             0             0             0
# FNR(Miss rate or false negative rate)                             0.0625        0.0           0.0           0.0
# FOR(False omission rate)                                          0.00402       0.0           0.0           0.0
# FP(False positive/type 1 error/false alarm)                       0             0             0             1
# FPR(Fall-out or false positive rate)                              0.0           0.0           0.0           0.01613
# G(G-measure geometric mean of precision and sensitivity)          0.96825       1.0           1.0           0.99753
# GI(Gini index)                                                    0.9375        1.0           1.0           0.98387
# GM(G-mean geometric mean of specificity and sensitivity)          0.96825       1.0           1.0           0.9919
# IBA(Index of balanced accuracy)                                   0.87891       1.0           1.0           0.99974
# IS(Information score)                                             4.04439       4.45943       2.95693       0.37906
# J(Jaccard index)                                                  0.9375        1.0           1.0           0.99507
# LS(Lift score)                                                    16.5          22.0          7.76471       1.30049
# MCC(Matthews correlation coefficient)                             0.9663        1.0           1.0           0.98946
# MCCI(Matthews correlation coefficient interpretation)             Very Strong   Very Strong   Very Strong   Very Strong
# MCEN(Modified confusion entropy)                                  0.09671       0             0             0.01461
# MK(Markedness)                                                    0.99598       1.0           1.0           0.99507
# N(Condition negative)                                             248           252           230           62
# NLR(Negative likelihood ratio)                                    0.0625        0.0           0.0           0.0
# NLRI(Negative likelihood ratio interpretation)                    Good          Good          Good          Good
# NPV(Negative predictive value)                                    0.99598       1.0           1.0           1.0
# OC(Overlap coefficient)                                           1.0           1.0           1.0           1.0
# OOC(Otsuka-Ochiai coefficient)                                    0.96825       1.0           1.0           0.99753
# OP(Optimized precision)                                           0.96395       1.0           1.0           0.98808
# P(Condition positive or support)                                  16            12            34            202
# PLR(Positive likelihood ratio)                                    None          None          None          62.0
# PLRI(Positive likelihood ratio interpretation)                    None          None          None          Good
# POP(Population)                                                   264           264           264           264
# PPV(Precision or positive predictive value)                       1.0           1.0           1.0           0.99507
# PRE(Prevalence)                                                   0.06061       0.04545       0.12879       0.76515
# Q(Yule Q - coefficient of colligation)                            None          None          None          None
# RACC(Random accuracy)                                             0.00344       0.00207       0.01659       0.58836
# RACCU(Random accuracy unbiased)                                   0.00345       0.00207       0.01659       0.58836
# TN(True negative/correct rejection)                               248           252           230           61
# TNR(Specificity or true negative rate)                            1.0           1.0           1.0           0.98387
# TON(Test outcome negative)                                        249           252           230           61
# TOP(Test outcome positive)                                        15            12            34            203
# TP(True positive/hit)                                             15            12            34            202
# TPR(Sensitivity, recall, hit rate, or true positive rate)         0.9375        1.0           1.0           1.0
# Y(Youden index)                                                   0.9375        1.0           1.0           0.98387
# dInd(Distance index)                                              0.0625        0.0           0.0           0.01613
# sInd(Similarity index)                                            0.95581       1.0           1.0           0.9886
#
# 1058 264
# Predict   0         1         2         3
# Actual
# 0         11        1         0         4
#
# 1         0         12        0         0
#
# 2         0         0         33        1
#
# 3         0         0         0         202
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (0.95929,0.99525)
# ACC Macro                                                         0.98864
# AUNP                                                              0.95769
# AUNU                                                              0.94668
# Bennett S                                                         0.9697
# CBA                                                               0.88925
# Chi-Squared                                                       677.63289
# Chi-Squared DF                                                    9
# Conditional Entropy                                               0.09263
# Cramer V                                                          0.92498
# Cross Entropy                                                     1.13019
# F1 Macro                                                          0.93692
# F1 Micro                                                          0.97727
# Gwet AC1                                                          0.97399
# Hamming Loss                                                      0.02273
# Joint Entropy                                                     1.21675
# KL Divergence                                                     0.00607
# Kappa                                                             0.94006
# Kappa 95% CI                                                      (0.89265,0.98747)
# Kappa No Prevalence                                               0.95455
# Kappa Standard Error                                              0.02419
# Kappa Unbiased                                                    0.94003
# Lambda A                                                          0.90323
# Lambda B                                                          0.89474
# Mutual Information                                                0.96246
# NIR                                                               0.76515
# Overall ACC                                                       0.97727
# Overall CEN                                                       0.04533
# Overall J                                                         (3.55701,0.88925)
# Overall MCC                                                       0.94158
# Overall MCEN                                                      0.07344
# Overall RACC                                                      0.62081
# Overall RACCU                                                     0.621
# P-Value                                                           -0.0
# PPV Macro                                                         0.97473
# PPV Micro                                                         0.97727
# Pearson C                                                         0.84831
# Phi-Squared                                                       2.56679
# RCI                                                               0.85619
# RR                                                                66.0
# Reference Entropy                                                 1.12412
# Response Entropy                                                  1.05509
# SOA1(Landis & Koch)                                               Almost Perfect
# SOA2(Fleiss)                                                      Excellent
# SOA3(Altman)                                                      Very Good
# SOA4(Cicchetti)                                                   Excellent
# SOA5(Cramer)                                                      Very Strong
# SOA6(Matthews)                                                    Very Strong
# Scott PI                                                          0.94003
# Standard Error                                                    0.00917
# TPR Macro                                                         0.91452
# TPR Micro                                                         0.97727
# Zero-one Loss                                                     6
#
# Class Statistics :
#
# Classes                                                           0             1             2             3
# ACC(Accuracy)                                                     0.98106       0.99621       0.99621       0.98106
# AGF(Adjusted F-score)                                             0.84953       0.99137       0.98638       0.9889
# AGM(Adjusted geometric mean)                                      0.91191       0.99705       0.99208       0.95132
# AM(Difference between automatic and manual classification)        -5            1             -1            5
# AUC(Area under the ROC curve)                                     0.84375       0.99802       0.98529       0.95968
# AUCI(AUC value interpretation)                                    Very Good     Excellent     Excellent     Excellent
# AUPR(Area under the PR curve)                                     0.84375       0.96154       0.98529       0.98792
# BCD(Bray-Curtis dissimilarity)                                    0.00947       0.00189       0.00189       0.00947
# BM(Informedness or bookmaker informedness)                        0.6875        0.99603       0.97059       0.91935
# CEN(Confusion entropy)                                            0.22601       0.07186       0.03503       0.03346
# DOR(Diagnostic odds ratio)                                        None          None          None          None
# DP(Discriminant power)                                            None          None          None          None
# DPI(Discriminant power interpretation)                            None          None          None          None
# ERR(Error rate)                                                   0.01894       0.00379       0.00379       0.01894
# F0.5(F0.5 score)                                                  0.91667       0.9375        0.99398       0.98058
# F1(F1 score - harmonic mean of precision and sensitivity)         0.81481       0.96          0.98507       0.98778
# F2(F2 score)                                                      0.73333       0.98361       0.97633       0.99507
# FDR(False discovery rate)                                         0.0           0.07692       0.0           0.02415
# FN(False negative/miss/type 2 error)                              5             0             1             0
# FNR(Miss rate or false negative rate)                             0.3125        0.0           0.02941       0.0
# FOR(False omission rate)                                          0.01976       0.0           0.00433       0.0
# FP(False positive/type 1 error/false alarm)                       0             1             0             5
# FPR(Fall-out or false positive rate)                              0.0           0.00397       0.0           0.08065
# G(G-measure geometric mean of precision and sensitivity)          0.82916       0.96077       0.98518       0.98785
# GI(Gini index)                                                    0.6875        0.99603       0.97059       0.91935
# GM(G-mean geometric mean of specificity and sensitivity)          0.82916       0.99801       0.98518       0.95883
# IBA(Index of balanced accuracy)                                   0.47266       0.99998       0.94204       0.9935
# IS(Information score)                                             4.04439       4.34395       2.95693       0.35091
# J(Jaccard index)                                                  0.6875        0.92308       0.97059       0.97585
# LS(Lift score)                                                    16.5          20.30769      7.76471       1.27536
# MCC(Matthews correlation coefficient)                             0.82092       0.95886       0.98305       0.94718
# MCCI(Matthews correlation coefficient interpretation)             Strong        Very Strong   Very Strong   Very Strong
# MCEN(Modified confusion entropy)                                  0.29014       0.11012       0.05789       0.05694
# MK(Markedness)                                                    0.98024       0.92308       0.99567       0.97585
# N(Condition negative)                                             248           252           230           62
# NLR(Negative likelihood ratio)                                    0.3125        0.0           0.02941       0.0
# NLRI(Negative likelihood ratio interpretation)                    Poor          Good          Good          Good
# NPV(Negative predictive value)                                    0.98024       1.0           0.99567       1.0
# OC(Overlap coefficient)                                           1.0           1.0           1.0           1.0
# OOC(Otsuka-Ochiai coefficient)                                    0.82916       0.96077       0.98518       0.98785
# OP(Optimized precision)                                           0.79588       0.99422       0.98129       0.93904
# P(Condition positive or support)                                  16            12            34            202
# PLR(Positive likelihood ratio)                                    None          252.0         None          12.4
# PLRI(Positive likelihood ratio interpretation)                    None          Good          None          Good
# POP(Population)                                                   264           264           264           264
# PPV(Precision or positive predictive value)                       1.0           0.92308       1.0           0.97585
# PRE(Prevalence)                                                   0.06061       0.04545       0.12879       0.76515
# Q(Yule Q - coefficient of colligation)                            None          None          None          None
# RACC(Random accuracy)                                             0.00253       0.00224       0.0161        0.59995
# RACCU(Random accuracy unbiased)                                   0.00261       0.00224       0.0161        0.60004
# TN(True negative/correct rejection)                               248           251           230           57
# TNR(Specificity or true negative rate)                            1.0           0.99603       1.0           0.91935
# TON(Test outcome negative)                                        253           251           231           57
# TOP(Test outcome positive)                                        11            13            33            207
# TP(True positive/hit)                                             11            12            33            202
# TPR(Sensitivity, recall, hit rate, or true positive rate)         0.6875        1.0           0.97059       1.0
# Y(Youden index)                                                   0.6875        0.99603       0.97059       0.91935
# dInd(Distance index)                                              0.3125        0.00397       0.02941       0.08065
# sInd(Similarity index)                                            0.77903       0.99719       0.9792        0.94298

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.69      0.81        16
#            1       0.92      1.00      0.96        12
#            2       1.00      0.97      0.99        34
#            3       0.98      1.00      0.99       202
#
#     accuracy                           0.98       264
#    macro avg       0.97      0.91      0.94       264
# weighted avg       0.98      0.98      0.98       264

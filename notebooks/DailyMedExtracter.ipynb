# %%
import os
import xmltodict
import pprint
import json
import xml.etree.ElementTree as ET
from lxml import etree
from datetime import date
import pandas as pd
import argparse

# %%
#Methods for extracting data from SPL labels

#http://www.accessdata.fda.gov/spl/stylesheet/spl-common.xsl
namespaces={"v3":"urn:hl7-org:v3",}

def normalize_date(date_string):
    year = int(date_string[0:4])
    month = int(date_string[4:6])
    day = int(date_string[6:8])
    return date(year,month,day).strftime("%b %d, %Y")

class DrugLabel(object):
    """represents a Drug Label in the SPL format.
    takes one argument, spl_label, which can be either an url or a file path"""

    def __init__(self, spl_label):
        self.label_data = spl_label
        self.xml = etree.parse(spl_label)

    def actives(self): #UNII code
        """returns a list of active compounds"""
        #here converting to a set removes duplicates
        return sorted(list(set(active.text for active in self.xml.xpath("//v3:ingredientSubstance/v3:activeMoiety/v3:activeMoiety/v3:name",namespaces=namespaces))))
    actives.label = "active cmpds"


    def unii(self): #UNII code
        """returns the drug's NDC number"""
        #this xpath query is NOT from the SPL xsl file
        return sorted(list(set(self.xml.xpath("//v3:ingredientSubstance/v3:activeMoiety/v3:activeMoiety/v3:code/@code",namespaces=namespaces))))
    unii.label = "unii"

    def iau(self):
        """returns the indications and usage section"""
        #here converting to a set removes duplicates
        return sorted(list(set(active.text for active in self.xml.xpath("//v3:structuredBody/",namespaces=namespaces))))
    actives.label = "active cmpds"
    

    def start_date(self):
        """returns start marketing date as a strftime formatted python date object"""
        date_string = self.xml.xpath("//v3:subjectOf/v3:marketingAct/v3:effectiveTime/v3:low/@value",namespaces=namespaces)[0]
        return normalize_date(date_string)
    start_date.label = "marketing start date"

    # don't bother - it's None for all labels
    # end_date.label = "marketing end date"
    # def end_date(self):
    # 	"""returns end marketing date as a strftime formatted python date object or the string "None if not defined
    # 	refers to the expiration date of the last lot released to the market
    # 	(from http://spl-work-group.wikispaces.com/file/view/creating_otc_sp_documentsl.pdf)"""
    # 	try:
    # 		date_string = self.xml.xpath("//v3:subjectOf/v3:marketingAct/v3:effectiveTime/v3:high/@value",namespaces=namespaces)[0]
    # 		return normalize_date(datestring)
    # 	except:
    # 		return "None"

    def marketing_category(self):
        """returns the marketing category"""
        return self.xml.xpath("//v3:subjectOf/v3:approval/v3:code/@displayName",namespaces=namespaces)[0]
    marketing_category.label = "marketing category"

    def revision_date(self):
        """returns label revision date"""
        date_string = self.xml.xpath("/v3:document/v3:effectiveTime/@value",namespaces=namespaces)[0]
        return normalize_date(date_string)
    revision_date.label = "revision date"

    def label_type(self):
        """returns the drug label type, typically 'HUMAN OTC DRUG LABEL' or 'HUMAN PRESCRIPTION DRUG LABEL' """
        return self.xml.xpath("//v3:code/@displayName",namespaces=namespaces)[0]
    label_type.label = "label type"


    def ndc(self):
        """returns the drug's NDC number"""
        #this xpath query is NOT from the SPL xsl file
        return self.xml.xpath("//v3:manufacturedProduct/v3:manufacturedProduct/v3:code/@code",namespaces=namespaces)[0]
    ndc.label = "ndc"

    def name(self):
        """returns the drug's name"""
        return self.xml.xpath("//v3:manufacturedProduct/v3:manufacturedProduct/v3:name",namespaces=namespaces)[0].text.replace("\t","").replace("\n","")
    name.label = "name"

    def distributor(self):
        """returns the drug's distributor"""
        return self.xml.xpath("//v3:author/v3:assignedEntity/v3:representedOrganization/v3:name",namespaces=namespaces)[0].text
    distributor.label = "distributor"

    def dosage_form(self):
        """returns the drug's dosage form"""
        return self.xml.xpath("//v3:manufacturedProduct/v3:manufacturedProduct/v3:formCode/@displayName",namespaces=namespaces)[0]
    dosage_form.label = "dosage form"

    #just a helper function for the next two functions, so no label
    def _get_word_list(self, word):
        """returns a list of etree instances of all occurances of 'word','Word' or 'WORD' """
        word = str(word)
        #this query also NOT from the SPL xsl file
        query = "//*[text()[contains(.,'%s') or contains(.,'%s') or contains(.,'%s')]]" %(word.lower(),word.upper(),word.capitalize())
        return self.xml.xpath(query,namespaces=namespaces)

    def test_word(self, word):
        if self._get_word_list(word): return 1
        else: return 0
    #TODO test_word.label = "%s?" %self.test_word.word

    def get_word_section(self, word):
        #finds the first ancestor section and returns section/code/@displayName
        word_section_list = []
        for word in self._get_word_list(word):
            word_section_list.extend(word.xpath("ancestor::v3:section[1]/v3:code/@displayName",namespaces=namespaces))
        if not word_section_list:
            return "n/a"
        return list(set(word_section_list))

    def get_text(self, code):
        """returns the drug's label"""
        
        path = '//v3:section/v3:code[@code='+ code+ ']/..//v3:paragraph'
        text = self.xml.xpath(path, namespaces=namespaces)
        length = len(text)
        newText = []
        for row in range(length):
            newText.append(text[row].text)
        return newText
    
    def get_fullText(self, code):
        """returns the drug's label"""
        
        path = '//v3:section/v3:code[@code=' + code +']/..//v3:text//*'
        text = self.xml.xpath(path,namespaces=namespaces)
        length = len(text)
        newText = []
        for row in range(length):
            newText.append(text[row].text)
        return newText

    def get_word_time(self, word):
        """
        returns the LATEST effectiveTime/@date for all of the instances of "word" mentioned
        """
        word_time_list = []
        for word in self._get_word_list(word):
            word_time_list += word.xpath("ancestor::v3:section/v3:effectiveTime/@value",namespaces=namespaces)
        if not word_time_list:
            return "n/a"
        try:
            return max(list(set(normalize_date(date) for date in word_time_list)))
        except:
            return max(list(normalize_date(date) for date in word_time_list))

    def build_url(self):
        """helper function that builds and returns the accessdata.fda.gov URL given the XML file name/directory"""
        #maybe won't work on windows because slash direction?
        uuid = self.label_data.split("/")[-1].split(".")[0]
        return "http://www.accessdata.fda.gov/spl/data/%s/%s.xml" %(uuid,uuid)

    def indications(self, code, xml):
        indications = []
        drugN = self.name()
        activeCompound = self.actives()
        uniiCode = self.unii()
        
        try:
            activeC = '|'.join(activeCompound)
        except:
            activeC = activeCompound        
        try:
            uniiC = '|'.join(uniiCode)
        except:
            uniiC = uniiCode        
        
        label = self.get_text(code)
        try:
            text = '|'.join(label)
        except:
            text = label
        
        full_Label = self.get_fullText(code)
        try:
            context = '|'.join(full_Label)
        except:
            context = full_Label
        
        data = [xml, drugN, activeC, uniiC, text, context]
        inidications = indications.append(data)  
        return indications

# %%
def getLabels(code= '"34067-9"'):

    #Code for going through all xml files and extracting all of the knowledge into one pandas dataframe and into a csv file within the folder

    count = 0

    path = '../DailyMedExtracter/prescription/temp_xml/'

    #The code is used to define which label heading you wish to extract
    '''
    Indications and Usage: '"34067-9"'
    Contraindications: '"34070-3"'
    '''

    for filename in os.listdir(path):
        if filename.endswith('.xml'):

            count = count +1
            if count % 1000 == 0:
                print(count)
                break
            try:
                DL = DrugLabel(path + filename)

            except:
                pass
            try:
                indications = DL.indications(code, path + filename)

                if count == 1:
                    ind = pd.DataFrame(indications, columns=['Label_ID','Drug_Brand_Name', 'Active_ingredient', 'UNII_ID', 'Formatted_Text','Text'])
                else:
                    newind = pd.DataFrame(indications, columns=['Label_ID','Drug_Brand_Name', 'Active_ingredient', 'UNII_ID', 'Formatted_Text','Text'])
                    ind = ind.append(newind)
            except:
                pass
    return ind

# %%
code = '"34067-9"'
ind = getLabels(code)
ind.head()
# Out:
# 1000
#                                             Label_ID  \
# 0  ../DailyMedExtracter/prescription/temp_xml/000...
# 0  ../DailyMedExtracter/prescription/temp_xml/000...
# 0  ../DailyMedExtracter/prescription/temp_xml/001...
# 0  ../DailyMedExtracter/prescription/temp_xml/001...
# 0  ../DailyMedExtracter/prescription/temp_xml/001...
#
#                        Drug_Brand_Name                 Active_ingredient  \
# 0                               SRONYX  Ethinyl Estradiol|Levonorgestrel
# 0                    Diclofenac Sodium                        DICLOFENAC
# 0  Triamterene and Hydrochlorothiazide   HYDROCHLOROTHIAZIDE|TRIAMTERENE
# 0            Venlafaxine Hydrochloride                       VENLAFAXINE
# 0                            Bleomycin                         BLEOMYCIN
#
#                  UNII_ID                                     Formatted_Text  \
# 0  423D2T571U|5W7SIA7YZW  Oral contraceptives are indicated for the prev...
# 0             144O8QL0L1  Carefully consider the potential benefits and ...
# 0  0J48LPH2TH|WS821Z52LQ  \n                     |Triamterene and hydroc...
# 0             GRZ5RCB1QG  Venlafaxine hydrochloride extended-release cap...
# 0             40S1VHN69B  Bleomycin for injection should be considered a...
#
#                                                 Text
# 0  Oral contraceptives should not be used in wome...
# 0  Diclofenac sodium delayed-release tablets, are...
# 0  Triamterene and hydrochlorothiazide should not...
# 0  Hypersensitivity to venlafaxine hydrochloride ...
# 0  Bleomycin for injection is contraindicated in ...

# %%
len(ind)
# Out:
# 989

# %%
ind
# Out:
#                                              Label_ID  \
# 0   ../DailyMedExtracter/prescription/temp_xml/000...
# 0   ../DailyMedExtracter/prescription/temp_xml/000...
# 0   ../DailyMedExtracter/prescription/temp_xml/001...
# 0   ../DailyMedExtracter/prescription/temp_xml/001...
# 0   ../DailyMedExtracter/prescription/temp_xml/001...
# 0   ../DailyMedExtracter/prescription/temp_xml/001...
# 0   ../DailyMedExtracter/prescription/temp_xml/001...
# 0   ../DailyMedExtracter/prescription/temp_xml/001...
# 0   ../DailyMedExtracter/prescription/temp_xml/001...
# 0   ../DailyMedExtracter/prescription/temp_xml/001...
# 0   ../DailyMedExtracter/prescription/temp_xml/001...
# 0   ../DailyMedExtracter/prescription/temp_xml/001...
# 0   ../DailyMedExtracter/prescription/temp_xml/001...
# 0   ../DailyMedExtracter/prescription/temp_xml/002...
# 0   ../DailyMedExtracter/prescription/temp_xml/002...
# 0   ../DailyMedExtracter/prescription/temp_xml/002...
# 0   ../DailyMedExtracter/prescription/temp_xml/002...
# 0   ../DailyMedExtracter/prescription/temp_xml/002...
# 0   ../DailyMedExtracter/prescription/temp_xml/002...
# 0   ../DailyMedExtracter/prescription/temp_xml/003...
# 0   ../DailyMedExtracter/prescription/temp_xml/003...
# 0   ../DailyMedExtracter/prescription/temp_xml/003...
# 0   ../DailyMedExtracter/prescription/temp_xml/003...
# 0   ../DailyMedExtracter/prescription/temp_xml/003...
# 0   ../DailyMedExtracter/prescription/temp_xml/004...
# 0   ../DailyMedExtracter/prescription/temp_xml/004...
# 0   ../DailyMedExtracter/prescription/temp_xml/004...
# 0   ../DailyMedExtracter/prescription/temp_xml/004...
# 0   ../DailyMedExtracter/prescription/temp_xml/004...
# 0   ../DailyMedExtracter/prescription/temp_xml/005...
# ..                                                ...
# 0   ../DailyMedExtracter/prescription/temp_xml/084...
# 0   ../DailyMedExtracter/prescription/temp_xml/084...
# 0   ../DailyMedExtracter/prescription/temp_xml/084...
# 0   ../DailyMedExtracter/prescription/temp_xml/084...
# 0   ../DailyMedExtracter/prescription/temp_xml/084...
# 0   ../DailyMedExtracter/prescription/temp_xml/085...
# 0   ../DailyMedExtracter/prescription/temp_xml/085...
# 0   ../DailyMedExtracter/prescription/temp_xml/085...
# 0   ../DailyMedExtracter/prescription/temp_xml/085...
# 0   ../DailyMedExtracter/prescription/temp_xml/085...
# 0   ../DailyMedExtracter/prescription/temp_xml/085...
# 0   ../DailyMedExtracter/prescription/temp_xml/085...
# 0   ../DailyMedExtracter/prescription/temp_xml/085...
# 0   ../DailyMedExtracter/prescription/temp_xml/086...
# 0   ../DailyMedExtracter/prescription/temp_xml/086...
# 0   ../DailyMedExtracter/prescription/temp_xml/086...
# 0   ../DailyMedExtracter/prescription/temp_xml/086...
# 0   ../DailyMedExtracter/prescription/temp_xml/086...
# 0   ../DailyMedExtracter/prescription/temp_xml/086...
# 0   ../DailyMedExtracter/prescription/temp_xml/086...
# 0   ../DailyMedExtracter/prescription/temp_xml/087...
# 0   ../DailyMedExtracter/prescription/temp_xml/087...
# 0   ../DailyMedExtracter/prescription/temp_xml/087...
# 0   ../DailyMedExtracter/prescription/temp_xml/087...
# 0   ../DailyMedExtracter/prescription/temp_xml/087...
# 0   ../DailyMedExtracter/prescription/temp_xml/087...
# 0   ../DailyMedExtracter/prescription/temp_xml/087...
# 0   ../DailyMedExtracter/prescription/temp_xml/087...
# 0   ../DailyMedExtracter/prescription/temp_xml/087...
# 0   ../DailyMedExtracter/prescription/temp_xml/088...
#
#                              Drug_Brand_Name  \
# 0                                     SRONYX
# 0                          Diclofenac Sodium
# 0        Triamterene and Hydrochlorothiazide
# 0                  Venlafaxine Hydrochloride
# 0                                  Bleomycin
# 0                                 Ampicillin
# 0                 Buprenorphine and Naloxone
# 0                          Trospium Chloride
# 0                   Sertraline Hydrochloride
# 0                                    Priftin
# 0                                Eszopiclone
# 0                                  Carbatrol
# 0                               CARISOPRODOL
# 0                           Selenium Sulfide
# 0                           Morphine Sulfate
# 0                                Haloperidol
# 0                                  RIBAVIRIN
# 0                    Trazodone Hydrochloride
# 0                     Esomeprazole Magnesium
# 0                                    DIGITEK
# 0                                Mirtazapine
# 0                  HYDRALAZINE HYDROCHLORIDE
# 0                                   Zortress
# 0                                 Lovastatin
# 0                    Naftifine Hydrochloride
# 0                                 METHERGINE
# 0       AZITHROMYCIN
# 0                                  Tadalafil
# 0                    Trazodone Hydrochloride
# 0                        Metoprolol Tartrate
# ..                                       ...
# 0                          Zolpidem Tartrate
# 0                                     OXYGEN
# 0                        Quetiapine Fumarate
# 0                         Potassium Chloride
# 0   HYDROCODONE BITARTRATE AND ACETAMINOPHEN
# 0                            Quinine Sulfate
# 0                                FENOFIBRATE
# 0                                   Premarin
# 0                                  Doxazosin
# 0                                  LORAZEPAM
# 0                                     Picato
# 0                                    VELCADE
# 0                            Sodium Chloride
# 0                                  PRED MILD
# 0                  Hydroxyzine Hydrochloride
# 0                                Eszopiclone
# 0                            Warfarin Sodium
# 0                                   Anectine
# 0                              Methocarbamol
# 0                                     VERMOX
# 0                               KETOCONAZOLE
# 0                       Levothyroxine Sodium
# 0                                 Clonazepam
# 0               CYPROHEPTADINE HYDROCHLORIDE
# 0                                      AMRIX
# 0                                 Quetiapine
# 0                                   BLINCYTO
# 0                Amitriptyline Hydrochloride
# 0               Metoclopramide Hydrochloride
# 0                          Hydromorphone HCl
#
#                    Active_ingredient                UNII_ID  \
# 0   Ethinyl Estradiol|Levonorgestrel  423D2T571U|5W7SIA7YZW
# 0                         DICLOFENAC             144O8QL0L1
# 0    HYDROCHLOROTHIAZIDE|TRIAMTERENE  0J48LPH2TH|WS821Z52LQ
# 0                        VENLAFAXINE             GRZ5RCB1QG
# 0                          BLEOMYCIN             40S1VHN69B
# 0                         AMPICILLIN             7C782967RD
# 0             BUPRENORPHINE|NALOXONE  36B82AMQ7N|40D3SCR4GZ
# 0                           TROSPIUM             T4Y8ORK057
# 0                         SERTRALINE             QUC7NX6WMB
# 0                        rifapentine             XJM390A33U
# 0                        ESZOPICLONE             UZX80K71OE
# 0                      CARBAMAZEPINE             33CM23913M
# 0                       CARISOPRODOL             21925K482H
# 0                   SELENIUM SULFIDE             Z69D9E381Q
# 0                           MORPHINE             76I7G6D29C
# 0                        HALOPERIDOL             J6292F8L3D
# 0                          RIBAVIRIN             49717AWG6K
# 0                          TRAZODONE             YBK48BXK30
# 0                       Esomeprazole             N3PA6559FT
# 0                            DIGOXIN             73K4184T59
# 0                        MIRTAZAPINE             A051Q2099Q
# 0                        HYDRALAZINE             26NAK24LS8
# 0                         EVEROLIMUS             9HW64Q8G6G
# 0                         LOVASTATIN             9LHU78OQFD
# 0                          NAFTIFINE             4FB1TON47A
# 0                   METHYLERGONOVINE             W53L6FE61V
# 0             AZITHROMYCIN ANHYDROUS             J2KLZ20U1M
# 0                          Tadalafil             742SXX0ICT
# 0                          TRAZODONE             YBK48BXK30
# 0                         METOPROLOL             GEB06NHM23
# ..                               ...                    ...
# 0                           ZOLPIDEM             7K383OQI23
# 0                             OXYGEN             S88TT14065
# 0                         QUETIAPINE             BGL0JSY5SI
# 0                   POTASSIUM CATION             295O53K152
# 0          ACETAMINOPHEN|HYDROCODONE  362O9ITL9D|6YKS4Y3WQ7
# 0                            QUININE             A7V27PHC7A
# 0                    FENOFIBRIC ACID             BGF9MN2HU1
# 0              ESTROGENS, CONJUGATED             IU5QR144QX
# 0                          DOXAZOSIN             NW1291F1W8
# 0                          LORAZEPAM             O26FZP769L
# 0                   ingenol mebutate             7686S50JAH
# 0                         bortezomib             69G8BD63PP
# 0         CHLORIDE ION|SODIUM CATION  LYR4M0NH37|Q32ZN48698
# 0                       prednisolone             9PHQ9Y1OLM
# 0                        HYDROXYZINE             30S50YM8OG
# 0                        ESZOPICLONE             UZX80K71OE
# 0                           WARFARIN             5Q7ZVV76EI
# 0                    SUCCINYLCHOLINE             J2R869A8YF
# 0                      METHOCARBAMOL             125OD7737X
# 0                        mebendazole             81G6I5V05I
# 0                       ketoconazole             R9400W927I
# 0                      LEVOTHYROXINE             Q51BO43MG4
# 0                         CLONAZEPAM             5PE9FDE8GB
# 0                     CYPROHEPTADINE             2YHB6175DO
# 0                    Cyclobenzaprine             69O5WQQ5TI
# 0                         QUETIAPINE             BGL0JSY5SI
# 0                       BLINATUMOMAB             4FR53SIF3A
# 0                      AMITRIPTYLINE             1806D8D52K
# 0                     METOCLOPRAMIDE             L4YEB44I46
# 0                      HYDROMORPHONE             Q812464R06
#
#                                        Formatted_Text  \
# 0   Oral contraceptives should not be used in wome...
# 0   Diclofenac sodium delayed-release tablets, are...
# 0   Triamterene and hydrochlorothiazide should not...
# 0   Hypersensitivity to venlafaxine hydrochloride ...
# 0   Bleomycin for injection is contraindicated in ...
# 0   A history of a previous hypersensitivity react...
# 0   Buprenorphine and naloxone sublingual tablets ...
# 0   [Trospium chloride tablets are contraindicated...
# 0   All Dosage Forms of Sertraline:|The use of MAO...
# 0   Known hypersensitivity to any rifamycin. (|PRI...
# 0   Eszopiclone tablets are contraindicated in pat...
# 0   Carbamazepine should not be used in patients w...
# 0   CARISOPRODOL is contraindicated in patients wi...
# 0                             \n
# 0   Morphine Sulfate Tablets are contraindicated i...
# 0   Haloperidol is contraindicated in severe toxic...
# 0   Ribavirin for inhalation solution, USP is cont...
# 0   Trazodone hydrochloride tablets are contraindi...
# 0   Esomeprazole magnesium is contraindicated in p...
# 0                                             DIGITEK
# 0   \n                     |Mirtazapine tablets, U...
# 0   Hypersensitivity to hydrALAZINE; coronary arte...
# 0   • Hypersensitivity to everolimus, sirolimus, o...
# 0   Hypersensitivity to any component of this medi...
# 0   Naftifine Hydrochloride Cream, 1% is contraind...
# 0   Hypertension; toxemia; pregnancy; and hypersen...
# 0
# 0   Administration of tadalafil to patients who ar...
# 0   Trazodone hydrochloride tablets are contraindi...
# 0    Metoprolol tartrate tablets are contraindicat...
# ..                                                ...
# 0   Zolpidem tartrate is contraindicated in patien...
# 0
# 0   Known hypersensitivity to quetiapine tablets o...
# 0   Potassium supplements are contraindicated in p...
# 0   This product should not be administered to pat...
# 0   Quinine sulfate, USP is contraindicated in pat...
# 0         Fenofibrate tablets are contraindicated in:
# 0   PREMARIN therapy is contraindicated in individ...
# 0   The use of doxazosin tablets is contraindicate...
# 0       Lorazepam is contraindicated in patients with
# 0   [Picato, None, Known hypersensitivity to ingen...
# 0   VELCADE is contraindicated in patients with hy...
# 0                                         None known.
# 0                                           PRED MILD
# 0   Hydroxyzine, when administered to the pregnant...
# 0   Eszopiclone is contraindicated in patients wit...
# 0   Warfarin sodium is contraindicated in:|Warfari...
# 0   Succinylcholine is contraindicated in persons ...
# 0   Methocarbamol Tablets are contraindicated in p...
# 0   VERMOX™ CHEWABLE is contraindicated in persons...
# 0   Ketoconazole 2% shampoo is contraindicated in ...
# 0   Levothyroxine is contraindicated in patients w...
# 0   Clonazepam should not be used in patients with...
# 0   \n                           |\n              ...
# 0
# 0   Hypersensitivity to quetiapine or to any excip...
# 0   BLINCYTO is contraindicated in patients with k...
# 0   Amitriptyline hydrochloride is contraindicated...
# 0   Metoclopramide should not be used whenever sti...
# 0
#
#                                                  Text
# 0   Oral contraceptives should not be used in wome...
# 0   Diclofenac sodium delayed-release tablets, are...
# 0   Triamterene and hydrochlorothiazide should not...
# 0   Hypersensitivity to venlafaxine hydrochloride ...
# 0   Bleomycin for injection is contraindicated in ...
# 0   A history of a previous hypersensitivity react...
# 0   Buprenorphine and naloxone sublingual tablets ...
# 0   [Trospium chloride tablets are contraindicated...
# 0   All Dosage Forms of Sertraline:|The use of MAO...
# 0   Known hypersensitivity to any rifamycin. (|4.1...
# 0   Eszopiclone tablets are contraindicated in pat...
# 0   Carbamazepine should not be used in patients w...
# 0   CARISOPRODOL is contraindicated in patients wi...
# 0          \n                     |CONTRAINDICATIONS:
# 0   Morphine Sulfate Tablets are contraindicated i...
# 0   Haloperidol is contraindicated in severe toxic...
# 0   Ribavirin for inhalation solution, USP is cont...
# 0   Trazodone hydrochloride tablets are contraindi...
# 0   Esomeprazole magnesium is contraindicated in p...
# 0   DIGITEK|®|\n                     |\n          ...
# 0   [\n                     , Hypersensitivity, Mi...
# 0   [None, Hypersensitivity to hydrALAZINE; corona...
# 0   • Hypersensitivity to everolimus, sirolimus, o...
# 0   Hypersensitivity to any component of this medi...
# 0   Naftifine Hydrochloride Cream, 1% is contraind...
# 0   Hypertension; toxemia; pregnancy; and hypersen...
# 0
# 0   \n                           |Administration o...
# 0   Trazodone hydrochloride tablets are contraindi...
# 0   [ Metoprolol tartrate tablets are contraindica...
# ..                                                ...
# 0   Zolpidem tartrate is contraindicated in patien...
# 0
# 0   Known hypersensitivity to quetiapine tablets o...
# 0   Potassium supplements are contraindicated in p...
# 0   This product should not be administered to pat...
# 0   Quinine sulfate, USP is contraindicated in pat...
# 0   Fenofibrate tablets are contraindicated in:|\n...
# 0   PREMARIN therapy is contraindicated in individ...
# 0   The use of doxazosin tablets is contraindicate...
# 0   [Lorazepam is contraindicated in patients with...
# 0   [Picato, ®, ®, [see Adverse Reactions (, 6.2, ...
# 0   VELCADE is contraindicated in patients with hy...
# 0                                         None known.
# 0                                       PRED MILD|®|®
# 0   Hydroxyzine, when administered to the pregnant...
# 0   Eszopiclone is contraindicated in patients wit...
# 0   [Warfarin sodium is contraindicated in:, \n   ...
# 0   Succinylcholine is contraindicated in persons ...
# 0   Methocarbamol Tablets are contraindicated in p...
# 0   VERMOX™ CHEWABLE is contraindicated in persons...
# 0   Ketoconazole 2% shampoo is contraindicated in ...
# 0   Levothyroxine is contraindicated in patients w...
# 0   Clonazepam should not be used in patients with...
# 0   [\n                           , CONTRAINDICATI...
# 0   \n                     |Hypersensitivity to an...
# 0   Hypersensitivity to quetiapine or to any excip...
# 0   BLINCYTO is contraindicated in patients with k...
# 0   Amitriptyline hydrochloride is contraindicated...
# 0   Metoclopramide should not be used whenever sti...
# 0
#
# [989 rows x 6 columns]

# %%
#Saves the data as XMLProduct
ind.to_csv("../data/output/XMLProduct.csv")

# %%
#Parser practice
parser =argparse.ArgumentParser()
parser.add_argument('-c', required=True, dest='code', help='enter path to the file for the gold standard drug indications')
    
args= parser.parse_args()
code = args.code
# Out:
# usage: ipykernel_launcher.py [-h] -c CODE
# ipykernel_launcher.py: error: the following arguments are required: -c
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
code = '"34070-3"'
path = '//v3:section/v3:code[@code='+ code+ ']/..//v3:paragraph'

# %%
path
# Out:
# '//v3:section/v3:code[@code="34070-3"]/..//v3:paragraph'

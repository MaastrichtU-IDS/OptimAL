# %%
import pandas as pd
import string
import re

# %%
df = pd.read_csv("../data/output/unlabeled_withDBID.csv")
print("The number of rows which " +str(len(df)))
# Out:
# The number of rows which 1438

# %%
df.rename(columns={"Context":"Text"}, inplace=True)
df.head()
# Out:
#                                             Label_ID  \
# 0  ../DailyMedExtracter/prescription/temp_xml/2e8...
# 1  ../DailyMedExtracter/prescription/temp_xml/d72...
# 2  ../DailyMedExtracter/prescription/temp_xml/cbb...
# 3  ../DailyMedExtracter/prescription/temp_xml/174...
# 4  ../DailyMedExtracter/prescription/temp_xml/0a1...
#
#                   Drug_Brand_Name Active_ingredient     UNII_ID  \
# 0                       Omnipaque           Iohexol  4419T9MX03
# 1  Dexamethasone Sodium Phosphate     DEXAMETHASONE  7S5I7G3JQL
# 2                       Ribavirin         RIBAVIRIN  49717AWG6K
# 3        Sertraline Hydrochloride        SERTRALINE  QUC7NX6WMB
# 4                   Ciprofloxacin     CIPROFLOXACIN  5E8K9I0O4U
#
#                                       Formatted_Text  \
# 0  OMNIPAQUE 300 is indicated for intrathecal adm...
# 1  \n                     |\n                    ...
# 2  Ribavirin capsules are indicated in combinatio...
# 3  \n                     | |Sertraline hydrochlo...
# 4  Ciprofloxacin tablets are a fluoroquinolone an...
#
#                                                 Text  WordCount    DB_ID  \
# 0  ['OMNIPAQUE 300 is indicated for intrathecal a...       4374  DB01362
# 1  ['\n                     ', '\n               ...       2481  DB01234
# 2  ['Ribavirin capsules are indicated in combinat...       2183  DB00811
# 3  [None, '\n                     ', 'Major Depre...       1674  DB01104
# 4  ['Ciprofloxacin tablets\xa0are a fluoroquinolo...       1497  DB00537
#
#        Drug_name
# 0        Iohexol
# 1  Dexamethasone
# 2      Ribavirin
# 3     Sertraline
# 4  Ciprofloxacin

# %%
#Need to drop NAN values to avoid errors
df.dropna(subset = ["Text"], inplace=True)
len(df)
# Out:
# 1452

# %%
def cleanText(text): 
    return text.replace('|','\n')

df.Text =df.Text.apply(cleanText)

# %%
def removeCharacters(s):
    b = "®ÃÂ¢â€ž¢®â‰¥"
    for char in b:
        a = s.replace(char,"")
    return a
def removeParagraphs(s):
    s = s.replace('\\n',' ')
    return s
def removeSlashes(s):
    s = s.replace("\'",'')
    return s
def removeDuplicatedWhitespace(s):
    " ".join(s.split())
    return s
def removePatterns(s):
    return re.sub(r'\\t',  '',  s)
def removePatterns2(s):
    return re.sub(r'\\xa0',  '',  s)
def removePatterns3(s):
    return re.sub(r'\\x',  '',  s)
def removePatterns4(s):
    return re.sub(r'â‰¥',  '',  s)
def removeCommaSpace(s):
    return re.sub('                     ,',  '',  s)
def removeNones(s):
    return re.sub('None,', '', s)
def removeNones2(s):
    return re.sub('None],', ']', s)
def trailingwhitespace(s):
    return s.strip()

df.Text = df.Text.apply(removeCommaSpace)
df.Text = df.Text.apply(removeNones)
df.Text = df.Text.apply(removeNones2)
df.Text = df.Text.apply(removePatterns)
df.Text = df.Text.apply(removePatterns2)
df.Text = df.Text.apply(removePatterns3)
df.Text = df.Text.apply(removePatterns4)
df.Text = df.Text.apply(removeCharacters)
df.Text = df.Text.apply(removeParagraphs)
df.Text = df.Text.apply(removeSlashes)
df.Text = df.Text.apply(removeDuplicatedWhitespace)
df.Text = df.Text.apply(trailingwhitespace)

df.head()
# Out:
#                                             Label_ID  \
# 0  ../DailyMedExtracter/prescription/temp_xml/2e8...
# 2  ../DailyMedExtracter/prescription/temp_xml/cbb...
# 3  ../DailyMedExtracter/prescription/temp_xml/174...
# 1  ../DailyMedExtracter/prescription/temp_xml/d72...
# 4  ../DailyMedExtracter/prescription/temp_xml/0a1...
#
#                   Drug_Brand_Name Active_ingredient     UNII_ID  \
# 0                       Omnipaque           Iohexol  4419T9MX03
# 2                       Ribavirin         RIBAVIRIN  49717AWG6K
# 3        Sertraline Hydrochloride        SERTRALINE  QUC7NX6WMB
# 1  Dexamethasone Sodium Phosphate     DEXAMETHASONE  7S5I7G3JQL
# 4                   Ciprofloxacin     CIPROFLOXACIN  5E8K9I0O4U
#
#                                       Formatted_Text  \
# 0  OMNIPAQUE 300 is indicated for intrathecal adm...
# 2  Ribavirin capsules are indicated in combinatio...
# 3  \n                     | |Sertraline hydrochlo...
# 1  \n                     |\n                    ...
# 4  Ciprofloxacin tablets are a fluoroquinolone an...
#
#                                                 Text  WordCount    DB_ID  \
# 0  [OMNIPAQUE 300 is indicated for intrathecal ad...       4284  DB01362
# 2  [Ribavirin capsules are indicated in combinati...       1860  DB00811
# 3  [   Major Depressive Disorder,  ,  Sertraline ...       1560  DB01104
# 1  [       \ufeffA. By intravenous or intramuscul...       1523  DB01234
# 4  [Ciprofloxacin tabletsare a fluoroquinolone an...       1451  DB00537
#
#        Drug_name
# 0        Iohexol
# 2      Ribavirin
# 3     Sertraline
# 1  Dexamethasone
# 4  Ciprofloxacin

# %%
counter = []
for index, row in df.iterrows():
    test = row['Text']
    #Counts the number of entries at row x and adds it to the counter list
    counter.append(len(test.split()))

#The word count list is now appended to the context file
df['WordCount'] = counter

# %%
#Sorts instances by string length
df = df.sort_values(by = "WordCount", ascending = False)

# %%
len(df)
# Out:
# 1452

# %%
df = df[df.WordCount>4]
print(len(df))
df.head()
# Out:
# 1438
#                                             Label_ID  \
# 0  ../DailyMedExtracter/prescription/temp_xml/2e8...
# 2  ../DailyMedExtracter/prescription/temp_xml/cbb...
# 3  ../DailyMedExtracter/prescription/temp_xml/174...
# 1  ../DailyMedExtracter/prescription/temp_xml/d72...
# 4  ../DailyMedExtracter/prescription/temp_xml/0a1...
#
#                   Drug_Brand_Name Active_ingredient     UNII_ID  \
# 0                       Omnipaque           Iohexol  4419T9MX03
# 2                       Ribavirin         RIBAVIRIN  49717AWG6K
# 3        Sertraline Hydrochloride        SERTRALINE  QUC7NX6WMB
# 1  Dexamethasone Sodium Phosphate     DEXAMETHASONE  7S5I7G3JQL
# 4                   Ciprofloxacin     CIPROFLOXACIN  5E8K9I0O4U
#
#                                       Formatted_Text  \
# 0  OMNIPAQUE 300 is indicated for intrathecal adm...
# 2  Ribavirin capsules are indicated in combinatio...
# 3  \n                     | |Sertraline hydrochlo...
# 1  \n                     |\n                    ...
# 4  Ciprofloxacin tablets are a fluoroquinolone an...
#
#                                                 Text  WordCount    DB_ID  \
# 0  [OMNIPAQUE 300 is indicated for intrathecal ad...       4284  DB01362
# 2  [Ribavirin capsules are indicated in combinati...       1860  DB00811
# 3  [   Major Depressive Disorder,  ,  Sertraline ...       1560  DB01104
# 1  [       \ufeffA. By intravenous or intramuscul...       1523  DB01234
# 4  [Ciprofloxacin tabletsare a fluoroquinolone an...       1451  DB00537
#
#        Drug_name
# 0        Iohexol
# 2      Ribavirin
# 3     Sertraline
# 1  Dexamethasone
# 4  Ciprofloxacin

# %%
df.to_csv("../data/output/unlabeled_withDBID.csv", index=False)

# %%
import urllib.request, urllib.error, urllib.parse
import json
import os
import pandas
from pprint import pprint

# %%
REST_URL = "http://data.bioontology.org"
API_KEY = "a28f1d5b-0cc4-454a-8baf-1b2285cfa549"

def get_json(url):
    opener = urllib.request.build_opener()
    opener.addheaders = [('Authorization', 'apikey token=' + API_KEY)]
    return json.loads(opener.open(url).read())

def print_annotations(annotations, get_class=True):
    #Result is the row
    for result in annotations:
        #returns a martix called annotatedClass which holds all of the ids, links, ontologies, etc
        class_details = result["annotatedClass"]
        if get_class:
            try:
                class_details = get_json(result["annotatedClass"]["links"]["self"])
            except urllib.error.HTTPError:
                print(f"Error retrieving {result['annotatedClass']['@id']}")
                continue
        print("Class details")
        print("\tid: " + class_details["@id"])
        print("\tprefLabel: " + class_details["prefLabel"])
        print("\tontology: " + class_details["links"]["ontology"])

        print("Annotation details")
        for annotation in result["annotations"]:
            print("\tfrom: " + str(annotation["from"]))
            print("\tto: " + str(annotation["to"]))
            print("\tmatch type: " + annotation["matchType"])

        if result["hierarchy"]:
            print("\n\tHierarchy annotations")
            for annotation in result["hierarchy"]:
                try:
                    class_details = get_json(annotation["annotatedClass"]["links"]["self"])
                except urllib.error.HTTPError:
                    print(f"Error retrieving {annotation['annotatedClass']['@id']}")
                    continue
                pref_label = class_details["prefLabel"] or "no label"
                print("\t\tClass details")
                print("\t\t\tid: " + class_details["@id"])
                print("\t\t\tprefLabel: " + class_details["prefLabel"])
                print("\t\t\tontology: " + class_details["links"]["ontology"])
                print("\t\t\tdistance from originally annotated class: " + str(annotation["distance"]))

        print("\n\n")

# %%
#Input the data you want to work with in here
df = pandas.read_csv('../data/output/unlabeled_withDBID.csv')
print(len(df))
df.head()
# Out:
# 1431
#    Unnamed: 0                                  Label_ID Drug_Brand_Name  \
# 0           0  302b23fa-a0c9-405f-9e9f-1d59284c8862.xml          MENTAX
# 1           0  32c3b588-388f-4e22-8fc7-af0f8b992755.xml        Cerezyme
# 2           0  0673b70a-a94f-4a8b-8153-1402e33fa3e0.xml        Simulect
# 3           0  94ba4d57-e4da-4080-9c8e-9e0065aef659.xml   Amytal Sodium
# 4           0  1a61a75c-19ff-462e-e054-00144ff8d46c.xml           OPIUM
#
#   Active_ingredient     UNII_ID  \
# 0        BUTENAFINE  91Y494NL0X
# 1      IMIGLUCERASE  Q6U6J48BWY
# 2       BASILIXIMAB  9927MT646M
# 3       AMOBARBITAL  GWH6IJ239E
# 4             OPIUM  37M3MZ001L
#
#                                   Formatted_Text  \
# 0                                         Mentax
# 1                        \n
# 2              Simulect|The efficacy of Simulect
# 3                                            NaN
# 4  VERITGO, DIARRHEA, PAIN, OR OTHER INDICATIONS
#
#                                                 Text  WordCount    DB_ID
# 0          MentaxM. furfur DOSAGE AND ADMINISTRATION          5  DB01091
# 1                       Cerezyme                 ...          5  DB00053
# 2                 Simulect The efficacy of Simulect           5  DB00074
# 3                                               A...          5  DB01351
# 4      VERITGO, DIARRHEA, PAIN, OR OTHER INDICATIONS          6  DB11130

# %%
#Now to make this run for each context available!!!!
id = []
From = []
To = []
matchType = []
annotation2 = []
ontology = []
context = []
dbid = []
drugname = []

#Adds additional parameters here for the bioportal search engine
additional_parameters = "&ontologies=DOID"

data = []
for index, row in df.iterrows():
    
    if index % 100  == 0:
        perc = index/len(df) *100
        print(str(index) + " : "+ str(perc))
    
    #Text input for the ontology search engine
    text_to_annotate = row["Text"]
    db_id = row["DB_ID"]
    drug_name = row["Active_ingredient"]
    label_id = row["Label_ID"]


    # Annotate using the provided text
    annotations = get_json(REST_URL + "/annotator?text=" + urllib.parse.quote(text_to_annotate) + additional_parameters)

    for result in annotations:
        class_details = result["annotatedClass"]

        for annotation in result["annotations"]:
            From.append(annotation["from"])
            To.append(annotation["to"])
            matchType.append(annotation["matchType"])
            annotation2.append(annotation["text"])   
            context.append(text_to_annotate)
            ontology.append("\tontology: " + class_details["links"]["ontology"])
            id.append(class_details["@id"])
            dbid.append(db_id)
            drugname.append(drug_name)
            data.append([label_id, annotation["from"], annotation["to"], annotation["matchType"], annotation["text"], 
                         text_to_annotate, class_details["@id"], db_id, drug_name ])
# Out:
# 0 : 0.0
# 100 : 6.988120195667366
# 200 : 13.976240391334732
# 300 : 20.964360587002094
# 400 : 27.952480782669465
# 500 : 34.940600978336825
# 600 : 41.92872117400419
# 700 : 48.91684136967156
# 800 : 55.90496156533893
# 900 : 62.893081761006286
# 1000 : 69.88120195667365
# 1100 : 76.86932215234103
# 1200 : 83.85744234800838
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-b43c9afc0ccd> in <module>
#      28
#      29     # Annotate using the provided text
# ---> 30     annotations = get_json(REST_URL + "/annotator?text=" + urllib.parse.quote(text_to_annotate) + additional_parameters)
#      31
#      32     for result in annotations:
#
# <ipython-input-2-3170afab88dd> in get_json(url)
#       5     opener = urllib.request.build_opener()
#       6     opener.addheaders = [('Authorization', 'apikey token=' + API_KEY)]
# ----> 7     return json.loads(opener.open(url).read())
#       8
#       9 def print_annotations(annotations, get_class=True):
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 414: Request-URI Too Large

# %%
len(data)
# Out:
# 5615

# %%
#Constructs the new dataframe (newdf) from the collected lists_
columns =['Label_ID','From','To','Type', 'Annotation', 'Context','DO_ID','DB_ID','DrugName' ]

newdf = pandas.DataFrame(data, columns= columns)
newdf.head()
# Out:
#                                    Label_ID  From  To  Type      Annotation  \
# 0  1a61a75c-19ff-462e-e054-00144ff8d46c.xml    10  17  PREF        DIARRHEA
# 1  0061a54d-79b7-48be-b889-b42de0624e33.xml    19  29  PREF     CYCLOPLEGIA
# 2  cb8394e1-a813-45f5-b358-3e69d2196fe9.xml    22  35  PREF  VULVOVAGINITIS
# 3  66f84cc7-8014-417d-af1d-935e85223b7f.xml    80  87  PREF        EPILEPSY
# 4  7bd438ca-ebcf-3e92-e053-2a91aa0a3675.xml    83  95   SYN   VIVAX MALARIA
#
#                                              Context  \
# 0      VERITGO, DIARRHEA, PAIN, OR OTHER INDICATIONS
# 1  For mydriasis and cycloplegia for diagnostic p...
# 2  For the treatment of vulvovaginitis caused by ...
# 3  Ethosuximide oral solution is indicated for th...
# 4  Primaquine phosphate is indicated for the radi...
#
#                                        DO_ID    DB_ID       DrugName
# 0  http://purl.obolibrary.org/obo/DOID_13250  DB11130          OPIUM
# 1  http://purl.obolibrary.org/obo/DOID_10033  DB00809    TROPICAMIDE
# 2   http://purl.obolibrary.org/obo/DOID_2273  DB00259  SULFANILAMIDE
# 3   http://purl.obolibrary.org/obo/DOID_1826  DB00593   ETHOSUXIMIDE
# 4  http://purl.obolibrary.org/obo/DOID_12978  DB01087     PRIMAQUINE

# %%
#Length of each of the df and the average number of annotations made per label
numOfAnno = len(newdf)
numOfContext = len(df.drop_duplicates(subset=["Text"]))

print(numOfAnno)
print(numOfContext)

print(numOfAnno/numOfContext)
# Out:
# 5615
# 1420
# 3.954225352112676

# %%
newdf.to_csv('../data/output/unlabeled_withBPAnnotations.csv', index=False)

# %%
df= pandas.read_csv('../data/contra/unlabeled_withBPAnnotations.csv')

# %%
print(len(df))
df.drop_duplicates(subset=["Context"])
# Out:
# 4129
#                                                Label_ID  From    To  Type  \
# 0     ../DailyMedExtracter/prescription/temp_xml/f39...     7    22   SYN
# 1     ../DailyMedExtracter/prescription/temp_xml/636...     1    16   SYN
# 2     ../DailyMedExtracter/prescription/temp_xml/6c3...     1    16   SYN
# 3     ../DailyMedExtracter/prescription/temp_xml/34d...     3    14  PREF
# 6     ../DailyMedExtracter/prescription/temp_xml/607...    13    27  PREF
# 8     ../DailyMedExtracter/prescription/temp_xml/8a0...     1    16   SYN
# 9     ../DailyMedExtracter/prescription/temp_xml/8ab...     1    16   SYN
# 10    ../DailyMedExtracter/prescription/temp_xml/8a2...    57    72   SYN
# 11    ../DailyMedExtracter/prescription/temp_xml/eef...     1     6  PREF
# 13    ../DailyMedExtracter/prescription/temp_xml/b11...    31    46   SYN
# 14    ../DailyMedExtracter/prescription/temp_xml/f39...    37    52   SYN
# 15    ../DailyMedExtracter/prescription/temp_xml/7c6...     1     6  PREF
# 17    ../DailyMedExtracter/prescription/temp_xml/23f...     1    16   SYN
# 18    ../DailyMedExtracter/prescription/temp_xml/0a3...    66    81   SYN
# 19    ../DailyMedExtracter/prescription/temp_xml/fa5...    51    66   SYN
# 20    ../DailyMedExtracter/prescription/temp_xml/3b7...    50    65   SYN
# 21    ../DailyMedExtracter/prescription/temp_xml/d04...    61    76   SYN
# 22    ../DailyMedExtracter/prescription/temp_xml/20d...     1     6  PREF
# 26    ../DailyMedExtracter/prescription/temp_xml/262...    36    51   SYN
# 27    ../DailyMedExtracter/prescription/temp_xml/cde...    20    35   SYN
# 28    ../DailyMedExtracter/prescription/temp_xml/522...    69    84   SYN
# 29    ../DailyMedExtracter/prescription/temp_xml/7c8...    54    69   SYN
# 30    ../DailyMedExtracter/prescription/temp_xml/789...    76    91   SYN
# 31    ../DailyMedExtracter/prescription/temp_xml/7ac...    82    97   SYN
# 32    ../DailyMedExtracter/prescription/temp_xml/4d7...    66    81   SYN
# 33    ../DailyMedExtracter/prescription/temp_xml/fc7...    63    78   SYN
# 34    ../DailyMedExtracter/prescription/temp_xml/1da...     1     6  PREF
# 36    ../DailyMedExtracter/prescription/temp_xml/26a...     9    24   SYN
# 44    ../DailyMedExtracter/prescription/temp_xml/031...    97   112   SYN
# 45    ../DailyMedExtracter/prescription/temp_xml/aae...    63    78   SYN
# ...                                                 ...   ...   ...   ...
# 3778  ../DailyMedExtracter/prescription/temp_xml/6bb...   207   220  PREF
# 3794  ../DailyMedExtracter/prescription/temp_xml/d11...   468   492  PREF
# 3798  ../DailyMedExtracter/prescription/temp_xml/f11...    24    39   SYN
# 3805  ../DailyMedExtracter/prescription/temp_xml/87d...   176   202  PREF
# 3813  ../DailyMedExtracter/prescription/temp_xml/0e9...   127   150  PREF
# 3820  ../DailyMedExtracter/prescription/temp_xml/754...   177   189  PREF
# 3830  ../DailyMedExtracter/prescription/temp_xml/498...    64    79   SYN
# 3835  ../DailyMedExtracter/prescription/temp_xml/728...   187   192  PREF
# 3843  ../DailyMedExtracter/prescription/temp_xml/a66...    45    57  PREF
# 3874  ../DailyMedExtracter/prescription/temp_xml/28e...    36    51   SYN
# 3882  ../DailyMedExtracter/prescription/temp_xml/7a0...    16    28  PREF
# 3887  ../DailyMedExtracter/prescription/temp_xml/119...    86   101   SYN
# 3891  ../DailyMedExtracter/prescription/temp_xml/182...   101   123  PREF
# 3927  ../DailyMedExtracter/prescription/temp_xml/1db...   119   141  PREF
# 3963  ../DailyMedExtracter/prescription/temp_xml/6cb...   221   234  PREF
# 3976  ../DailyMedExtracter/prescription/temp_xml/208...   110   132  PREF
# 4007  ../DailyMedExtracter/prescription/temp_xml/e98...    71    86   SYN
# 4012  ../DailyMedExtracter/prescription/temp_xml/4b7...    30    45   SYN
# 4019  ../DailyMedExtracter/prescription/temp_xml/895...    52    60  PREF
# 4021  ../DailyMedExtracter/prescription/temp_xml/cbb...   402   417   SYN
# 4031  ../DailyMedExtracter/prescription/temp_xml/96f...  1104  1107  PREF
# 4033  ../DailyMedExtracter/prescription/temp_xml/a5e...   180   191  PREF
# 4052  ../DailyMedExtracter/prescription/temp_xml/f2b...    71    91  PREF
# 4070  ../DailyMedExtracter/prescription/temp_xml/34e...    42    57   SYN
# 4074  ../DailyMedExtracter/prescription/temp_xml/562...   401   427  PREF
# 4103  ../DailyMedExtracter/prescription/temp_xml/5a9...   125   131  PREF
# 4113  ../DailyMedExtracter/prescription/temp_xml/fc7...  1809  1816  PREF
# 4116  ../DailyMedExtracter/prescription/temp_xml/e99...   272   279  PREF
# 4119  ../DailyMedExtracter/prescription/temp_xml/11b...    62    77   SYN
# 4122  ../DailyMedExtracter/prescription/temp_xml/872...    78    96  PREF
#
#                        Annotation  \
# 0                HYPERSENSITIVITY
# 1                HYPERSENSITIVITY
# 2                HYPERSENSITIVITY
# 3                    HYPERTENSION
# 6                 HYPERTHYROIDISM
# 8                HYPERSENSITIVITY
# 9                HYPERSENSITIVITY
# 10               HYPERSENSITIVITY
# 11                         ANURIA
# 13               HYPERSENSITIVITY
# 14               HYPERSENSITIVITY
# 15                         ANURIA
# 17               HYPERSENSITIVITY
# 18               HYPERSENSITIVITY
# 19               HYPERSENSITIVITY
# 20               HYPERSENSITIVITY
# 21               HYPERSENSITIVITY
# 22                         ANURIA
# 26               HYPERSENSITIVITY
# 27               HYPERSENSITIVITY
# 28               HYPERSENSITIVITY
# 29               HYPERSENSITIVITY
# 30               HYPERSENSITIVITY
# 31               HYPERSENSITIVITY
# 32               HYPERSENSITIVITY
# 33               HYPERSENSITIVITY
# 34                         ANURIA
# 36               HYPERSENSITIVITY
# 44               HYPERSENSITIVITY
# 45               HYPERSENSITIVITY
# ...                           ...
# 3778               CARDIAC ARREST
# 3794    VENTRICULAR SEPTAL DEFECT
# 3798             HYPERSENSITIVITY
# 3805  ACUTE MYOCARDIAL INFARCTION
# 3813     STEVENS-JOHNSON SYNDROME
# 3820                LIVER DISEASE
# 3830             HYPERSENSITIVITY
# 3835                       ASTHMA
# 3843                HEART DISEASE
# 3874             HYPERSENSITIVITY
# 3882                LIVER DISEASE
# 3887             HYPERSENSITIVITY
# 3891      CORONARY ARTERY DISEASE
# 3927      CORONARY ARTERY DISEASE
# 3963               CARDIAC ARREST
# 3976      CORONARY ARTERY DISEASE
# 4007             HYPERSENSITIVITY
# 4012             HYPERSENSITIVITY
# 4019                    PORPHYRIA
# 4021             HYPERSENSITIVITY
# 4031                         ACNE
# 4033                 PANCREATITIS
# 4052        PRADER-WILLI SYNDROME
# 4070             HYPERSENSITIVITY
# 4074  PELVIC INFLAMMATORY DISEASE
# 4103                      DISEASE
# 4113                     ISCHEMIA
# 4116                     SYNDROME
# 4119             HYPERSENSITIVITY
# 4122          ATRIAL FIBRILLATION
#
#                                                 Context  \
# 0                Known hypersensitivity to Rose Bengal.
# 1     Hypersensitivity to Dapsone and/or its derivat...
# 2           Hypersensitivity to any of the ingredients.
# 3     ['Hypertension; toxemia; pregnancy; and hypers...
# 6     Symptomatic Hyperthyroidism\nSymptomatic Hyper...
# 8     Hypersensitivity to any component of this prod...
# 9     Hypersensitivity to any component of this medi...
# 10    ['\n                     ', 'CONTRAINDICATIONS...
# 11    Anuria. Known hypersensitivity to chlorthalido...
# 13    [None, 'CONTRAINDICATIONS ', 'Hypersensitivity...
# 14    AZOPT\n\n\n                           \nHypers...
# 15    Anuria. Known hypersensitivity to indapamide o...
# 17    Hypersensitivity to olsalazine, other salicyla...
# 18    ['\n                     ', 'Systemic fungal i...
# 19    MONUROL is contraindicated in patients with kn...
# 20    ETHYOL is contraindicated in patients with kno...
# 21    NIPENT is contraindicated in patients who have...
# 22    Anuria, hepatic coma or precoma, known allergy...
# 26    Contraindicated in persons showing hypersensit...
# 27    [None, 'A previous hypersensitivity reaction t...
# 28    FOSCAVIR is contraindicated in patients with c...
# 29    TRIDIONE is contraindicated in patients with a...
# 30    Daunorubicin hydrochloride is contraindicated ...
# 31    Chlordiazepoxide Hydrochloride Capsule is cont...
# 32    [None, ' Etomidate is contraindicated in patie...
# 33    ANZEMET Tablets are contraindicated in patient...
# 34    Anuria.\n\nHypersensitivity to any component o...
# 36    [None, 'Hypersensitivity to HydrALAZINE ; coro...
# 44    Mitoxantrone injection (concentrate) is contra...
# 45    Methsuximide should not be used in patients wi...
# ...                                                 ...
# 3778  ['Esmolol hydrochloride injection is contraind...
# 3794  Fluorouracil may cause fetal harm when adminis...
# 3798  \n                     \nHypersensitivity\nCef...
# 3805  [None, '\n                           ', 'Do no...
# 3813  ['\n                           ', 'SUSTIVA is ...
# 3820  ['Ezetimibe is contraindicated in the followin...
# 3830  Clomiphene citrate is contraindicated in patie...
# 3835  ['MITIGO is contraindicated in patients with:'...
# 3843  ['\n                           ', 'Ischemic he...
# 3874  ['\n                           ', 'Hypersensit...
# 3882  [None, 'Active liver disease, which may includ...
# 3887  Glyburide tablets are contraindicated in patie...
# 3891  ['Zolmitriptan tablets are contraindicated in ...
# 3927  ['Eletriptan hydrobromide tablets are contrain...
# 3963  Potassium citrate extended-release tablets are...
# 3976  ['Rizatriptan benzoate tablets are contraindic...
# 4007  ['INVIRASE is contraindicated in patients with...
# 4012  ['\n                     ', 'Hypersensitivity ...
# 4019  ['Griseofulvin is contraindicated in patients ...
# 4021  Ribavirin capsules may cause birth defects and...
# 4031  Retinoids may cause fetal harm when administer...
# 4033  ['VIBERZI\xa0is contraindicated in patients:',...
# 4052  \n                           \nAcute critical ...
# 4070  [None, '\n                           ', 'Hyper...
# 4074  ['The use of LILETTA is contraindicated when o...
# 4103  ['\n                     ', 'Divalproex sodium...
# 4113  ['\n                     ', 'APTIVUS is contra...
# 4116  [None, '\n                     ', 'When using'...
# 4119  Targretin gel 1% is contraindicated in patient...
# 4122  MULTAQ is contraindicated in patients with:\n\...
#
#                                             DO_ID    DB_ID  \
# 0        http://purl.obolibrary.org/obo/DOID_1205  DB14215
# 1        http://purl.obolibrary.org/obo/DOID_1205  DB00250
# 2        http://purl.obolibrary.org/obo/DOID_1205  DB00180
# 3       http://purl.obolibrary.org/obo/DOID_10763  DB00353
# 6        http://purl.obolibrary.org/obo/DOID_7998  DB09134
# 8        http://purl.obolibrary.org/obo/DOID_1205  DB06794
# 9        http://purl.obolibrary.org/obo/DOID_1205  DB00200
# 10       http://purl.obolibrary.org/obo/DOID_1205  DB06824
# 11       http://purl.obolibrary.org/obo/DOID_2983  DB00310
# 13       http://purl.obolibrary.org/obo/DOID_1205  DB00868
# 14       http://purl.obolibrary.org/obo/DOID_1205  DB01194
# 15       http://purl.obolibrary.org/obo/DOID_2983  DB00808
# 17       http://purl.obolibrary.org/obo/DOID_1205  DB01250
# 18       http://purl.obolibrary.org/obo/DOID_1205  DB14681
# 19       http://purl.obolibrary.org/obo/DOID_1205  DB00828
# 20       http://purl.obolibrary.org/obo/DOID_1205  DB01143
# 21       http://purl.obolibrary.org/obo/DOID_1205  DB00552
# 22       http://purl.obolibrary.org/obo/DOID_2983  DB00524
# 26       http://purl.obolibrary.org/obo/DOID_1205  DB00809
# 27       http://purl.obolibrary.org/obo/DOID_1205  DB00417
# 28       http://purl.obolibrary.org/obo/DOID_1205  DB00529
# 29       http://purl.obolibrary.org/obo/DOID_1205  DB00347
# 30       http://purl.obolibrary.org/obo/DOID_1205  DB00694
# 31       http://purl.obolibrary.org/obo/DOID_1205  DB00475
# 32       http://purl.obolibrary.org/obo/DOID_1205  DB00292
# 33       http://purl.obolibrary.org/obo/DOID_1205  DB00757
# 34       http://purl.obolibrary.org/obo/DOID_2983  DB00880
# 36       http://purl.obolibrary.org/obo/DOID_1205  DB01275
# 44       http://purl.obolibrary.org/obo/DOID_1205  DB01204
# 45       http://purl.obolibrary.org/obo/DOID_1205  DB05246
# ...                                           ...      ...
# 3778  http://purl.obolibrary.org/obo/DOID_0060319  DB00187
# 3794     http://purl.obolibrary.org/obo/DOID_1657  DB00544
# 3798     http://purl.obolibrary.org/obo/DOID_1205  DB01212
# 3805     http://purl.obolibrary.org/obo/DOID_9408  DB00246
# 3813  http://purl.obolibrary.org/obo/DOID_0050426  DB00625
# 3820      http://purl.obolibrary.org/obo/DOID_409  DB00973
# 3830     http://purl.obolibrary.org/obo/DOID_1205  DB00882
# 3835     http://purl.obolibrary.org/obo/DOID_2841  DB00295
# 3843      http://purl.obolibrary.org/obo/DOID_114  DB00918
# 3874     http://purl.obolibrary.org/obo/DOID_1205  DB01095
# 3882      http://purl.obolibrary.org/obo/DOID_409  DB01076
# 3887     http://purl.obolibrary.org/obo/DOID_1205  DB01016
# 3891     http://purl.obolibrary.org/obo/DOID_3393  DB00315
# 3927     http://purl.obolibrary.org/obo/DOID_3393  DB00216
# 3963  http://purl.obolibrary.org/obo/DOID_0060319  DB04272
# 3976     http://purl.obolibrary.org/obo/DOID_3393  DB00953
# 4007     http://purl.obolibrary.org/obo/DOID_1205  DB01232
# 4012     http://purl.obolibrary.org/obo/DOID_1205  DB01211
# 4019    http://purl.obolibrary.org/obo/DOID_13268  DB00400
# 4021     http://purl.obolibrary.org/obo/DOID_1205  DB00811
# 4031     http://purl.obolibrary.org/obo/DOID_6543  DB00799
# 4033     http://purl.obolibrary.org/obo/DOID_4989  DB09272
# 4052    http://purl.obolibrary.org/obo/DOID_11983  DB00052
# 4070     http://purl.obolibrary.org/obo/DOID_1205  DB00289
# 4074     http://purl.obolibrary.org/obo/DOID_1003  DB00367
# 4103        http://purl.obolibrary.org/obo/DOID_4  DB00313
# 4113      http://purl.obolibrary.org/obo/DOID_326  DB00932
# 4116      http://purl.obolibrary.org/obo/DOID_225  DB00472
# 4119     http://purl.obolibrary.org/obo/DOID_1205  DB00307
# 4122  http://purl.obolibrary.org/obo/DOID_0060224  DB04855
#
#                       DrugName
# 0               Rose Bengal AT
# 1                      DAPSONE
# 2        FLUNISOLIDE ANHYDROUS
# 3             METHYLERGONOVINE
# 6                     IOVERSOL
# 8                   LODOXAMIDE
# 9             HYDROXOCOBALAMIN
# 10                   TRIENTINE
# 11              CHLORTHALIDONE
# 13                 Benzonatate
# 14                BRINZOLAMIDE
# 15                  INDAPAMIDE
# 17                  olsalazine
# 18                   CORTISONE
# 19                  FOSFOMYCIN
# 20        AMIFOSTINE ANHYDROUS
# 21                 PENTOSTATIN
# 22                  METOLAZONE
# 26                 TROPICAMIDE
# 27                PENICILLIN V
# 28                   foscarnet
# 29               TRIMETHADIONE
# 30                DAUNORUBICIN
# 31            CHLORDIAZEPOXIDE
# 32                   ETOMIDATE
# 33                  DOLASETRON
# 34              Chlorothiazide
# 36     Hydralazine|Hydralazine
# 44                MITOXANTRONE
# 45                METHSUXIMIDE
# ...                        ...
# 3778                   ESMOLOL
# 3794              fluorouracil
# 3798               CEFTRIAXONE
# 3805               ZIPRASIDONE
# 3813                 efavirenz
# 3820                 EZETIMIBE
# 3830                CLOMIPHENE
# 3835                  MORPHINE
# 3843               almotriptan
# 3874               FLUVASTATIN
# 3882              ATORVASTATIN
# 3887                 GLYBURIDE
# 3891              Zolmitriptan
# 3927                eletriptan
# 3963     ANHYDROUS CITRIC ACID
# 3976               RIZATRIPTAN
# 4007                saquinavir
# 4012            CLARITHROMYCIN
# 4019              GRISEOFULVIN
# 4021                 RIBAVIRIN
# 4031                TAZAROTENE
# 4033               ELUXADOLINE
# 4052                SOMATROPIN
# 4070               Atomoxetine
# 4074            LEVONORGESTREL
# 4103             VALPROIC ACID
# 4113                tipranavir
# 4116                FLUOXETINE
# 4119                BEXAROTENE
# 4122               Dronedarone
#
# [998 rows x 9 columns]

# %%
# !pip install snorkel --user
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip/http' or its parent directory is not owned by the current user and the cache has been disabled. Please check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned by the current user and caching wheels has been disabled. check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Requirement already satisfied: snorkel in /home/jovyan/.local/lib/python3.7/site-packages (0.9.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.33.0 in /opt/conda/lib/python3.7/site-packages (from snorkel) (4.40.0)
# Requirement already satisfied: scipy<2.0.0,>=1.2.0 in /opt/conda/lib/python3.7/site-packages (from snorkel) (1.3.2)
# Requirement already satisfied: scikit-learn<0.22.0,>=0.20.2 in /opt/conda/lib/python3.7/site-packages (from snorkel) (0.20.3)
# Requirement already satisfied: torch<1.2.0,>=1.1.0 in /home/jovyan/.local/lib/python3.7/site-packages (from snorkel) (1.1.0)
# Requirement already satisfied: pandas<0.26.0,>=0.25.0 in /home/jovyan/.local/lib/python3.7/site-packages (from snorkel) (0.25.3)
# Requirement already satisfied: numpy<2.0.0,>=1.16.0 in /opt/conda/lib/python3.7/site-packages (from snorkel) (1.16.2)
# Requirement already satisfied: tensorboardX<2.0,>=1.6 in /home/jovyan/.local/lib/python3.7/site-packages (from snorkel) (1.9)
# Requirement already satisfied: networkx<2.4,>=2.2 in /home/jovyan/.local/lib/python3.7/site-packages (from snorkel) (2.3)
# Requirement already satisfied: munkres==1.1.2 in /home/jovyan/.local/lib/python3.7/site-packages (from snorkel) (1.1.2)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas<0.26.0,>=0.25.0->snorkel) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.7/site-packages (from pandas<0.26.0,>=0.25.0->snorkel) (2.8.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from tensorboardX<2.0,>=1.6->snorkel) (1.13.0)
# Requirement already satisfied: protobuf>=3.8.0 in /opt/conda/lib/python3.7/site-packages (from tensorboardX<2.0,>=1.6->snorkel) (3.9.2)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx<2.4,>=2.2->snorkel) (4.4.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from protobuf>=3.8.0->tensorboardX<2.0,>=1.6->snorkel) (42.0.2.post20191201)

# %%
import snorkel

# %%
import pandas as pd

# %%
unlabeled_df  = pd.read_csv('unlabeled/raw_cleaned.csv')
unlabeled_df = unlabeled_df[['disease','DO_ID','DB_ID','DrugName','Set_ID','Context','Section']]
unlabeled_df.head()
# Out:
#          disease         DO_ID    DB_ID         DrugName  \
# 0  paraganglioma  DOID_0050773  DB00752  TRANYLCYPROMINE
# 1       syndrome      DOID_225  DB00752  TRANYLCYPROMINE
# 2      hay fever     DOID_4481  DB00752  TRANYLCYPROMINE
# 3  paraganglioma  DOID_0050773  DB00752  TRANYLCYPROMINE
# 4       syndrome      DOID_225  DB00752  TRANYLCYPROMINE
#
#                                  Set_ID  \
# 0  b72d8187-dfcc-4ea0-b5e9-c0be95b69a27
# 1  b72d8187-dfcc-4ea0-b5e9-c0be95b69a27
# 2  b72d8187-dfcc-4ea0-b5e9-c0be95b69a27
# 3  6a0b609b-0625-4c26-91a1-59ee3ece3ddf
# 4  6a0b609b-0625-4c26-91a1-59ee3ece3ddf
#
#                                              Context           Section
# 0  concomitant use or use in rapid succession wit...  Contraindication
# 1  concomitant use or use in rapid succession wit...  Contraindication
# 2  concomitant use or use in rapid succession wit...  Contraindication
# 3  concomitant use or use in rapid succession wit...  Contraindication
# 4  concomitant use or use in rapid succession wit...  Contraindication

# %%
crowd1_df =pd.read_csv('crowd/match_crowd_data.csv')
#crowd1_df.head()
crowd1_df = crowd1_df[['disease','DO_ID','DB_ID','Drug_name','Label_ID','Set_ID','Context','Section','relation']]
crowd1_df.head()
# Out:
#                   disease       DO_ID    DB_ID     Drug_name  \
# 0            hypertension  DOID_10763  DB00657  Mecamylamine
# 1  malignant hypertension  DOID_10824  DB00657  Mecamylamine
# 2            hypertension  DOID_10763  DB00401   Nisoldipine
# 3            hypertension  DOID_10763  DB00612    Bisoprolol
# 4            hypertension  DOID_10763  DB00960      Pindolol
#
#                                    Label_ID  \
# 0  976f404f-4857-4bad-9a3c-9bf3d5ca9f5b.xml
# 1  976f404f-4857-4bad-9a3c-9bf3d5ca9f5b.xml
# 2  ce733b39-7857-4538-92d6-1c68a4e4eb75.xml
# 3  c818c38d-ee37-4ceb-b078-611483b4f743.xml
# 4  d4078b63-30ad-435b-a081-4d90562962b5.xml
#
#                                  Set_ID  \
# 0  c6822ce4-e741-4366-b72a-5f5146354f97
# 1  c6822ce4-e741-4366-b72a-5f5146354f97
# 2  a6a8a8ba-3966-4f37-a58b-44d3b05bdc4e
# 3  c818c38d-ee37-4ceb-b078-611483b4f743
# 4  b5a5a1e9-ee9b-41b1-b2d5-5f5834b816a7
#
#                                              Context      Section   relation
# 0  For the management of moderately severe to sev...  Indications  treatment
# 1  For the management of moderately severe to sev...  Indications  treatment
# 2  Nisoldipine extended-release tablets are indic...  Indications  treatment
# 3  Bisoprolol fumarate tablets, USP are indicated...  Indications  treatment
# 4  Pindolol tablets are indicated in the manageme...  Indications  treatment

# %%
crowd2_df =pd.read_csv('crowd/crowd_2nd.csv')
crowd2_df = crowd2_df[['disease','DO_ID','DB_ID','Drug_name','Label_ID','Set_ID','Context','Section','relation']]
crowd2_df.head()
# Out:
#                    disease       DO_ID    DB_ID              Drug_name  \
# 0         thrombocytopenia   DOID_1588  DB05332            ROMIPLOSTIM
# 1  urinary tract infection  DOID_13148  DB04272  ANHYDROUS CITRIC ACID
# 2             hypertension  DOID_10763  DB00177              VALSARTAN
# 3         rhabdomyosarcoma   DOID_3247  DB00970           DACTINOMYCIN
# 4                  rosacea   DOID_8881  DB00916          METRONIDAZOLE
#
#                                    Label_ID  \
# 0  0065c77d-0a8e-48d8-8f1f-fc78f6cacc41.xml
# 1  01c62b42-cd67-4a44-8ac9-7daa079ce528.xml
# 2  02359e00-234a-4d27-a824-65dcb8cf3482.xml
# 3  028310eb-7a34-470d-9041-cee58fd3622c.xml
# 4  030c1db3-fbce-4963-bc60-7438d927c8b4.xml
#
#                                  Set_ID  \
# 0  c45f9a58-37c1-4f76-8e36-97d38c577037
# 1  39f46084-fc4b-4bfc-91cb-9be7e647655a
# 2  fb3ef419-fb3b-4a40-9151-938741d26ade
# 3  5dc19443-1bac-4bb4-893e-e791b72b3d26
# 4  970a767a-7a65-4cdf-84fe-4dbe0a77b80a
#
#                                              Context           Section  \
# 0  Nplate is indicated for the treatment of throm...       Indications
# 1  Patients with hyperkalemia (or who have condit...  Contraindication
# 2  Valsartan tablets are an angiotensin II recept...       Indications
# 3  Dactinomycin for injection is an actinomycin i...       Indications
# 4  Metronidazole topical lotion is indicated for ...       Indications
#
#            relation
# 0         treatment
# 1  contraindication
# 2         treatment
# 3         treatment
# 4         treatment

# %%
len(crowd1_df),len(crowd2_df)
# Out:
# (1574, 611)

# %%
crowd_df = crowd1_df.append(crowd2_df)
len(crowd_df)
# Out:
# 2185

# %%
crowd_df[crowd_df.duplicated(subset=['Label_ID','DO_ID','Section'], keep=False)].sort_values(by=['Label_ID','DO_ID'])
# Out:
#                                              disease         DO_ID    DB_ID  \
# 918                            prader-willi syndrome    DOID_11983  DB00052
# 13                             Prader-Willi Syndrome    DOID_11983  DB00052
# 574                                        influenza     DOID_8469  DB00558
# 117                                        influenza     DOID_8469  DB00558
# 385                    lung non-small cell carcinoma     DOID_3908  DB00530
# 118                       non-small cell lung cancer     DOID_3908  DB00530
# 876                              atrial fibrillation  DOID_0060224  DB00908
# 121                              atrial fibrillation  DOID_0060224  DB00908
# 579                              bacterial vaginosis     DOID_3385  DB00911
# 199                              Bacterial Vaginosis     DOID_3385  DB00911
# 383                    lung non-small cell carcinoma     DOID_3908  DB00642
# 202                       non-small cell lung cancer     DOID_3908  DB00642
# 619                                    ewing sarcoma     DOID_3369  DB00970
# 262                                    Ewing sarcoma     DOID_3369  DB00970
# 462                                         lymphoma  DOID_0060058  DB09053
# 325                                         lymphoma  DOID_0060058  DB09053
# 460                     chronic lymphocytic leukemia     DOID_1040  DB09053
# 326                     chronic lymphocytic leukemia     DOID_1040  DB09053
# 659                                  motion sickness     DOID_2951  DB01174
# 424                                  motion sickness     DOID_2951  DB01174
# 382                    lung non-small cell carcinoma     DOID_3908  DB05578
# 431                       non-small cell lung cancer     DOID_3908  DB05578
# 899                           esophageal candidiasis    DOID_13146  DB00520
# 435                           esophageal candidiasis    DOID_13146  DB00520
# 324                               tuberous sclerosis    DOID_13515  DB01590
# 469                               tuberous sclerosis    DOID_13515  DB01590
# 322                             renal cell carcinoma     DOID_4450  DB01590
# 470                                              RCC     DOID_4450  DB01590
# 323                            kidney angiomyolipoma     DOID_8411  DB01590
# 468                             renal angiomyolipoma     DOID_8411  DB01590
# 602                                    toxoplasmosis     DOID_9965  DB00359
# 477                                    Toxoplasmosis     DOID_9965  DB00359
# 846                         type 2 diabetes mellitus     DOID_9352  DB01124
# 503          non-insulin-dependent diabetes mellitus     DOID_9352  DB01124
# 719                         type 2 diabetes mellitus     DOID_9352  DB01276
# 549                         type 2 diabetes mellitus     DOID_9352  DB01276
# 375  human immunodeficiency virus infectious disease      DOID_526  DB01232
# 570                                    HIV infection      DOID_526  DB01232
# 647                             thyroid gland cancer     DOID_1781  DB08911
# 585                                   thyroid cancer     DOID_1781  DB08911
# 646                    lung non-small cell carcinoma     DOID_3908  DB08911
# 584                       non-small cell lung cancer     DOID_3908  DB08911
# 141                   congenital adrenal hyperplasia  DOID_0050811  DB00443
# 589                   Congenital adrenal hyperplasia  DOID_0050811  DB00443
# 490                                      tonsillitis    DOID_10456  DB01416
# 604                                      tonsillitis    DOID_10456  DB01416
#
#          Drug_name                                  Label_ID  \
# 918   Somatotropin  0684f2d9-9697-4134-aa35-ec180bdd790c.xml
# 13      SOMATROPIN  0684f2d9-9697-4134-aa35-ec180bdd790c.xml
# 574      Zanamivir  342b7e19-49d6-4d0b-950a-cc00f4b79924.xml
# 117      ZANAMIVIR  342b7e19-49d6-4d0b-950a-cc00f4b79924.xml
# 385      Erlotinib  34a616f7-8301-4dba-bb2f-a27691e3e08e.xml
# 118      ERLOTINIB  34a616f7-8301-4dba-bb2f-a27691e3e08e.xml
# 876      Quinidine  35843ff3-e830-43ff-a9c0-ad7abdcbda15.xml
# 121      QUINIDINE  35843ff3-e830-43ff-a9c0-ad7abdcbda15.xml
# 579     Tinidazole  530af487-7e0b-4ad5-a45b-3f7d9b1b71ae.xml
# 199     TINIDAZOLE  530af487-7e0b-4ad5-a45b-3f7d9b1b71ae.xml
# 383     Pemetrexed  55e080d5-d7a8-45b8-9d52-11629342cb7c.xml
# 202     Pemetrexed  55e080d5-d7a8-45b8-9d52-11629342cb7c.xml
# 619   Dactinomycin  73021e70-f3cf-3d8a-e053-2a91aa0a09fe.xml
# 262   DACTINOMYCIN  73021e70-f3cf-3d8a-e053-2a91aa0a09fe.xml
# 462      Ibrutinib  832c4df6-a63c-49cc-9c0c-70c59d057661.xml
# 325      IBRUTINIB  832c4df6-a63c-49cc-9c0c-70c59d057661.xml
# 460      Ibrutinib  832c4df6-a63c-49cc-9c0c-70c59d057661.xml
# 326      IBRUTINIB  832c4df6-a63c-49cc-9c0c-70c59d057661.xml
# 659  Phenobarbital  a40749c5-9e43-4b29-8994-dfbd1af6d61e.xml
# 424  PHENOBARBITAL  a40749c5-9e43-4b29-8994-dfbd1af6d61e.xml
# 382    Ramucirumab  a8c8c7e7-3faf-4d83-9b4a-b96548ffaed8.xml
# 431    ramucirumab  a8c8c7e7-3faf-4d83-9b4a-b96548ffaed8.xml
# 899    Caspofungin  ab92e590-88da-4009-88cc-5942082eb643.xml
# 435    CASPOFUNGIN  ab92e590-88da-4009-88cc-5942082eb643.xml
# 324     Everolimus  beceb18a-7957-4a80-bcc1-b4a0b05ef106.xml
# 469     EVEROLIMUS  beceb18a-7957-4a80-bcc1-b4a0b05ef106.xml
# 322     Everolimus  beceb18a-7957-4a80-bcc1-b4a0b05ef106.xml
# 470     EVEROLIMUS  beceb18a-7957-4a80-bcc1-b4a0b05ef106.xml
# 323     Everolimus  beceb18a-7957-4a80-bcc1-b4a0b05ef106.xml
# 468     EVEROLIMUS  beceb18a-7957-4a80-bcc1-b4a0b05ef106.xml
# 602   Sulfadiazine  c0c1e237-a373-48c0-b9be-a9501f9a4b2d.xml
# 477   SULFADIAZINE  c0c1e237-a373-48c0-b9be-a9501f9a4b2d.xml
# 846    Tolbutamide  cd4a83cf-3a04-4d26-bc54-b4c539237619.xml
# 503    TOLBUTAMIDE  cd4a83cf-3a04-4d26-bc54-b4c539237619.xml
# 719      Exenatide  e0cceca4-759d-4ca9-be65-23a0199e5766.xml
# 549      exenatide  e0cceca4-759d-4ca9-be65-23a0199e5766.xml
# 375     Saquinavir  e981c067-b7f7-440b-a4d3-1cd79038af4a.xml
# 570     saquinavir  e981c067-b7f7-440b-a4d3-1cd79038af4a.xml
# 647     Trametinib  f2f2e14e-f72f-4187-86d4-225c9475e13f.xml
# 585     TRAMETINIB  f2f2e14e-f72f-4187-86d4-225c9475e13f.xml
# 646     Trametinib  f2f2e14e-f72f-4187-86d4-225c9475e13f.xml
# 584     TRAMETINIB  f2f2e14e-f72f-4187-86d4-225c9475e13f.xml
# 141  Betamethasone  f3b194d6-1add-42b4-a980-a0539e06bc9e.xml
# 589  Betamethasone  f3b194d6-1add-42b4-a980-a0539e06bc9e.xml
# 490    Cefpodoxime  fa487191-4b42-4a56-97f6-4a7cafdc6e93.xml
# 604    CEFPODOXIME  fa487191-4b42-4a56-97f6-4a7cafdc6e93.xml
#
#                                    Set_ID  \
# 918  58d84ffa-4056-4e36-ad67-7bd4aef444a5
# 13   58d84ffa-4056-4e36-ad67-7bd4aef444a5
# 574  12ff22f6-20b5-4fa8-9028-58f87e169ff5
# 117  12ff22f6-20b5-4fa8-9028-58f87e169ff5
# 385  5d97f401-4853-4a9a-907d-21e8a4d16088
# 118  5d97f401-4853-4a9a-907d-21e8a4d16088
# 876  02a34403-3cb9-4de7-8c40-9da281a8e5e1
# 121  02a34403-3cb9-4de7-8c40-9da281a8e5e1
# 579  4e03b4ac-c88a-4044-9d58-0cfcda3db53c
# 199  4e03b4ac-c88a-4044-9d58-0cfcda3db53c
# 383  f5a860f3-37ec-429c-ae04-9c88d7c55c08
# 202  f5a860f3-37ec-429c-ae04-9c88d7c55c08
# 619  9914e793-a49c-eb00-1ab7-f606c786fe25
# 262  9914e793-a49c-eb00-1ab7-f606c786fe25
# 462  0dfd0279-ff17-4ea9-89be-9803c71bab44
# 325  0dfd0279-ff17-4ea9-89be-9803c71bab44
# 460  0dfd0279-ff17-4ea9-89be-9803c71bab44
# 326  0dfd0279-ff17-4ea9-89be-9803c71bab44
# 659  ffcaa218-ed6a-4557-9645-b9a91128a214
# 424  ffcaa218-ed6a-4557-9645-b9a91128a214
# 382  c6080942-dee6-423e-b688-1272c2ae90d4
# 431  c6080942-dee6-423e-b688-1272c2ae90d4
# 899  722facc6-d4ea-4975-b83e-3ae63df69ed2
# 435  722facc6-d4ea-4975-b83e-3ae63df69ed2
# 324  2150f73a-179b-4afc-b8ce-67c85cc72f04
# 469  2150f73a-179b-4afc-b8ce-67c85cc72f04
# 322  2150f73a-179b-4afc-b8ce-67c85cc72f04
# 470  2150f73a-179b-4afc-b8ce-67c85cc72f04
# 323  2150f73a-179b-4afc-b8ce-67c85cc72f04
# 468  2150f73a-179b-4afc-b8ce-67c85cc72f04
# 602  10549cba-9c15-4d2e-a68c-5afbc178591d
# 477  10549cba-9c15-4d2e-a68c-5afbc178591d
# 846  3995eed8-39ec-ce5e-8cc2-062f93445c8d
# 503  3995eed8-39ec-ce5e-8cc2-062f93445c8d
# 719  c621d002-b7bf-4f3a-af68-4f70fd298d05
# 549  c621d002-b7bf-4f3a-af68-4f70fd298d05
# 375  b8b53129-06ab-4143-b9b7-7675e49a52ef
# 570  b8b53129-06ab-4143-b9b7-7675e49a52ef
# 647  0002ad27-779d-42ab-83b5-bc65453412a1
# 585  0002ad27-779d-42ab-83b5-bc65453412a1
# 646  0002ad27-779d-42ab-83b5-bc65453412a1
# 584  0002ad27-779d-42ab-83b5-bc65453412a1
# 141  024cd444-04e2-441a-9863-9e5db741e657
# 589  024cd444-04e2-441a-9863-9e5db741e657
# 490  8519a9d8-7106-4545-bc58-859ee9a6708e
# 604  8519a9d8-7106-4545-bc58-859ee9a6708e
#
#                                                Context      Section  \
# 918  OMNITROPE(r) is a recombinant human growth hor...  Indications
# 13   OMNITROPE(r) is a recombinant human growth hor...  Indications
# 574  RELENZA, an influenza neuraminidase inhibitor,...  Indications
# 117  RELENZA, an influenza neuraminidase inhibitor,...  Indications
# 385  Erlotinib tablets are a kinase inhibitor indic...  Indications
# 118  Erlotinib tablets are a kinase inhibitor indic...  Indications
# 876  In patients with symptomatic atrial fibrillati...  Indications
# 121  In patients with symptomatic atrial fibrillati...  Indications
# 579  Tinidazole Tablets is a nitroimidazole antimic...  Indications
# 199  Tinidazole Tablets is a nitroimidazole antimic...  Indications
# 383  ALIMTA\r\n(r)\r\n \r\nin combination with pemb...  Indications
# 202  ALIMTA\r\n (r)\r\n \r\n in combination with pe...  Indications
# 619  COSMEGEN is an actinomycin indicated for the t...  Indications
# 262  COSMEGEN is an actinomycin indicated for the t...  Indications
# 462  IMBRUVICA is a kinase inhibitor indicated for ...  Indications
# 325  IMBRUVICA is a kinase inhibitor indicated for ...  Indications
# 460  IMBRUVICA is a kinase inhibitor indicated for ...  Indications
# 326  IMBRUVICA is a kinase inhibitor indicated for ...  Indications
# 659  \r\nSedative. Sedation is obtainable within an...  Indications
# 424  Sedative. Sedation is obtainable within an hou...  Indications
# 382  CYRAMZA\r\n(r)\r\n \r\nas a single agent or in...  Indications
# 431  CYRAMZA\r\n (r)\r\n \r\n as a single agent or ...  Indications
# 899  Caspofungin acetate for injection is an echino...  Indications
# 435  Caspofungin acetate for injection is an echino...  Indications
# 324  AFINITOR is a kinase inhibitor indicated for t...  Indications
# 469  AFINITOR is a kinase inhibitor indicated for t...  Indications
# 322  AFINITOR is a kinase inhibitor indicated for t...  Indications
# 470  AFINITOR is a kinase inhibitor indicated for t...  Indications
# 323  AFINITOR is a kinase inhibitor indicated for t...  Indications
# 468  AFINITOR is a kinase inhibitor indicated for t...  Indications
# 602  SulfADIAZine tablets USP are indicated in the ...  Indications
# 477  SulfADIAZine tablets USP are indicated in the ...  Indications
# 846  Tolbutamide tablets are indicated as an adjunc...  Indications
# 503  Tolbutamide tablets are indicated as an adjunc...  Indications
# 719  BYETTA is a glucagon-like peptide-1 (GLP-1) re...  Indications
# 549  BYETTA is a glucagon-like peptide-1 (GLP-1) re...  Indications
# 375  INVIRASE in combination with ritonavir and oth...  Indications
# 570  INVIRASE in combination with ritonavir and oth...  Indications
# 647  MEKINIST is a kinase inhibitor indicated as a ...  Indications
# 585  MEKINIST is a kinase inhibitor indicated as a ...  Indications
# 646  MEKINIST is a kinase inhibitor indicated as a ...  Indications
# 584  MEKINIST is a kinase inhibitor indicated as a ...  Indications
# 141  When oral therapy is not feasible, the \r\nint...  Indications
# 589  When oral therapy is not feasible, the\r\n int...  Indications
# 490  Cefpodoxime proxetil is indicated for the trea...  Indications
# 604  Cefpodoxime proxetil is indicated for the trea...  Indications
#
#              relation
# 918         treatment
# 13          treatment
# 574         treatment
# 117         treatment
# 385         treatment
# 118         treatment
# 876            relief
# 121         treatment
# 579         treatment
# 199         treatment
# 383         treatment
# 202         treatment
# 619         treatment
# 262         treatment
# 462         treatment
# 325         treatment
# 460         treatment
# 326         treatment
# 659         treatment
# 424         treatment
# 382         treatment
# 431         treatment
# 899         treatment
# 435         treatment
# 324  contraindication
# 469         treatment
# 322         treatment
# 470         treatment
# 323         treatment
# 468         treatment
# 602         treatment
# 477         treatment
# 846         treatment
# 503         treatment
# 719            relief
# 549         treatment
# 375         treatment
# 570         treatment
# 647         treatment
# 585         treatment
# 646         treatment
# 584         treatment
# 141         treatment
# 589         treatment
# 490         treatment
# 604         treatment

# %%
#crowd_df= crowd_df.drop_duplicates(subset=['Label_ID','DO_ID','Section'], keep='last')
crowd_df= crowd_df.drop_duplicates(subset=['Label_ID','DO_ID','Section'], keep='last')
len(crowd_df)
# Out:
# 2162

# %%
unlabeled_df= unlabeled_df.rename(columns={'DrugName':'Drug_name'}).append(crowd_df)

# %%
unlabeled_df.drop_duplicates(subset=['Set_ID','DO_ID'], keep='last', inplace=True)

# %%
test_df =pd.read_csv('expert/clean_expert_resolved_all.csv')
test_df = test_df[['DO_ID','DB_ID','Drug_name','Set_ID','Context','Section','relation']]
test_df.head()
# Out:
#         DO_ID    DB_ID    Drug_name                                Set_ID  \
# 0  DOID_10763  DB00401  Nisoldipine  a6a8a8ba-3966-4f37-a58b-44d3b05bdc4e
# 1  DOID_10763  DB00612   Bisoprolol  c818c38d-ee37-4ceb-b078-611483b4f743
# 2  DOID_10763  DB00960     Pindolol  b5a5a1e9-ee9b-41b1-b2d5-5f5834b816a7
# 3  DOID_10763  DB00876   Eprosartan  64fbc500-3b77-4c9c-8576-b3ec5f6655a5
# 4  DOID_10763  DB00598    Labetalol  f81baebd-424d-4d39-893c-d9d622377c53
#
#                                              Context      Section  \
# 0  Nisoldipine extended-release tablets are indic...  Indications
# 1  Bisoprolol fumarate tablets, USP are indicated...  Indications
# 2  Pindolol tablets are indicated in the manageme...  Indications
# 3  Eprosartan mesylate tablets are indicated for ...  Indications
# 4  Labetalol hydrochloride tablets, USP are indic...  Indications
#
#                 relation
# 0  Indication: Treatment
# 1  Indication: Treatment
# 2  Indication: Treatment
# 3  Indication: Treatment
# 4  Indication: Treatment

# %%
len(test_df)
# Out:
# 358

# %%
diff = pd.concat([unlabeled_df,test_df])
diff  = diff.reset_index(drop=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
diff_gpby = diff.groupby(['Set_ID','DO_ID'])

# %%
idx = [d.index[0] for g,d in diff_gpby if len(d) == 1]

# %%
idx_val = [d.index[0] for g,d in diff_gpby if len(d) > 1]

# %%
train_df = diff.iloc[idx]

# %%
len(train_df)
# Out:
# 72592

# %%
dev_df = diff.iloc[idx_val]
len(dev_df)
# Out:
# 358

# %%
dev_df.relation.value_counts()
# Out:
# relief              121
# treatment           118
# effect               82
# contraindication     35
# Name: relation, dtype: int64

# %%
Y_dev = dev_df.merge(test_df, on=['Set_ID','DO_ID'])['relation_y']

# %%
Y_dev.value_counts()
# Out:
# Contraindication                  133
# Indication: Treatment             121
# Indication: Symptomatic Relief     65
# Effect                             39
# Name: relation_y, dtype: int64

# %%
classes_y = {
'Effect': 0,
'Contraindication': 1,
'Indication: Symptomatic Relief': 2,
'Indication: Treatment':3 
}
Y_dev =Y_dev.map(classes_y)

# %%
from snorkel.labeling import LabelingFunction

# %%
from snorkel.labeling import PandasLFApplier

# %%
from snorkel.labeling import LFAnalysis

# %%
my_phrases = { 'effect': 
["hypersensitivity reactions",
"associated with the risk of",
"to the risk of",
"a high risk for",
"a high risk of",
"high incidence of", 
"higher incidence of", 
" cause ",
" causes ",
"symptoms occure",
"teratogenic",
"site reaction",
"the risk of development",
"is associated with a risk of",
"symptoms of the poisoning",
"symptoms of poisoning" 
],

 'contraindication': 
["not administrated to",
"contraindicated in",
"contraindicatedin",
"should not be used",
"is contraindication for",
"is contraindication when",
"is contraindicated when",
"must not be used for",
"do not administer",
"should not initiate",
"not be administered to",
"do not initiate patients",
"contraindication for",
"should not be given",
"do not use"],
              
 'relief': 
["relief of the signs",
"relief of signs",
"relief of symptoms",
"relief of the symptoms",
"help",
"helps",
"relief of signs and symptoms of",
"reduction of symptoms of",
"treatment of the symptoms of",
"for the relief",
"management of the signs and symptoms of"], 

 'treatment':
[" indicated for the treatment of",
" indicated in the management of",
" indicated for the management of",
"for the management of",
"management of",
" indicated for the maintenance of remission", 
"or the treatment of",
"in the treatment of",
" indicated as",
" indicated in",
"be effective",
"active treatment of",
" indicated for",
"treatment of",
" indicated as an adjunct",
" indicated for use in the treatment of", 
" indicated for the intermittent treatment", 
" indicated to reduce the rate of",
" indicated for the rapid control",
" indicated for the control",
"reduce the risk of",
" indicated as adjunctive treatment",
"for the treatment of",
" indicated as an adjunct"]
           }

phrases = pd.DataFrame({ key:pd.Series(value) for key, value in my_phrases.items() })

phrases
# Out:
#                           effect          contraindication  \
# 0     hypersensitivity reactions      not administrated to
# 1    associated with the risk of        contraindicated in
# 2                 to the risk of         contraindicatedin
# 3                a high risk for        should not be used
# 4                 a high risk of   is contraindication for
# 5              high incidence of  is contraindication when
# 6            higher incidence of   is contraindicated when
# 7                         cause       must not be used for
# 8                        causes          do not administer
# 9                symptoms occure       should not initiate
# 10                   teratogenic    not be administered to
# 11                 site reaction  do not initiate patients
# 12       the risk of development      contraindication for
# 13  is associated with a risk of       should not be given
# 14     symptoms of the poisoning                do not use
# 15         symptoms of poisoning                       NaN
# 16                           NaN                       NaN
# 17                           NaN                       NaN
# 18                           NaN                       NaN
# 19                           NaN                       NaN
# 20                           NaN                       NaN
# 21                           NaN                       NaN
# 22                           NaN                       NaN
# 23                           NaN                       NaN
#
#                                      relief  \
# 0                       relief of the signs
# 1                           relief of signs
# 2                        relief of symptoms
# 3                    relief of the symptoms
# 4                                      help
# 5                                     helps
# 6           relief of signs and symptoms of
# 7                  reduction of symptoms of
# 8              treatment of the symptoms of
# 9                            for the relief
# 10  management of the signs and symptoms of
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
#
#                                       treatment
# 0                indicated for the treatment of
# 1                indicated in the management of
# 2               indicated for the management of
# 3                         for the management of
# 4                                 management of
# 5    indicated for the maintenance of remission
# 6                           or the treatment of
# 7                           in the treatment of
# 8                                  indicated as
# 9                                  indicated in
# 10                                 be effective
# 11                          active treatment of
# 12                                indicated for
# 13                                 treatment of
# 14                      indicated as an adjunct
# 15        indicated for use in the treatment of
# 16     indicated for the intermittent treatment
# 17              indicated to reduce the rate of
# 18              indicated for the rapid control
# 19                    indicated for the control
# 20                           reduce the risk of
# 21            indicated as adjunctive treatment
# 22                         for the treatment of
# 23                      indicated as an adjunct

# %%
effect = { 'phrases': 
["hypersensitivity reactions",
"associated with the risk of",
"to the risk of",
"a high risk for",
"a high risk of",
"high incidence of", 
"higher incidence of", 
" cause ",
" causes ",
"symptoms occure",
"teratogenic",
"site reaction",
"the risk of development",
"is associated with a risk of",
"symptoms of the poisoning",
"symptoms of poisoning" 
]}
effect_df = pd.DataFrame(effect)

 
contraindication = {'phrases': 
["not administrated to",
"contraindicated in",
"contraindicatedin",
"should not be used",
"is contraindication for",
"is contraindication when",
"is contraindicated when",
"must not be used for",
"do not administer",
"should not initiate",
"not be administered to",
"do not initiate patients",
"contraindication for",
"should not be given",
"do not use"]}
contraindication_df = pd.DataFrame(contraindication)
              
relief = {'phrases': 
["relief of the signs",
"relief of signs",
"relief of symptoms",
"relief of the symptoms",
"help",
"helps",
"relief of signs and symptoms of",
"reduction of symptoms of",
"treatment of the symptoms of",
"for the relief",
"management of the signs and symptoms of"]} 
relief_df = pd.DataFrame(relief)

treatment = {'phrases':
[" indicated for the treatment of",
" indicated in the management of",
" indicated for the management of",
"for the management of",
"management of",
" indicated for the maintenance of remission", 
"or the treatment of",
"in the treatment of",
" indicated as",
" indicated in",
"be effective",
"active treatment of",
" indicated for",
"treatment of",
" indicated as an adjunct",
" indicated for use in the treatment of", 
" indicated for the intermittent treatment", 
" indicated to reduce the rate of",
" indicated for the rapid control",
" indicated for the control",
"reduce the risk of",
" indicated as adjunctive treatment",
"for the treatment of"]}
treatment_df = pd.DataFrame(treatment)

# %%
from snorkel.labeling import labeling_function
from snorkel.preprocess import preprocessor


def check(x, string):
    return x in string


def find_phrases(text):
    # Find which phrases appear in the sentence
    class_effect = effect_df['phrases'].apply(lambda num : check(num,text))
    class_contraindication = contraindication_df['phrases'].apply(lambda num : check(num,text))
    class_relief = relief_df['phrases'].apply(lambda num : check(num,text))
    class_treatment = treatment_df['phrases'].apply(lambda num : check(num,text))
    
    #Create a dataset from them
    classes = {
    'effect': class_effect,
    'contraindication': class_contraindication,
    'relief': class_relief,
    'treatment':class_treatment 
    }

    classes = pd.DataFrame(classes)
    
    a = class_effect.index[class_effect == True].tolist()
    b = class_contraindication.index[class_contraindication == True].tolist()
    c = class_relief.index[class_relief == True].tolist()
    d = class_treatment.index[class_treatment == True].tolist()
    return classes, a, b, c, d
                                                 

# return the position of a phrase/word in a sentence
def pos_of_phrase(string, substring):
    substring_length = len(substring)    
    def recurse(locations_found, start):
        location = string.find(substring, start)
        if location != -1:
            return recurse(locations_found + [location], location+substring_length)
        else:
            return locations_found

    return recurse([], 0)

# return the minimum distance of all phrase/word from the target disease
def get_diff_of_pos(classes, column, pos, string):
    name = classes.columns[column]
    my_col = classes[name]
    x = [k for k,v in enumerate(my_col) if v == True]
    
    candidate = []
    distances = []
    for i in range(len(x)):
        word = phrases[classes.columns[column]][x[i]]
        
        for i in range(len(pos_of_phrase(string, word))):
            distances.append( abs(pos -   pos_of_phrase(string, word)[i]) )

    return min(distances)


@labeling_function()
def phrase_occur(x):
    
    text = x.Context

    classes, a, b, c, d =find_phrases(text)


    # Check if you have unique class and label based on that 
    if len(a)!=0 and len(b)==len(c)==len(d)==0:
        #print('effect')
        return RELATION_CLASSES['effect']
    elif len(b)!=0 and len(a)==len(c)==len(d)==0:
        #print('contraindication')
        return RELATION_CLASSES['contraindication']
    elif len(c)!=0 and len(a)==len(b)==len(d)==0:
        #print('relief')
        return  RELATION_CLASSES['relief']
    elif len(d)!=0 and len(a)==len(b)==len(c)==0:
        #print('treatment')
        return  RELATION_CLASSES['treatment']
    elif len(a)==len(b)==len(c)==len(d)==0:
        #print('IDK')
        return ABSTAIN
    return ABSTAIN

@labeling_function()
def phrase_closeness(x):
    text = x.Context
    pos1 = text.find(x.disease)
    dis_len = len(x.disease)
    classes, a, b, c, d = find_phrases(text)
    
    minDist = len(text.split())
    category = ABSTAIN
    for class_,found_phrases in {'effect':a, 'contraindication':b, 'relief':c, 'treatment':d}.items():
        for phrase_index in found_phrases:
            phrase =phrases.loc[phrase_index,class_]
            pos2 = text.find(phrase)
            phr_len = len(phrase)
            if pos1 > pos2:
                span = text[pos2+phr_len:pos1]
            else:
                span = text[pos1+dis_len:pos2]
            words = span.split()
            distance = len(words)
            if minDist > distance:
                minDist = distance
                category = class_
    
    if category == ABSTAIN:
        return ABSTAIN
    return RELATION_CLASSES[category]

@labeling_function()
def crowd(x):
    #print (x.relation_type)
    if x.relation in RELATION_CLASSES:
        return RELATION_CLASSES[x.relation]
    return ABSTAIN

# %%
dev_df.relation.unique()
# Out:
# array(['treatment', 'effect', 'relief', 'contraindication', nan],
#       dtype=object)

# %%
ABSTAIN = -1

RELATION_CLASSES = {
'effect': 0,
'contraindication': 1,
'relief': 2,
'treatment':3 
} 
RELATION_CLASSES
# Out:
# {'effect': 0, 'contraindication': 1, 'relief': 2, 'treatment': 3}

# %%
lfs = [crowd, phrase_occur, phrase_closeness]
applier = PandasLFApplier(lfs)

# %%
L_train = applier.apply(train_df)

# %%
L_dev = applier.apply(dev_df)
# Out:
#   0%|          | 0/358 [00:00<?, ?it/s]
#   4%|▎         | 13/358 [00:00<00:02, 124.79it/s]
#   7%|▋         | 26/358 [00:00<00:02, 125.52it/s]
#  11%|█         | 39/358 [00:00<00:02, 124.70it/s]
#  15%|█▍        | 52/358 [00:00<00:02, 124.60it/s]
#  18%|█▊        | 64/358 [00:00<00:02, 123.08it/s]
#  22%|██▏       | 77/358 [00:00<00:02, 124.53it/s]
#  25%|██▌       | 90/358 [00:00<00:02, 124.39it/s]
#  29%|██▉       | 103/358 [00:00<00:02, 124.57it/s]
#  32%|███▏      | 116/358 [00:00<00:01, 124.33it/s]
#  36%|███▌      | 128/358 [00:01<00:01, 122.79it/s]
#  40%|███▉      | 142/358 [00:01<00:01, 125.46it/s]
#  43%|████▎     | 155/358 [00:01<00:01, 123.61it/s]
#  47%|████▋     | 168/358 [00:01<00:01, 123.48it/s]
#  51%|█████     | 181/358 [00:01<00:01, 124.15it/s]
#  54%|█████▍    | 195/358 [00:01<00:01, 126.62it/s]
#  58%|█████▊    | 208/358 [00:01<00:01, 126.95it/s]
#  62%|██████▏   | 221/358 [00:01<00:01, 127.39it/s]
#  65%|██████▌   | 234/358 [00:01<00:00, 127.33it/s]
#  69%|██████▉   | 247/358 [00:01<00:00, 127.47it/s]
#  73%|███████▎  | 260/358 [00:02<00:00, 127.52it/s]
#  76%|███████▋  | 273/358 [00:02<00:00, 127.23it/s]
#  80%|███████▉  | 286/358 [00:02<00:00, 127.37it/s]
#  84%|████████▎ | 299/358 [00:02<00:00, 127.43it/s]
#  87%|████████▋ | 312/358 [00:02<00:00, 127.21it/s]
#  91%|█████████ | 325/358 [00:02<00:00, 126.92it/s]
#  94%|█████████▍| 338/358 [00:02<00:00, 127.80it/s]
# 100%|██████████| 358/358 [00:02<00:00, 125.53it/s]

# %%
Y_dev.unique()
# Out:
# array([3, 0, 2, 1])

# %%
from snorkel.labeling import LabelModel
# Train LabelModel.
label_model = LabelModel(cardinality=4, verbose=True)
label_model.fit(L_train, n_epochs=100, seed=123, log_freq=20, l2=0.1, lr=0.01)

# %%
label_model.fit(L_train, Y_dev, n_epochs=5000, log_freq=500, seed=12345)

# %%
from snorkel.analysis import metric_score
from snorkel.utils import probs_to_preds

probs_dev = label_model.predict_proba(L_dev)
preds_dev = probs_to_preds(probs_dev)
print(
    f"Label model f1 score: {metric_score(Y_dev, preds_dev, probs=probs_dev, metric='f1_macro')}"
)
print(
    f"Label model roc-auc: {metric_score(Y_dev, preds_dev, probs=probs_dev, metric='accuracy')}"
)
# Out:
# Label model f1 score: 0.643495192430824
# Label model roc-auc: 0.7067039106145251

# %%
from snorkel.labeling import filter_unlabeled_dataframe

probs_train = label_model.predict_proba(L_train)
pred_train =label_model.predict(L_train)
df_train_filtered, probs_train_filtered = filter_unlabeled_dataframe(
    X=train_df, y=pred_train, L=L_train
)

# %%
df_train_filtered['noisy_labels'] =probs_train_filtered
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_train_filtered.relation = df_train_filtered.relation.replace(RELATION_CLASSES)
# Out:
# /home/jovyan/.local/lib/python3.7/site-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_train_filtered.rename(columns={'relation':'crowd_label'}, inplace=True)
# Out:
# /home/jovyan/.local/lib/python3.7/site-packages/pandas/core/frame.py:4238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
df_train_filtered.to_csv('train_data.csv',index=False)

# %%
df_train_filtered

# %%
test_df['label']= Y_dev

# %%
test_df.rename(columns={'relation':'crowd_label'}, inplace=True)

# %%
test_df.head()
# Out:
#         DO_ID    DB_ID    Drug_name                                Set_ID  \
# 0  DOID_10763  DB00401  Nisoldipine  a6a8a8ba-3966-4f37-a58b-44d3b05bdc4e
# 1  DOID_10763  DB00612   Bisoprolol  c818c38d-ee37-4ceb-b078-611483b4f743
# 2  DOID_10763  DB00960     Pindolol  b5a5a1e9-ee9b-41b1-b2d5-5f5834b816a7
# 3  DOID_10763  DB00876   Eprosartan  64fbc500-3b77-4c9c-8576-b3ec5f6655a5
# 4  DOID_10763  DB00598    Labetalol  f81baebd-424d-4d39-893c-d9d622377c53
#
#                                              Context      Section  \
# 0  Nisoldipine extended-release tablets are indic...  Indications
# 1  Bisoprolol fumarate tablets, USP are indicated...  Indications
# 2  Pindolol tablets are indicated in the manageme...  Indications
# 3  Eprosartan mesylate tablets are indicated for ...  Indications
# 4  Labetalol hydrochloride tablets, USP are indic...  Indications
#
#              crowd_label  label
# 0  Indication: Treatment      3
# 1  Indication: Treatment      0
# 2  Indication: Treatment      3
# 3  Indication: Treatment      0
# 4  Indication: Treatment      2

# %%
test_df.to_csv('test_data.csv',index=False)

# %%
# !pip install tensorflow==1.14.0 --user
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip/http' or its parent directory is not owned by the current user and the cache has been disabled. Please check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned by the current user and caching wheels has been disabled. check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Collecting tensorflow==1.14.0
#   Downloading https://files.pythonhosted.org/packages/f4/28/96efba1a516cdacc2e2d6d081f699c001d414cc8ca3250e6d59ae657eb2b/tensorflow-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (109.3MB)
#      |████████████████████████████████| 109.3MB 18.3MB/s eta 0:00:01   |███                             | 10.4MB 3.4MB/s eta 0:00:30     |███▏                            | 10.7MB 3.4MB/s eta 0:00:29     |███▏                            | 11.0MB 3.4MB/s eta 0:00:29     |███▉                            | 13.0MB 7.0MB/s eta 0:00:14     |████▏                           | 14.1MB 7.0MB/s eta 0:00:14     |████▏                           | 14.3MB 7.0MB/s eta 0:00:14     |████▌                           | 15.5MB 7.0MB/s eta 0:00:14     |████▋                           | 15.7MB 7.0MB/s eta 0:00:14     |████▋                           | 15.8MB 7.0MB/s eta 0:00:14     |█████                           | 17.4MB 6.3MB/s eta 0:00:15     |█████▌                          | 18.7MB 6.3MB/s eta 0:00:15     |██████▊                         | 23.1MB 3.4MB/s eta 0:00:26     |█████████▍                      | 32.2MB 3.9MB/s eta 0:00:20     |██████████▍                     | 35.3MB 5.0MB/s eta 0:00:15     |██████████▋                     | 36.1MB 5.0MB/s eta 0:00:15     |██████████▋                     | 36.4MB 5.0MB/s eta 0:00:15     |███████████▏                    | 38.0MB 2.6MB/s eta 0:00:27     |███████████▏                    | 38.2MB 2.6MB/s eta 0:00:27     |███████████▍                    | 38.7MB 2.6MB/s eta 0:00:27     |███████████▋                    | 39.8MB 2.6MB/s eta 0:00:27     |███████████▊                    | 40.1MB 2.6MB/s eta 0:00:27     |███████████▉                    | 40.4MB 2.6MB/s eta 0:00:27     |████████████▎                   | 41.9MB 2.6MB/s eta 0:00:26     |█████████████▋                  | 46.3MB 2.4MB/s eta 0:00:27     |██████████████▎                 | 48.7MB 9.3MB/s eta 0:00:07     |██████████████▋                 | 49.8MB 9.3MB/s eta 0:00:07     |██████████████▉                 | 50.5MB 9.3MB/s eta 0:00:07     |███████████████                 | 50.9MB 9.3MB/s eta 0:00:07     |███████████████▏                | 51.9MB 9.3MB/s eta 0:00:07     |███████████████▍                | 52.5MB 9.3MB/s eta 0:00:07     |███████████████▍                | 52.7MB 9.3MB/s eta 0:00:07     |███████████████▋                | 53.3MB 9.3MB/s eta 0:00:07     |████████████████                | 54.9MB 6.0MB/s eta 0:00:10     |████████████████▏               | 55.1MB 6.0MB/s eta 0:00:10     |███████████████████▉            | 67.6MB 5.1MB/s eta 0:00:09     |████████████████████            | 68.6MB 5.1MB/s eta 0:00:09     |████████████████████▍           | 69.4MB 5.1MB/s eta 0:00:08     |████████████████████▍           | 69.6MB 7.4MB/s eta 0:00:06     |█████████████████████▉          | 74.4MB 7.4MB/s eta 0:00:05     |███████████████████████▎        | 79.4MB 5.7MB/s eta 0:00:06     |███████████████████████▎        | 79.6MB 5.7MB/s eta 0:00:06     |███████████████████████▍        | 80.0MB 5.7MB/s eta 0:00:06     |████████████████████████▏       | 82.6MB 7.0MB/s eta 0:00:04     |████████████████████████████▊   | 97.9MB 6.7MB/s eta 0:00:02     |█████████████████████████████▏  | 99.7MB 3.6MB/s eta 0:00:03     |█████████████████████████████▌  | 100.7MB 3.6MB/s eta 0:00:03     |█████████████████████████████▋  | 100.9MB 3.6MB/s eta 0:00:03     |██████████████████████████████▏ | 102.9MB 3.6MB/s eta 0:00:02     |██████████████████████████████▋ | 104.4MB 3.6MB/s eta 0:00:02
# Collecting astor>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/c3/88/97eef84f48fa04fbd6750e62dcceafba6c63c81b7ac1420856c8dcc0a3f9/astor-0.8.1-py2.py3-none-any.whl
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0) (1.16.2)
# Collecting termcolor>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 20.7MB/s eta 0:00:01
# Collecting wrapt>=1.11.1
#   Downloading https://files.pythonhosted.org/packages/23/84/323c2415280bc4fc880ac5050dddfb3c8062c2552b34c2e512eb4aa68f79/wrapt-1.11.2.tar.gz
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 15.6MB/s eta 0:00:01     |███████████████████             | 1.9MB 15.6MB/s eta 0:00:01
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0) (0.33.6)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0) (1.13.0)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 6.0MB/s eta 0:00:01
# Collecting grpcio>=1.8.6
#   Downloading https://files.pythonhosted.org/packages/bc/b3/0052e38c640d52b710e235b15821cc3c61d0065bf54e70a44550ef127349/grpcio-1.26.0-cp37-cp37m-manylinux2010_x86_64.whl (2.4MB)
#      |████████████████████████████████| 2.4MB 5.0MB/s eta 0:00:01
# Collecting keras-preprocessing>=1.0.5
#   Downloading https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41kB)
#      |████████████████████████████████| 51kB 11.4MB/s ta 0:00:011
# Collecting gast>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/1f/04/4e36c33f8eb5c5b6c622a1f4859352a6acca7ab387257d4b3c191d23ec1d/gast-0.3.2.tar.gz
# Collecting absl-py>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/1a/53/9243c600e047bd4c3df9e69cfabc1e8004a82cac2e0c484580a78a94ba2a/absl-py-0.9.0.tar.gz (104kB)
#      |████████████████████████████████| 112kB 4.2MB/s eta 0:00:01
# Collecting google-pasta>=0.1.6
#   Downloading https://files.pythonhosted.org/packages/c3/fd/1e86bc4837cc9a3a5faf3db9b1854aa04ad35b5f381f9648fbe81a6f94e4/google_pasta-0.1.8-py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 8.7MB/s eta 0:00:011
# Requirement already satisfied: protobuf>=3.6.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0) (3.9.2)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras-applications>=1.0.6->tensorflow==1.14.0) (2.9.0)
# Collecting markdown>=2.6.8
#   Downloading https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl (87kB)
#      |████████████████████████████████| 92kB 7.1MB/s eta 0:00:011
# Collecting werkzeug>=0.11.15
#   Downloading https://files.pythonhosted.org/packages/ce/42/3aeda98f96e85fd26180534d36570e4d18108d62ae36f87694b476b83d6f/Werkzeug-0.16.0-py2.py3-none-any.whl (327kB)
#      |████████████████████████████████| 327kB 5.7MB/s eta 0:00:01
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (42.0.2.post20191201)
# Building wheels for collected packages: termcolor, wrapt, gast, absl-py
#   WARNING: Building wheel for termcolor failed: [Errno 13] Permission denied: '/home/jovyan/.cache/pip/wheels/7c'
#   WARNING: Building wheel for wrapt failed: [Errno 13] Permission denied: '/home/jovyan/.cache/pip/wheels/d7'
#   WARNING: Building wheel for gast failed: [Errno 13] Permission denied: '/home/jovyan/.cache/pip/wheels/59'
#   WARNING: Building wheel for absl-py failed: [Errno 13] Permission denied: '/home/jovyan/.cache/pip/wheels/8e'
# Failed to build termcolor wrapt gast absl-py
# Installing collected packages: astor, termcolor, keras-applications, wrapt, markdown, absl-py, grpcio, werkzeug, tensorboard, tensorflow-estimator, keras-preprocessing, gast, google-pasta, tensorflow
#     Running setup.py install for termcolor ... done
#     Running setup.py install for wrapt ... done
#   WARNING: The script markdown_py is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#     Running setup.py install for absl-py ... done
#   WARNING: The script tensorboard is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#     Running setup.py install for gast ... done
#   WARNING: The scripts freeze_graph, saved_model_cli, tensorboard, tf_upgrade_v2, tflite_convert, toco and toco_from_protos are installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed absl-py-0.9.0 astor-0.8.1 gast-0.3.2 google-pasta-0.1.8 grpcio-1.26.0 keras-applications-1.0.8 keras-preprocessing-1.1.0 markdown-3.1.1 tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0 termcolor-1.1.0 werkzeug-0.16.0 wrapt-1.11.2

# %%
from tf_model import get_model, get_feature_arrays
from utils import get_n_epochs

X_train = get_feature_arrays(df_train_filtered)
model = get_model()
batch_size = 64
model.fit(X_train, probs_train_filtered, batch_size=batch_size, epochs=get_n_epochs())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-93-15ef1c17b2fc> in <module>
# ----> 1 from tf_model import get_model, get_feature_arrays
#       2 from utils import get_n_epochs
#       3
#       4 X_train = get_feature_arrays(df_train_filtered)
#       5 model = get_model()
#
# ModuleNotFoundError: No module named 'tf_model'

# %%
from snorkel.analysis import metric_score

preds_dev = label_model.predict(L_dev)

# %%
acc = metric_score(Y_dev, preds_dev, probs=None, metric="accuracy")

# %%
print(f"LabelModel Accuracy: {acc:.3f}")
# Out:
# LabelModel Accuracy: 0.782

# %%
f1 = metric_score(Y_dev, preds_dev, probs=None, metric='f1_macro')
print(f"LabelModel F1: {f1:.3f}")
# Out:
# LabelModel F1: 0.725

# %%
from snorkel.labeling import LFAnalysis
LFAnalysis(L_dev, lfs).lf_summary(Y_dev.values).head()
# Out:
#                   j      Polarity  Coverage  Overlaps  Conflicts  Correct  \
# crowd             0  [0, 1, 2, 3]  0.994413  0.916201   0.424581      201
# phrase_occur      1  [0, 1, 2, 3]  0.583799  0.583799   0.282123      166
# phrase_closeness  2  [0, 1, 2, 3]  0.921788  0.918994   0.424581      244
#
#                   Incorrect  Emp. Acc.
# crowd                   155   0.564607
# phrase_occur             43   0.794258
# phrase_closeness         86   0.739394

# %%
test_df.relation.value_counts()

# %%
import numpy as np
import torch
from pytorch_transformers import BertModel, BertTokenizer

# %%
model = BertModel.from_pretrained("/jupyter/bert/wwm_uncased_L-24_H-1024_A-16")

tokenizer = BertTokenizer.from_pretrained("/jupyter/bert/wwm_uncased_L-24_H-1024_A-16")


def encode_text(text):
    input_ids = torch.tensor([tokenizer.encode(text)])
    return model(input_ids)[0].mean(1)[0].detach().numpy()


X_train = np.array(list(df_train.tweet_text.apply(encode_text).values))
X_test = np.array(list(df_test.tweet_text.apply(encode_text).values))
Model on labels
# Out:
#   File "<ipython-input-330-a8b65a08b151>", line 13
#     Model on labels
#            ^
# SyntaxError: invalid syntax

# %%
# !pip install transformers --user
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip/http' or its parent directory is not owned by the current user and the cache has been disabled. Please check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned by the current user and caching wheels has been disabled. check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/50/10/aeefced99c8a59d828a92cc11d213e2743212d3641c87c82d61b035a7d5c/transformers-2.3.0-py3-none-any.whl (447kB)
#      |████████████████████████████████| 450kB 3.1MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from transformers) (1.16.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from transformers) (2.22.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from transformers) (4.40.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.7/site-packages (from transformers) (2020.1.8)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.7/site-packages (from transformers) (0.0.38)
# Requirement already satisfied: boto3 in /home/jovyan/.local/lib/python3.7/site-packages (from transformers) (1.11.0)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.7/site-packages (from transformers) (0.1.85)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->transformers) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->transformers) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->transformers) (1.25.7)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers) (1.13.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers) (7.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers) (0.14.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.7/site-packages (from boto3->transformers) (0.9.4)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/jovyan/.local/lib/python3.7/site-packages (from boto3->transformers) (0.3.0)
# Requirement already satisfied: botocore<1.15.0,>=1.14.0 in /home/jovyan/.local/lib/python3.7/site-packages (from boto3->transformers) (1.14.0)
# Requirement already satisfied: docutils<0.16,>=0.10 in /opt/conda/lib/python3.7/site-packages (from botocore<1.15.0,>=1.14.0->boto3->transformers) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.7/site-packages (from botocore<1.15.0,>=1.14.0->boto3->transformers) (2.8.1)
# Installing collected packages: transformers
# Successfully installed transformers-2.3.0

# %%
from transformers import BertTokenizer

# Load the BERT tokenizer.
print('Loading BERT tokenizer...')
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
# Out:
# Loading BERT tokenizer...

# %%
text = train_df.loc[0,'Context']
print (text)
# Out:
# For the management of moderately severe to severe essential hypertension and in uncomplicated cases of malignant hypertension.

# %%
encoded_sent = tokenizer.encode(
                        text,                      # Sentence to encode.
                        add_special_tokens = True, # Add '[CLS]' and '[SEP]'

                        # This function also supports truncation and conversion
                        # to pytorch tensors, but we need to do padding, so we
                        # can't use these features :( .
                        #max_length = 128,          # Truncate all sentences.
                        #return_tensors = 'pt',     # Return pytorch tensors.
                   )

# %%
encoded_sent
# Out:
# [101,
#  2005,
#  1996,
#  2968,
#  1997,
#  17844,
#  5729,
#  2000,
#  5729,
#  6827,
#  23760,
#  29048,
#  1998,
#  1999,
#  4895,
#  9006,
#  24759,
#  17872,
#  3572,
#  1997,
#  16007,
#  27881,
#  23760,
#  29048,
#  1012,
#  102]
